# %%
# !pip install requests
# !pip install beautifulsoup4
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Mounted at /content/drive

# %%
# books_to_scrape = [
#     "1984",
#     "To Kill a Mockingbird",
#     "The Great Gatsby",
#     "Pride and Prejudice",
#     "The Catcher in the Rye",
#     "Lord of the Flies",
#     "Animal Farm",
#     "Brave New World",
#     "The Lord of the Rings",
#     "The Hobbit",
#     "Fahrenheit 451",
#     "The Grapes of Wrath",
#     "The Old Man and the Sea",
#     "The Adventures of Huckleberry Finn",
#     "Moby-Dick",
#     "War and Peace",
#     "Crime and Punishment",
#     "The Brothers Karamazov",
#     "Don Quixote",
#     "Hamlet",
#     "Romeo and Juliet",
#     "Macbeth",
#     "Othello",
#     "The Merchant of Venice",
#     "Frankenstein",
#     "Dracula",
#     "Wuthering Heights",
#     "Jane Eyre",
#     "Great Expectations",
#     "The Scarlet Letter",
#     "The Picture of Dorian Gray",
#     "Heart of Darkness",
#     "One Hundred Years of Solitude",
#     "The Bell Jar",
#     "The Stranger",
#     "Slaughterhouse-Five",
#     "Catch-22",
#     "Beloved",
#     "A Tale of Two Cities",
#     "Les Misérables",
#     "Anna Karenina",
#     "The Odyssey",
#     "The Iliad",
#     "The Aeneid",
#     "The Canterbury Tales",
#     "The Divine Comedy",
#     "Paradise Lost",
#     "Walden",
#     "The Adventures of Tom Sawyer",
#     "Adventures of Huckleberry Finn",
#     "Little Women",
#     "The Grapes of Wrath",
#     "The Sound and the Fury",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "As I Lay Dying",
#     "Their Eyes Were Watching God",
#     "The Color Purple",
#     "Invisible Man",
#     "Native Son",
#     "The Call of the Wild",
#     "White Fang",
#     "The War of the Worlds",
#     "20,000 Leagues Under the Sea",
#     "Journey to the Center of the Earth",
#     "The Three Musketeers",
#     "Robinson Crusoe",
#     "Gulliver's Travels",
#     "The Time Machine",
#     "Dr. Jekyll and Mr. Hyde",
#     "The Adventures of Sherlock Holmes",
#     "The Hound of the Baskervilles",
#     "The Count of Monte Cristo",
#     "The Invisible Man",
#     "The Island of Dr. Moreau",
#     "The Metamorphosis",
#     "The Trial",
#     "One Flew Over the Cuckoo's Nest",
#     "The Jungle",
#     "The Age of Innocence",
#     "The Bostonians",
#     "The Red Badge of Courage",
#     "The Portrait of a Lady",
#     "The Turn of the Screw",
#     "Sister Carrie",
#     "Winesburg, Ohio",
#     "A Farewell to Arms",
#     "For Whom the Bell Tolls",
#     "The Old Man and the Sea",
#     "A Farewell to Arms",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "The Good Soldier",
#     "The Heart of the Matter",
#     "The End of the Affair",
#     "The Power and the Glory",
#     "The Quiet American",
#     "The Third Man",
#     "The Human Factor",
#     "The Tale of Genji",
#     "One Hundred Years of Solitude",
#     "The Master and Margarita",
#     "The Book Thief",
#     "The Kite Runner",
#     "Norwegian Wood",
#     "The Alchemist",
#     "The Joy Luck Club",
#     "Things Fall Apart",
#     "The God of Small Things",
#     "The Hitchhiker's Guide to the Galaxy",
#     "The Handmaid's Tale",
#     "The Road",
#     "The Martian",
#     "Dune",
#     "Harry Potter and the Sorcerer's Stone",
#     "The Hunger Games",
#     "The Help",
#     "The Girl with the Dragon Tattoo",
#     "Gone Girl",
#     "The Girl on the Train",
#     "The Da Vinci Code",
#     "Life of Pi",
#     "The Curious Incident of the Dog in the Night-Time",
#     "The Secret Life of Bees",
#     "The Lovely Bones",
#     "The Book of Negroes",
#     "The Night Circus",
#     "The Catcher in the Rye",
#     "The Perks of Being a Wallflower",
#     "The Fault in Our Stars",
#     "Eleanor Oliphant Is Completely Fine",
#     "Educated",
#     "Where the Crawdads Sing",
#     "Circe",
#     "The Nightingale",
#     "All the Light We Cannot See",
#     "Before We Were Yours",
#     "A Man Called Ove",
#     "The Silent Patient",
#     "The Goldfinch",
#     "Big Little Lies",
#     "The Tattooist of Auschwitz",
#     "The Rosie Project",
#     "The Underground Railroad",
#     "Orphan Train",
#     "A Gentleman in Moscow",
#     "The Light Between Oceans",
#     "The Night Circus",
#     "The Miniaturist",
#     "The Girl With All the Gifts",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Circle",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Luminaries"
# ]
# # Ensure uniqueness of titles
# books_to_scrape = list(set(books_to_scrape))

# # # Truncate the list to 100 titles or less
# # books_to_scrape = books_to_scrape[:100]

# # Print the first few book titles to verify
# print(books_to_scrape[:100])

# %%
import nltk
nltk.download('book')

from nltk.book import text4  # Using text4, which contains a collection of texts from the Gutenberg project

# Extracting unique book titles from the Gutenberg corpus
book_titles = list(set(text4))

# Filtering out non-alphanumeric characters and ensuring titles are capitalized
book_titles = [title.strip().capitalize() for title in book_titles if title.isalnum()]
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(len(book_titles))
books_to_scrape = book_titles[9000:9993]
# books_to_scrape = book_titles[1000:2000]
# etc
print(len(books_to_scrape))
print(books_to_scrape)
# Out:
# 9993
# 993
# ['Conditions', 'Split', 'Needful', 'Dispassionate', 'Greatest', 'World', 'Bar', 'Failure', 'Forty', 'Distrust', 'Mystery', 'Renders', 'Exportation', 'Envisage', 'Slaveholding', 'Fight', 'Befitting', 'Misguided', 'Historic', 'Defect', 'Renounce', 'Cultural', 'Hurtful', 'Whose', 'Almighty', 'Met', 'Indicated', '1790', 'Stability', 'Maturity', 'Burdensome', 'Indissoluble', 'Quarters', 'Thought', 'Thomas', 'Above', 'Alter', 'Indivisible', 'Warmth', 'Steadfast', 'Thirds', 'Invoking', 'Personal', 'Unbending', 'Pleasantness', 'Plagues', 'Commitments', 'Household', 'Lifetime', 'Seize', 'Threefold', 'Reverend', 'Reborn', 'Lot', 'Mariners', 'Rewarding', 'Considerately', 'Taxing', 'Access', 'Compassion', 'Thoughtfully', 'Throng', 'Goes', 'Initiate', 'Comprise', 'Diversification', 'Pursuance', 'Value', 'Negotiations', 'Politics', 'Profits', 'Elevation', 'Committing', 'Tangible', 'Pursue', 'Recognition', 'King', 'Holy', 'Talents', 'Bargain', 'Monumental', 'Fiber', 'Cotton', 'Incapable', 'Divine', 'Look', 'Retained', 'Enhance', 'Dishonorable', 'Advance', 'These', 'Gigantic', 'Healing', 'Behave', 'Abound', 'Faithfully', 'Manufacturing', 'Changeless', 'Intentioned', 'Americansâ', 'Juncture', 'Discontents', 'Penalizes', 'Inflict', 'Estimation', 'Invention', 'Beloved', 'Values', 'Jungles', 'Genius', 'Shock', 'Draw', 'Encroaches', 'Example', 'Here', 'Discriminations', 'Induces', 'Carriers', 'Uniform', 'Skill', 'Owe', 'Pernicious', 'Timeâ', 'Polygamy', 'Multiplying', 'Wit', 'Finishing', 'Day', 'Mosque', 'Supplying', 'Cromwell', 'Scruple', 'Infusing', 'Gallant', 'Satisfaction', 'Imminent', 'Canal', 'Retaliation', 'Godsend', 'Humiliation', 'Knowing', 'Aboriginal', 'Lakes', 'Three', 'Humiliating', 'Necessities', 'Based', 'Kindly', 'Attack', 'Saw', 'Friendship', 'Neighborhood', 'Exterminating', 'Studiously', 'Corner', 'Shameful', 'Sundered', 'Igniting', 'Exciting', 'Volunteer', 'Exploit', 'Infancy', 'Interest', 'Prisoner', 'Longings', 'Prepossessions', 'Undiminished', 'Runs', 'Clarified', 'Symptom', 'Guaranties', 'Vision', 'Residents', 'Habit', 'Realizing', 'Ratified', 'Readily', 'Contentious', 'Anniversary', 'Dishonor', 'Spasmodic', 'Approach', 'Adherence', 'Soundly', 'Ears', 'Schemes', 'Consume', 'Hard', 'Courts', 'Unquestionable', 'Superiors', 'South', 'Domination', 'Vow', 'Substitutes', 'Cost', 'Continue', 'Limit', 'Occupation', 'Sympathetic', 'Estimated', 'Contests', 'Lost', 'Anticipating', 'Simplify', 'Elder', 'Information', 'Acquired', 'Intangible', 'Distance', '30th', 'Responses', 'Lessons', 'Tongues', 'Drastically', 'Thirdly', 'Suggested', 'Upon', 'Expand', 'Times', 'Evinced', 'Examine', 'Inequality', 'Bounties', 'T', 'Emphatically', 'Escapes', 'Revolutionary', 'Aim', 'Propitious', 'Carries', 'Prevalence', 'Child', 'Aliens', 'Patrol', 'Hold', 'Breast', 'Achieved', 'Degenerate', 'Reference', 'Abstain', 'Relation', 'Guadalcanal', 'Beneficent', 'Firmest', 'Old', 'Boat', 'Unanimity', 'Domain', 'Regard', 'Gloomy', 'Fears', 'Depend', 'Decision', 'Affliction', 'Final', 'Commissions', 'Bound', 'Discover', 'Useful', 'Thrones', 'Order', 'Specter', 'Measures', 'Able', 'Arbitration', 'His', 'Formidable', 'Seats', 'Measurable', 'Fountain', 'Platforms', 'Portion', 'Directed', 'Armies', 'Renounced', 'Implore', 'Altar', 'Week', 'Price', 'Traces', 'Vital', 'Calmness', '1815', 'Fitted', 'League', 'Xa', 'Colonists', 'Investigations', 'What', 'Christs', 'Palliation', 'Factor', 'Contemplation', 'Manage', 'Emergency', 'Having', 'Administrators', 'Civilized', 'Encyclopedia', 'Implies', 'Comprehensively', 'Spokesmen', 'Went', 'Characteristic', 'Visit', 'Enlarge', 'Untrue', 'Advocates', 'Especially', 'Cities', 'Contribution', 'Regulating', 'Member', 'Dreams', 'Between', 'Refunding', 'Contended', 'Effects', 'Ineffectual', 'Eve', 'Furtherance', 'Pardoned', 'Mayflower', 'Shaking', 'Mortifications', 'Prelude', 'Energy', 'Ill', 'Regretted', 'Conscientiously', 'Weaken', 'Cherishes', 'Adds', 'Prolonged', 'Reflections', 'Contemplations', 'Creed', 'Boundless', 'Compromise',  ...

# %%
import requests
from googlesearch import search
from bs4 import BeautifulSoup
import os

# def get_summary(book_title):
#     url = f"https://www.sparknotes.com/lit/{book_title}/summary/"
#     response = requests.get(url)
#     # print(response)
#     soup = BeautifulSoup(response.text, 'html.parser')

#     summary_div = soup.find('div', class_='mainTextContent main-container')
#     # print(summary_div)
#     if summary_div:
#         summary = summary_div.text.strip()
#         return summary
#     else:
#         print(f"Error: Summary not found for {book_title}")
#         return None

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url and 'summary' in url:
            return url
    return None


def get_summary_from_sparknotes(book_title):
    # Check if the summary file already exists
    filename = f"{output_dir}/{book_title}_summary.txt"
    if os.path.exists(filename):
      print(f"Summary for {book_title} already exists. Reading from file.")
    else:
      sparknotes_url = get_sparknotes_url(book_title)
      print(sparknotes_url)
      if sparknotes_url:
          response = requests.get(sparknotes_url)
          soup = BeautifulSoup(response.text, 'html.parser')
          summary_div = soup.find('div', class_='mainTextContent main-container')
          if summary_div:
              summary = summary_div.text.strip()
              return summary
          else:
              print(f"Error: Summary not found for {book_title}")
              return None
      else:
          print(f"Error: SparkNotes summary not found for {book_title}")
          return None


def save_summary_to_file(book_title, summary, output_dir = "summaries"):
    if summary is not None:  # Check if summary is not None
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        filename = f"{output_dir}/{book_title}_summary.txt"
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(summary)
            print(f"Summary for {book_title} saved successfully.")
    # else:
    #     print(f"No summary found for {book_title}. Skipping saving to file.")

# books_to_scrape = ["1984", "ToKillAMockingbird", "TheGreatGatsby"]  # Add more book titles as needed

for book_title in books_to_scrape:
    try:
        output_dir = "summaries"
        summary = get_summary_from_sparknotes(book_title)
        # print(summary)

        save_summary_to_file(book_title, summary,)
    except Exception as e:
        print(f"Error processing {book_title}: {e}")
# Out:
# https://www.sparknotes.com/lit/nervouscondition/summary/
# Summary for Conditions saved successfully.
# None
# Error: SparkNotes summary not found for Split
# None
# Error: SparkNotes summary not found for Needful
# https://www.sparknotes.com/lit/morrie/summary/
# Summary for Dispassionate saved successfully.
# https://www.sparknotes.com/lit/greatex/summary/
# Summary for Greatest saved successfully.
# https://www.sparknotes.com/lit/bravenew/summary/
# Summary for World saved successfully.
# None
# Error: SparkNotes summary not found for Bar
# None
# Error: SparkNotes summary not found for Failure
# None
# Error: SparkNotes summary not found for Forty
# None
# Error: SparkNotes summary not found for Distrust
# https://www.sparknotes.com/lit/the-curious-incident-of-the-dog-in-the-night-time/summary/
# Summary for Mystery saved successfully.
# https://www.sparknotes.com/lit/night/summary/
# Summary for Renders saved successfully.
# None
# Error: SparkNotes summary not found for Exportation
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Envisage saved successfully.
# None
# Error: SparkNotes summary not found for Slaveholding
# None
# Error: SparkNotes summary not found for Fight
# None
# Error: SparkNotes summary not found for Befitting
# None
# Error: SparkNotes summary not found for Misguided
# https://www.sparknotes.com/lit/oldtestament/summary/
# Summary for Historic saved successfully.
# None
# Error: SparkNotes summary not found for Defect
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Renounce saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Cultural saved successfully.
# None
# Error: SparkNotes summary not found for Hurtful
# https://www.sparknotes.com/lit/afraidofwoolf/summary/
# Summary for Whose saved successfully.
# https://www.sparknotes.com/lit/freak-the-mighty/summary/
# Summary for Almighty saved successfully.
# https://www.sparknotes.com/lit/wrinkle/summary/
# Summary for Met saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Indicated saved successfully.
# https://www.sparknotes.com/lit/franklinautobio/summary/
# Summary for 1790 saved successfully.
# None
# Error: SparkNotes summary not found for Stability
# None
# Error: SparkNotes summary not found for Maturity
# None
# Error: SparkNotes summary not found for Burdensome
# None
# Error: SparkNotes summary not found for Indissoluble
# None
# Error: SparkNotes summary not found for Quarters
# None
# Error: SparkNotes summary not found for Thought
# https://www.sparknotes.com/lit/maze-runner/summary/
# Summary for Thomas saved successfully.
# https://www.sparknotes.com/lit/fever/summary/
# Summary for Above saved successfully.
# None
# Error: SparkNotes summary not found for Alter
# https://www.sparknotes.com/lit/invisibleman/summary/
# Summary for Indivisible saved successfully.
# None
# Error: SparkNotes summary not found for Warmth
# None
# Error: SparkNotes summary not found for Steadfast
# None
# Error: SparkNotes summary not found for Thirds
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Invoking saved successfully.
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Personal saved successfully.
# None
# Error: SparkNotes summary not found for Unbending
# None
# Error: SparkNotes summary not found for Pleasantness
# https://www.sparknotes.com/lit/plague/summary/
# Summary for Plagues saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Commitments saved successfully.
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Household saved successfully.
# None
# Error: SparkNotes summary not found for Lifetime
# https://www.sparknotes.com/lit/seize/summary/
# Summary for Seize saved successfully.
# None
# Error: SparkNotes summary not found for Threefold
# None
# Error: SparkNotes summary not found for Reverend
# https://www.sparknotes.com/lit/v-for-vendetta/summary/
# Summary for Reborn saved successfully.
# https://www.sparknotes.com/lit/lot49/summary/
# Summary for Lot saved successfully.
# https://www.sparknotes.com/lit/silas/summary/
# Summary for Mariners saved successfully.
# None
# Error: SparkNotes summary not found for Rewarding
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Considerately saved successfully.
# https://www.sparknotes.com/lit/gilgamesh/summary/
# Summary for Taxing saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Access saved successfully.
# None
# Error: SparkNotes summary not found for Compassion
# None
# Error: SparkNotes summary not found for Thoughtfully
# None
# Error: SparkNotes summary not found for Throng
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Goes saved successfully.
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Initiate saved successfully.
# None
# Error: SparkNotes summary not found for Comprise
# None
# Error: SparkNotes summary not found for Diversification
# None
# Error: SparkNotes summary not found for Pursuance
# https://www.sparknotes.com/lit/451/summary/
# Summary for Value saved successfully.
# None
# Error: SparkNotes summary not found for Negotiations
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Politics saved successfully.
# None
# Error: SparkNotes summary not found for Profits
# None
# Error: SparkNotes summary not found for Elevation
# None
# Error: SparkNotes summary not found for Committing
# None
# Error: SparkNotes summary not found for Tangible
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Pursue saved successfully.
# None
# Error: SparkNotes summary not found for Recognition
# https://www.sparknotes.com/lit/futureking/summary/
# Summary for King saved successfully.
# https://www.sparknotes.com/lit/oldtestament/summary/
# Summary for Holy saved successfully.
# None
# Error: SparkNotes summary not found for Talents
# https://www.sparknotes.com/lit/shabanu/summary/
# Summary for Bargain saved successfully.
# None
# Error: SparkNotes summary not found for Monumental
# https://www.sparknotes.com/lit/451/summary/
# Summary for Fiber saved successfully.
# None
# Error: SparkNotes summary not found for Cotton
# None
# Error: SparkNotes summary not found for Incapable
# https://www.sparknotes.com/lit/when-emperor-was-divine/summary/
# Summary for Divine saved successfully.
# https://www.sparknotes.com/lit/looking-for-alaska/summary/
# Summary for Look saved successfully.
# None
# Error: SparkNotes summary not found for Retained
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Enhance saved successfully.
# https://www.sparknotes.com/lit/lordjim/summary/
# Summary for Dishonorable saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Advance saved successfully.
# https://www.sparknotes.com/lit/there-there/summary/
# Summary for These saved successfully.
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Gigantic saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Healing saved successfully.
# None
# Error: SparkNotes summary not found for Behave
# None
# Error: SparkNotes summary not found for Abound
# None
# Error: SparkNotes summary not found for Faithfully
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Manufacturing saved successfully.
# None
# Error: SparkNotes summary not found for Changeless
# None
# Error: SparkNotes summary not found for Intentioned
# https://www.sparknotes.com/lit/americanah/summary/
# Summary for Americansâ saved successfully.
# None
# Error: SparkNotes summary not found for Juncture
# None
# Error: SparkNotes summary not found for Discontents
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Penalizes saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Inflict saved successfully.
# None
# Error: SparkNotes summary not found for Estimation
# None
# Error: SparkNotes summary not found for Invention
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Beloved saved successfully.
# None
# Error: SparkNotes summary not found for Values
# https://www.sparknotes.com/lit/jungle/summary/
# Summary for Jungles saved successfully.
# None
# Error: SparkNotes summary not found for Genius
# https://www.sparknotes.com/lit/eyes/summary/
# Summary for Shock saved successfully.
# None
# Error: SparkNotes summary not found for Draw
# None
# Error: SparkNotes summary not found for Encroaches
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Example saved successfully.
# https://www.sparknotes.com/lit/there-there/summary/
# Summary for Here saved successfully.
# None
# Error: SparkNotes summary not found for Discriminations
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Induces saved successfully.
# https://www.sparknotes.com/lit/call/summary/
# Summary for Carriers saved successfully.
# None
# Error: SparkNotes summary not found for Uniform
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Skill saved successfully.
# None
# Error: SparkNotes summary not found for Owe
# None
# Error: SparkNotes summary not found for Pernicious
# https://www.sparknotes.com/lit/wrinkle/summary/
# Summary for Timeâ saved successfully.
# https://www.sparknotes.com/lit/changes/summary/
# Summary for Polygamy saved successfully.
# None
# Error: SparkNotes summary not found for Multiplying
# None
# Error: SparkNotes summary not found for Wit
# None
# Error: SparkNotes summary not found for Finishing
# https://www.sparknotes.com/lit/seize/summary/
# Summary for Day saved successfully.
# None
# Error: SparkNotes summary not found for Mosque
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Supplying saved successfully.
# https://www.sparknotes.com/lit/amanforallseasons/summary/
# Summary for Cromwell saved successfully.
# None
# Error: SparkNotes summary not found for Scruple
# None
# Error: SparkNotes summary not found for Infusing
# https://www.sparknotes.com/lit/gawain/summary/
# Summary for Gallant saved successfully.
# None
# Error: SparkNotes summary not found for Satisfaction
# None
# Error: SparkNotes summary not found for Imminent
# None
# Error: SparkNotes summary not found for Canal
# None
# Error: SparkNotes summary not found for Retaliation
# None
# Error: SparkNotes summary not found for Godsend
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Humiliation saved successfully.
# None
# Error: SparkNotes summary not found for Knowing
# None
# Error: SparkNotes summary not found for Aboriginal
# https://www.sparknotes.com/lit/lake-of-the-woods/summary/
# Summary for Lakes saved successfully.
# None
# Error: SparkNotes summary not found for Three
# None
# Error: SparkNotes summary not found for Humiliating
# None
# Error: SparkNotes summary not found for Necessities
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Based saved successfully.
# None
# Error: SparkNotes summary not found for Kindly
# https://www.sparknotes.com/lit/hatchet/summary/
# Summary for Attack saved successfully.
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Saw saved successfully.
# None
# Error: SparkNotes summary not found for Friendship
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Neighborhood saved successfully.
# None
# Error: SparkNotes summary not found for Exterminating
# None
# Error: SparkNotes summary not found for Studiously
# None
# Error: SparkNotes summary not found for Corner
# https://www.sparknotes.com/lit/disgrace/summary/
# Summary for Shameful saved successfully.
# None
# Error: SparkNotes summary not found for Sundered
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Igniting saved successfully.
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Exciting saved successfully.
# None
# Error: SparkNotes summary not found for Volunteer
# https://www.sparknotes.com/lit/screwtape-letters/summary/
# Summary for Exploit saved successfully.
# None
# Error: SparkNotes summary not found for Infancy
# None
# Error: SparkNotes summary not found for Interest
# https://www.sparknotes.com/lit/potter3/summary/
# Summary for Prisoner saved successfully.
# https://www.sparknotes.com/lit/lolita/summary/
# Summary for Longings saved successfully.
# None
# Error: SparkNotes summary not found for Prepossessions
# None
# Error: SparkNotes summary not found for Undiminished
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Runs saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Clarified saved successfully.
# None
# Error: SparkNotes summary not found for Symptom
# https://www.sparknotes.com/lit/david-and-goliath/summary/
# Summary for Guaranties saved successfully.
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Vision saved successfully.
# None
# Error: SparkNotes summary not found for Residents
# None
# Error: SparkNotes summary not found for Habit
# None
# Error: SparkNotes summary not found for Realizing
# None
# Error: SparkNotes summary not found for Ratified
# None
# Error: SparkNotes summary not found for Readily
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Contentious saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Anniversary saved successfully.
# None
# Error: SparkNotes summary not found for Dishonor
# None
# Error: SparkNotes summary not found for Spasmodic
# None
# Error: SparkNotes summary not found for Approach
# None
# Error: SparkNotes summary not found for Adherence
# None
# Error: SparkNotes summary not found for Soundly
# https://www.sparknotes.com/lit/wonder/summary/
# Summary for Ears saved successfully.
# https://www.sparknotes.com/lit/chains/summary/
# Summary for Schemes saved successfully.
# None
# Error: SparkNotes summary not found for Consume
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Hard saved successfully.
# https://www.sparknotes.com/lit/a-court-of-thorns-and-roses/summary/
# Summary for Courts saved successfully.
# https://www.sparknotes.com/lit/animalfarm/summary/
# Summary for Unquestionable saved successfully.
# None
# Error: SparkNotes summary not found for Superiors
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for South saved successfully.
# None
# Error: SparkNotes summary not found for Domination
# None
# Error: SparkNotes summary not found for Vow
# None
# Error: SparkNotes summary not found for Substitutes
# https://www.sparknotes.com/lit/montecristo/summary/
# Summary for Cost saved successfully.
# None
# Error: SparkNotes summary not found for Continue
# None
# Error: SparkNotes summary not found for Limit
# None
# Error: SparkNotes summary not found for Occupation
# None
# Error: SparkNotes summary not found for Sympathetic
# https://www.sparknotes.com/lit/nisa/summary/
# Summary for Estimated saved successfully.
# None
# Error: SparkNotes summary not found for Contests
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Lost saved successfully.
# None
# Error: SparkNotes summary not found for Anticipating
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Simplify saved successfully.
# None
# Error: SparkNotes summary not found for Elder
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Information saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Acquired saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Intangible saved successfully.
# None
# Error: SparkNotes summary not found for Distance
# None
# Error: SparkNotes summary not found for 30th
# None
# Error: SparkNotes summary not found for Responses
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Lessons saved successfully.
# None
# Error: SparkNotes summary not found for Tongues
# https://www.sparknotes.com/lit/medea/summary/
# Summary for Drastically saved successfully.
# None
# Error: SparkNotes summary not found for Thirdly
# None
# Error: SparkNotes summary not found for Suggested
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Upon saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Expand saved successfully.
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Times saved successfully.
# None
# Error: SparkNotes summary not found for Evinced
# None
# Error: SparkNotes summary not found for Examine
# None
# Error: SparkNotes summary not found for Inequality
# https://www.sparknotes.com/lit/do-androids-dream-of-electric-sheep/summary/
# Summary for Bounties saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for T saved successfully.
# None
# Error: SparkNotes summary not found for Emphatically
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Escapes saved successfully.
# None
# Error: SparkNotes summary not found for Revolutionary
# None
# Error: SparkNotes summary not found for Aim
# None
# Error: SparkNotes summary not found for Propitious
# https://www.sparknotes.com/lit/carrie/summary/
# Summary for Carries saved successfully.
# None
# Error: SparkNotes summary not found for Prevalence
# https://www.sparknotes.com/lit/childofthedark/summary/
# Summary for Child saved successfully.
# https://www.sparknotes.com/lit/childhoodsend/summary/
# Summary for Aliens saved successfully.
# None
# Error: SparkNotes summary not found for Patrol
# None
# Error: SparkNotes summary not found for Hold
# None
# Error: SparkNotes summary not found for Breast
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Achieved saved successfully.
# None
# Error: SparkNotes summary not found for Degenerate
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Reference saved successfully.
# None
# Error: SparkNotes summary not found for Abstain
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Relation saved successfully.
# None
# Error: SparkNotes summary not found for Guadalcanal
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Beneficent saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Firmest saved successfully.
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Old saved successfully.
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Boat saved successfully.
# None
# Error: SparkNotes summary not found for Unanimity
# https://www.sparknotes.com/lit/bend-in-the-river/summary/
# Summary for Domain saved successfully.
# None
# Error: SparkNotes summary not found for Regard
# None
# Error: SparkNotes summary not found for Gloomy
# https://www.sparknotes.com/lit/afraidofwoolf/summary/
# Summary for Fears saved successfully.
# None
# Error: SparkNotes summary not found for Depend
# None
# Error: SparkNotes summary not found for Decision
# https://www.sparknotes.com/lit/the-fault-in-our-stars/summary/
# Summary for Affliction saved successfully.
# None
# Error: SparkNotes summary not found for Final
# None
# Error: SparkNotes summary not found for Commissions
# None
# Error: SparkNotes summary not found for Bound
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Discover saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Useful saved successfully.
# https://www.sparknotes.com/lit/a-game-of-thrones/summary/
# Summary for Thrones saved successfully.
# https://www.sparknotes.com/lit/harrypotter5/summary/
# Summary for Order saved successfully.
# https://www.sparknotes.com/lit/frankenstein/summary/
# Summary for Specter saved successfully.
# None
# Error: SparkNotes summary not found for Measures
# None
# Error: SparkNotes summary not found for Able
# None
# Error: SparkNotes summary not found for Arbitration
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for His saved successfully.
# None
# Error: SparkNotes summary not found for Formidable
# None
# Error: SparkNotes summary not found for Seats
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Measurable saved successfully.
# https://www.sparknotes.com/lit/fountainhead/summary/
# Summary for Fountain saved successfully.
# None
# Error: SparkNotes summary not found for Platforms
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Portion saved successfully.
# None
# Error: SparkNotes summary not found for Directed
# None
# Error: SparkNotes summary not found for Armies
# None
# Error: SparkNotes summary not found for Renounced
# None
# Error: SparkNotes summary not found for Implore
# None
# Error: SparkNotes summary not found for Altar
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Week saved successfully.
# None
# Error: SparkNotes summary not found for Price
# None
# Error: SparkNotes summary not found for Traces
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Vital saved successfully.
# https://www.sparknotes.com/lit/separate/summary/
# Summary for Calmness saved successfully.
# https://www.sparknotes.com/lit/emma/summary/
# Summary for 1815 saved successfully.
# https://www.sparknotes.com/lit/verity/summary/
# Summary for Fitted saved successfully.
# https://www.sparknotes.com/lit/20000-leagues-under-the-sea/summary/
# Summary for League saved successfully.
# https://www.sparknotes.com/lit/malcolmx/summary/
# Summary for Xa saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Colonists saved successfully.
# None
# Error: SparkNotes summary not found for Investigations
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for What saved successfully.
# None
# Error: SparkNotes summary not found for Christs
# None
# Error: SparkNotes summary not found for Palliation
# None
# Error: SparkNotes summary not found for Factor
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Contemplation saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Manage saved successfully.
# None
# Error: SparkNotes summary not found for Emergency
# https://www.sparknotes.com/lit/havingoursay/summary/
# Summary for Having saved successfully.
# None
# Error: SparkNotes summary not found for Administrators
# None
# Error: SparkNotes summary not found for Civilized
# https://www.sparknotes.com/lit/nickel-boys/summary/
# Summary for Encyclopedia saved successfully.
# None
# Error: SparkNotes summary not found for Implies
# https://www.sparknotes.com/lit/invisibleman/summary/
# Summary for Comprehensively saved successfully.
# None
# Error: SparkNotes summary not found for Spokesmen
# https://www.sparknotes.com/lit/gonewith/summary/
# Summary for Went saved successfully.
# None
# Error: SparkNotes summary not found for Characteristic
# None
# Error: SparkNotes summary not found for Visit
# None
# Error: SparkNotes summary not found for Enlarge
# None
# Error: SparkNotes summary not found for Untrue
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Advocates saved successfully.
# None
# Error: SparkNotes summary not found for Especially
# https://www.sparknotes.com/lit/a-tale-of-two-cities/summary/
# Summary for Cities saved successfully.
# None
# Error: SparkNotes summary not found for Contribution
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Regulating saved successfully.
# https://www.sparknotes.com/lit/memberwedding/summary/
# Summary for Member saved successfully.
# https://www.sparknotes.com/lit/animaldreams/summary/
# Summary for Dreams saved successfully.
# https://www.sparknotes.com/lit/betweentheworld/summary/
# Summary for Between saved successfully.
# None
# Error: SparkNotes summary not found for Refunding
# None
# Error: SparkNotes summary not found for Contended
# https://www.sparknotes.com/lit/souls-of-black-folk/summary/
# Summary for Effects saved successfully.
# None
# Error: SparkNotes summary not found for Ineffectual
# None
# Error: SparkNotes summary not found for Eve
# https://www.sparknotes.com/lit/eastofeden/summary/
# Summary for Furtherance saved successfully.
# None
# Error: SparkNotes summary not found for Pardoned
# None
# Error: SparkNotes summary not found for Mayflower
# None
# Error: SparkNotes summary not found for Shaking
# None
# Error: SparkNotes summary not found for Mortifications
# https://www.sparknotes.com/lit/gilgamesh/summary/
# Summary for Prelude saved successfully.
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Energy saved successfully.
# None
# Error: SparkNotes summary not found for Ill
# https://www.sparknotes.com/lit/the-midnight-library/summary/
# Summary for Regretted saved successfully.
# None
# Error: SparkNotes summary not found for Conscientiously
# None
# Error: SparkNotes summary not found for Weaken
# https://www.sparknotes.com/lit/bluesteye/summary/
# Summary for Cherishes saved successfully.
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Adds saved successfully.
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Prolonged saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Reflections saved successfully.
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Contemplations saved successfully.
# None
# Error: SparkNotes summary not found for Creed
# None
# Error: SparkNotes summary not found for Boundless
# None
# Error: SparkNotes summary not found for Compromise
# None
# Error: SparkNotes summary not found for Extricate
# https://www.sparknotes.com/lit/exit-west/summary/
# Summary for West saved successfully.
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Referred saved successfully.
# https://www.sparknotes.com/lit/treasure/summary/
# Summary for Treasure saved successfully.
# None
# Error: SparkNotes summary not found for Protector
# None
# Error: SparkNotes summary not found for Special
# None
# Error: SparkNotes summary not found for Unhappy
# None
# Error: SparkNotes summary not found for Transcendent
# None
# Error: SparkNotes summary not found for Principal
# None
# Error: SparkNotes summary not found for Mischief
# None
# Error: SparkNotes summary not found for Shining
# None
# Error: SparkNotes summary not found for Congenial
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Resorting saved successfully.
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for Devised saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Contention saved successfully.
# None
# Error: SparkNotes summary not found for Position
# None
# Error: SparkNotes summary not found for Clarify
# None
# Error: SparkNotes summary not found for Lawfully
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Deprivation saved successfully.
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Complete saved successfully.
# None
# Error: SparkNotes summary not found for Courageously
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Much saved successfully.
# None
# Error: SparkNotes summary not found for Arresting
# https://www.sparknotes.com/lit/secondsex/summary/
# Summary for Situation saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Document saved successfully.
# https://www.sparknotes.com/lit/way-to-rainy-mountain/summary/
# Summary for Forebears saved successfully.
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Lawless saved successfully.
# https://www.sparknotes.com/lit/elegantuniverse/summary/
# Summary for Gravity saved successfully.
# None
# Error: SparkNotes summary not found for Tutor
# None
# Error: SparkNotes summary not found for Blotches
# None
# Error: SparkNotes summary not found for Tormented
# https://www.sparknotes.com/lit/the-westing-game/summary/
# Summary for Heirs saved successfully.
# None
# Error: SparkNotes summary not found for Battlefields
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Pass saved successfully.
# None
# Error: SparkNotes summary not found for Invitations
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Recommending saved successfully.
# https://www.sparknotes.com/lit/johnnygun/summary/
# Summary for Decency saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Weigh saved successfully.
# None
# Error: SparkNotes summary not found for Otherwise
# https://www.sparknotes.com/lit/metamorph/summary/
# Summary for Sweeping saved successfully.
# https://www.sparknotes.com/lit/billybudd/summary/
# Summary for Solicitation saved successfully.
# None
# Error: SparkNotes summary not found for Preyed
# https://www.sparknotes.com/lit/eastofeden/summary/
# Summary for Settled saved successfully.
# None
# Error: SparkNotes summary not found for Rectified
# https://www.sparknotes.com/lit/dubliners/summary/
# Summary for Procured saved successfully.
# None
# Error: SparkNotes summary not found for Injured
# None
# Error: SparkNotes summary not found for Parent
# None
# Error: SparkNotes summary not found for Warren
# https://www.sparknotes.com/lit/long-walk-to-water/summary/
# Summary for Walk saved successfully.
# None
# Error: SparkNotes summary not found for Tolerated
# https://www.sparknotes.com/lit/ulysses/summary/
# Summary for Office saved successfully.
# None
# Error: SparkNotes summary not found for Halted
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Representations saved successfully.
# None
# Error: SparkNotes summary not found for Unaided
# None
# Error: SparkNotes summary not found for Revitalize
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Long saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Domiciled saved successfully.
# None
# Error: SparkNotes summary not found for Drifting
# https://www.sparknotes.com/lit/sounder/summary/
# Summary for Termination saved successfully.
# None
# Error: SparkNotes summary not found for Gifts
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Elsewhere saved successfully.
# None
# Error: SparkNotes summary not found for Saps
# None
# Error: SparkNotes summary not found for Ragged
# None
# Error: SparkNotes summary not found for Encountered
# https://www.sparknotes.com/lit/451/summary/
# Summary for Degrees saved successfully.
# https://www.sparknotes.com/lit/joyluck/summary/
# Summary for Partially saved successfully.
# None
# Error: SparkNotes summary not found for Tenure
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Moment saved successfully.
# https://www.sparknotes.com/lit/blacklikeme/summary/
# Summary for Like saved successfully.
# https://www.sparknotes.com/lit/murder-of-roger-ackroyd/summary/
# Summary for Murder saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Professions saved successfully.
# https://www.sparknotes.com/lit/all-the-light/summary/
# Summary for Find saved successfully.
# https://www.sparknotes.com/lit/they-both-die-at-the-end/summary/
# Summary for Dies saved successfully.
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for Intends saved successfully.
# None
# Error: SparkNotes summary not found for Rejecting
# None
# Error: SparkNotes summary not found for Dignified
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Halfway saved successfully.
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Qualified saved successfully.
# https://www.sparknotes.com/lit/noexit/summary/
# Summary for No saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Repeating saved successfully.
# None
# Error: SparkNotes summary not found for Hypercritical
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Oar saved successfully.
# None
# Error: SparkNotes summary not found for Conspiracies
# None
# Error: SparkNotes summary not found for Trusted
# None
# Error: SparkNotes summary not found for Servant
# None
# Error: SparkNotes summary not found for Symbol
# None
# Error: SparkNotes summary not found for Yourself
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for Its saved successfully.
# None
# Error: SparkNotes summary not found for Uninspiring
# None
# Error: SparkNotes summary not found for Reflects
# https://www.sparknotes.com/lit/puddnhead/summary/
# Summary for Putting saved successfully.
# None
# Error: SparkNotes summary not found for Avoid
# None
# Error: SparkNotes summary not found for Nixon
# None
# Error: SparkNotes summary not found for Welfare
# None
# Error: SparkNotes summary not found for Reestablish
# None
# Error: SparkNotes summary not found for Shape
# https://www.sparknotes.com/lit/poisonwood/summary/
# Summary for Footprints saved successfully.
# None
# Error: SparkNotes summary not found for Meant
# None
# Error: SparkNotes summary not found for Concentration
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Usefulness saved successfully.
# None
# Error: SparkNotes summary not found for Compact
# https://www.sparknotes.com/lit/purple/summary/
# Summary for Colorable saved successfully.
# None
# Error: SparkNotes summary not found for Terrifying
# https://www.sparknotes.com/lit/frankenstein/summary/
# Summary for Modern saved successfully.
# None
# Error: SparkNotes summary not found for Unwasted
# None
# Error: SparkNotes summary not found for Questioned
# None
# Error: SparkNotes summary not found for Solemn
# https://www.sparknotes.com/lit/fellowship/summary/
# Summary for Fellowship saved successfully.
# None
# Error: SparkNotes summary not found for Protecting
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Human saved successfully.
# https://www.sparknotes.com/lit/persuasion/summary/
# Summary for Persuasion saved successfully.
# None
# Error: SparkNotes summary not found for Uneconomical
# None
# Error: SparkNotes summary not found for Sober
# None
# Error: SparkNotes summary not found for Immutable
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for As saved successfully.
# None
# Error: SparkNotes summary not found for Creator
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Obtained saved successfully.
# None
# Error: SparkNotes summary not found for Fog
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Evident saved successfully.
# https://www.sparknotes.com/lit/the-perks-of-being-a-wallflower/summary/
# Summary for Thoughtful saved successfully.
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Inadequate saved successfully.
# None
# Error: SparkNotes summary not found for Weightiest
# https://www.sparknotes.com/lit/chains/summary/
# Summary for Locks saved successfully.
# None
# Error: SparkNotes summary not found for Prohibitions
# None
# Error: SparkNotes summary not found for Motion
# None
# Error: SparkNotes summary not found for Regional
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Misconstrued saved successfully.
# https://www.sparknotes.com/lit/they-both-die-at-the-end/summary/
# Summary for Both saved successfully.
# https://www.sparknotes.com/lit/redblack/summary/
# Summary for Red saved successfully.
# None
# Error: SparkNotes summary not found for Dynamos
# https://www.sparknotes.com/lit/the-perks-of-being-a-wallflower/summary/
# Summary for Allocating saved successfully.
# None
# Error: SparkNotes summary not found for Sixty
# None
# Error: SparkNotes summary not found for Plenty
# None
# Error: SparkNotes summary not found for Merited
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Bad saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Earnest saved successfully.
# None
# Error: SparkNotes summary not found for Timidity
# None
# Error: SparkNotes summary not found for Stubbornness
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Drive saved successfully.
# None
# Error: SparkNotes summary not found for Oaths
# None
# Error: SparkNotes summary not found for Entity
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Book saved successfully.
# None
# Error: SparkNotes summary not found for Resentments
# None
# Error: SparkNotes summary not found for Callous
# None
# Error: SparkNotes summary not found for Thou
# None
# Error: SparkNotes summary not found for Sixth
# None
# Error: SparkNotes summary not found for Arbitrary
# None
# Error: SparkNotes summary not found for 15th
# None
# Error: SparkNotes summary not found for Colossal
# None
# Error: SparkNotes summary not found for Essential
# None
# Error: SparkNotes summary not found for Deserves
# None
# Error: SparkNotes summary not found for Disobedience
# None
# Error: SparkNotes summary not found for Official
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Arrive saved successfully.
# None
# Error: SparkNotes summary not found for Massacre
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Common saved successfully.
# https://www.sparknotes.com/lit/lightforest/summary/
# Summary for Forest saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Earn saved successfully.
# None
# Error: SparkNotes summary not found for Laboring
# None
# Error: SparkNotes summary not found for May
# None
# Error: SparkNotes summary not found for Daring
# None
# Error: SparkNotes summary not found for Asunder
# None
# Error: SparkNotes summary not found for Robes
# https://www.sparknotes.com/lit/the-city-of-ember/summary/
# Summary for Instructions saved successfully.
# None
# Error: SparkNotes summary not found for Grief
# None
# Error: SparkNotes summary not found for Appreciation
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Police saved successfully.
# None
# Error: SparkNotes summary not found for Needs
# None
# Error: SparkNotes summary not found for Fanatical
# None
# Error: SparkNotes summary not found for Affections
# None
# Error: SparkNotes summary not found for Downfall
# None
# Error: SparkNotes summary not found for Square
# None
# Error: SparkNotes summary not found for Formulation
# None
# Error: SparkNotes summary not found for Undertone
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Indispensably saved successfully.
# None
# Error: SparkNotes summary not found for Polite
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Advocate saved successfully.
# https://www.sparknotes.com/lit/born-a-crime/summary/
# Summary for Mixed saved successfully.
# https://www.sparknotes.com/lit/homegoing/summary/
# Summary for Village saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Swollen saved successfully.
# None
# Error: SparkNotes summary not found for Parent
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Youthful saved successfully.
# https://www.sparknotes.com/lit/stranger/summary/
# Summary for Slowly saved successfully.
# https://www.sparknotes.com/lit/we-were-liars/summary/
# Summary for Inured saved successfully.
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Conventions saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Confronts saved successfully.
# None
# Error: SparkNotes summary not found for Sometimes
# https://www.sparknotes.com/lit/slaughter/summary/
# Summary for Suffers saved successfully.
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Demonstrations saved successfully.
# None
# Error: SparkNotes summary not found for Sacredly
# None
# Error: SparkNotes summary not found for Aspiration
# None
# Error: SparkNotes summary not found for Magna
# None
# Error: SparkNotes summary not found for Rash
# None
# Error: SparkNotes summary not found for Prerequisites
# https://www.sparknotes.com/lit/waves/summary/
# Summary for Stimulus saved successfully.
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Annexed saved successfully.
# None
# Error: SparkNotes summary not found for Equitably
# None
# Error: SparkNotes summary not found for Gillis
# None
# Error: SparkNotes summary not found for Predilection
# None
# Error: SparkNotes summary not found for Augmentation
# None
# Error: SparkNotes summary not found for Salerno
# None
# Error: SparkNotes summary not found for Chiefly
# None
# Error: SparkNotes summary not found for Disciples
# None
# Error: SparkNotes summary not found for Surpluses
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Spot saved successfully.
# https://www.sparknotes.com/lit/bend-in-the-river/summary/
# Summary for Vindicated saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Revered saved successfully.
# https://www.sparknotes.com/lit/into-the-wild/summary/
# Summary for Embark saved successfully.
# None
# Error: SparkNotes summary not found for Discretion
# None
# Error: SparkNotes summary not found for Determination
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Financing saved successfully.
# None
# Error: SparkNotes summary not found for Perseverance
# None
# Error: SparkNotes summary not found for Loyalty
# None
# Error: SparkNotes summary not found for Forbearing
# None
# Error: SparkNotes summary not found for Mother
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Apology saved successfully.
# None
# Error: SparkNotes summary not found for Navigable
# None
# Error: SparkNotes summary not found for Manufactures
# None
# Error: SparkNotes summary not found for Bare
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Crushes saved successfully.
# None
# Error: SparkNotes summary not found for Consoling
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Work saved successfully.
# None
# Error: SparkNotes summary not found for Insistence
# https://www.sparknotes.com/lit/frankenstein/summary/
# Summary for Eloquence saved successfully.
# https://www.sparknotes.com/lit/beowulf/summary/
# Summary for Reign saved successfully.
# None
# Error: SparkNotes summary not found for Sacredly
# None
# Error: SparkNotes summary not found for Par
# None
# Error: SparkNotes summary not found for Signs
# https://www.sparknotes.com/lit/david-and-goliath/summary/
# Summary for Limits saved successfully.
# None
# Error: SparkNotes summary not found for Sympathize
# None
# Error: SparkNotes summary not found for Tire
# https://www.sparknotes.com/lit/long-walk-to-water/summary/
# Summary for Well saved successfully.
# None
# Error: SparkNotes summary not found for Dangerously
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Statute saved successfully.
# https://www.sparknotes.com/lit/nativeson/summary/
# Summary for Philanthropist saved successfully.
# None
# Error: SparkNotes summary not found for Expeditious
# None
# Error: SparkNotes summary not found for Cut
# None
# Error: SparkNotes summary not found for Unessential
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Deep saved successfully.
# https://www.sparknotes.com/lit/leave-the-world-behind/summary/
# Summary for Leave saved successfully.
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Schools saved successfully.
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Proposed saved successfully.
# https://www.sparknotes.com/lit/joyluck/summary/
# Summary for Impartially saved successfully.
# None
# Error: SparkNotes summary not found for Aver
# None
# Error: SparkNotes summary not found for Billows
# None
# Error: SparkNotes summary not found for Sentiments
# None
# Error: SparkNotes summary not found for Forging
# https://www.sparknotes.com/lit/robin-hood/summary/
# Summary for Outlaw saved successfully.
# None
# Error: SparkNotes summary not found for Yourselves
# https://www.sparknotes.com/lit/dangerous/summary/
# Summary for Danger saved successfully.
# None
# Error: SparkNotes summary not found for Unchanged
# https://www.sparknotes.com/lit/night/summary/
# Summary for Evening saved successfully.
# https://www.sparknotes.com/lit/station-eleven/summary/
# Summary for 11 saved successfully.
# None
# Error: SparkNotes summary not found for Chair
# https://www.sparknotes.com/lit/silas/summary/
# Summary for Hoards saved successfully.
# https://www.sparknotes.com/lit/origin/summary/
# Summary for Mechanism saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Treading saved successfully.
# None
# Error: SparkNotes summary not found for Lawgivers
# None
# Error: SparkNotes summary not found for Fund
# None
# Error: SparkNotes summary not found for Availability
# None
# Error: SparkNotes summary not found for Aggression
# None
# Error: SparkNotes summary not found for Sends
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Pres saved successfully.
# None
# Error: SparkNotes summary not found for Contest
# None
# Error: SparkNotes summary not found for Reveal
# None
# Error: SparkNotes summary not found for Robe
# None
# Error: SparkNotes summary not found for Extenuating
# https://www.sparknotes.com/lit/giver/summary/
# Summary for About saved successfully.
# None
# Error: SparkNotes summary not found for Archibald
# https://www.sparknotes.com/lit/unbroken/summary/
# Summary for Unbroken saved successfully.
# None
# Error: SparkNotes summary not found for Monticello
# None
# Error: SparkNotes summary not found for Decay
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Perpetual saved successfully.
# https://www.sparknotes.com/lit/princessbride/summary/
# Summary for Dread saved successfully.
# None
# Error: SparkNotes summary not found for Steady
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Devotion saved successfully.
# None
# Error: SparkNotes summary not found for Unceasingly
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for Finally saved successfully.
# https://www.sparknotes.com/lit/sargasso/summary/
# Summary for Wide saved successfully.
# https://www.sparknotes.com/lit/littleprince/summary/
# Summary for Prince saved successfully.
# None
# Error: SparkNotes summary not found for Hopefulness
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Provide saved successfully.
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Bottoms saved successfully.
# None
# Error: SparkNotes summary not found for Departments
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Registered saved successfully.
# None
# Error: SparkNotes summary not found for Manifestly
# https://www.sparknotes.com/lit/godot/summary/
# Summary for Auspicious saved successfully.
# https://www.sparknotes.com/lit/betweentheworld/summary/
# Summary for Xand saved successfully.
# https://www.sparknotes.com/lit/orientexpress/summary/
# Summary for Express saved successfully.
# None
# Error: SparkNotes summary not found for Reality
# None
# Error: SparkNotes summary not found for Memorial
# https://www.sparknotes.com/lit/narrative/summary/
# Summary for Freer saved successfully.
# https://www.sparknotes.com/lit/where-the-crawdads-sing/summary/
# Summary for Where saved successfully.
# https://www.sparknotes.com/lit/godot/summary/
# Summary for Hoping saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Profess saved successfully.
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Polls saved successfully.
# None
# Error: SparkNotes summary not found for Disbursed
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for California saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Borrowing saved successfully.
# None
# Error: SparkNotes summary not found for Mediation
# None
# Error: SparkNotes summary not found for Delight
# None
# Error: SparkNotes summary not found for Crafty
# None
# Error: SparkNotes summary not found for Speed
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Sanctimonious saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Believes saved successfully.
# None
# Error: SparkNotes summary not found for Tarawa
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Successful saved successfully.
# None
# Error: SparkNotes summary not found for 1941
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Ranks saved successfully.
# https://www.sparknotes.com/lit/everything-i-never-told-you/summary/
# Summary for You saved successfully.
# Summary for You already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Evacuation
# https://www.sparknotes.com/lit/sovereignty/summary/
# Summary for Abode saved successfully.
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Crave saved successfully.
# https://www.sparknotes.com/lit/candide/summary/
# Summary for Contracted saved successfully.
# None
# Error: SparkNotes summary not found for Seeds
# None
# Error: SparkNotes summary not found for Decisions
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Declaration saved successfully.
# None
# Error: SparkNotes summary not found for Instinct
# None
# Error: SparkNotes summary not found for Equipped
# None
# Error: SparkNotes summary not found for Scabbard
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Honesty saved successfully.
# None
# Error: SparkNotes summary not found for Accomplished
# https://www.sparknotes.com/lit/a-tale-of-two-cities/summary/
# Summary for Pledging saved successfully.
# https://www.sparknotes.com/lit/mollflanders/summary/
# Summary for Mall saved successfully.
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Lower saved successfully.
# None
# Error: SparkNotes summary not found for Conclusion
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for Devise saved successfully.
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Proposals saved successfully.
# https://www.sparknotes.com/lit/stranger/summary/
# Summary for Correctly saved successfully.
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Approving saved successfully.
# None
# ...
# Summary for Animated saved successfully.
# None
# Error: SparkNotes summary not found for Hurricanes
# None
# Error: SparkNotes summary not found for Pelosi
# None
# Error: SparkNotes summary not found for Postwar
# None
# Error: SparkNotes summary not found for Secondary
# None
# Error: SparkNotes summary not found for Streams
# None
# Error: SparkNotes summary not found for Delusions
# None
# Error: SparkNotes summary not found for Contemplating
# https://www.sparknotes.com/lit/greatex/summary/
# Summary for Revenue saved successfully.
# https://www.sparknotes.com/lit/david-and-goliath/summary/
# Summary for Densely saved successfully.
# https://www.sparknotes.com/lit/sensibility/summary/
# Summary for Squandered saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Conviction saved successfully.
# None
# Error: SparkNotes summary not found for Sights
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Located saved successfully.
# None
# Error: SparkNotes summary not found for Sanguine
# None
# Error: SparkNotes summary not found for Inviting
# None
# Error: SparkNotes summary not found for Plenty
# https://www.sparknotes.com/lit/go-set-a-watchman/summary/
# Summary for Watchman saved successfully.
# https://www.sparknotes.com/lit/solitude/summary/
# Summary for Ceaseless saved successfully.
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Good saved successfully.
# None
# Error: SparkNotes summary not found for Florida
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Criminal saved successfully.
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Hardest saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Indispensable saved successfully.
# https://www.sparknotes.com/lit/siddhartha/summary/
# Summary for Searching saved successfully.
# None
# Error: SparkNotes summary not found for Unvexed
# None
# Error: SparkNotes summary not found for Oppression
# None
# Error: SparkNotes summary not found for Local
# None
# Error: SparkNotes summary not found for Retrace
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Dignifies saved successfully.
# None
# Error: SparkNotes summary not found for Enlist
# https://www.sparknotes.com/lit/englishpatient/summary/
# Summary for English saved successfully.
# None
# Error: SparkNotes summary not found for Hero
# https://www.sparknotes.com/lit/ordinarypeople/summary/
# Summary for Individuals saved successfully.
# None
# Error: SparkNotes summary not found for Careless
# None
# Error: SparkNotes summary not found for Evince
# None
# Error: SparkNotes summary not found for Cruising
# None
# Error: SparkNotes summary not found for Unleashed
# https://www.sparknotes.com/lit/jekyll/summary/
# Summary for 1886 saved successfully.
# None
# Error: SparkNotes summary not found for Discernment
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for Please saved successfully.
# None
# Error: SparkNotes summary not found for Antifederal
# None
# Error: SparkNotes summary not found for Prevented
# https://www.sparknotes.com/lit/adambede/summary/
# Summary for Adams saved successfully.
# None
# Error: SparkNotes summary not found for Transcending
# https://www.sparknotes.com/lit/frome/summary/
# Summary for From saved successfully.
# None
# Error: SparkNotes summary not found for Britannic
# None
# Error: SparkNotes summary not found for Enhanced
# None
# Error: SparkNotes summary not found for Phase
# https://www.sparknotes.com/lit/the-fault-in-our-stars/summary/
# Summary for Faults saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Drama saved successfully.
# None
# Error: SparkNotes summary not found for Cars
# None
# Error: SparkNotes summary not found for Dispositions
# None
# Error: SparkNotes summary not found for Restated
# https://www.sparknotes.com/lit/futureking/summary/
# Summary for Once saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Colonial saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Begun saved successfully.
# https://www.sparknotes.com/lit/sensibility/summary/
# Summary for Sensitive saved successfully.
# None
# Error: SparkNotes summary not found for Shopkeepers
# None
# Error: SparkNotes summary not found for Stipulated
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Induced saved successfully.
# None
# Error: SparkNotes summary not found for Exchanges
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Invading saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Govern saved successfully.
# None
# Error: SparkNotes summary not found for Recreation
# None
# Error: SparkNotes summary not found for Assisted
# https://www.sparknotes.com/lit/gonewith/summary/
# Summary for Winds saved successfully.
# None
# Error: SparkNotes summary not found for Stamp
# https://www.sparknotes.com/lit/kindred/summary/
# Summary for Kindred saved successfully.
# None
# Error: SparkNotes summary not found for Administrated
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Floridas saved successfully.
# None
# Error: SparkNotes summary not found for Dogmatic
# None
# Error: SparkNotes summary not found for Possesses
# None
# Error: SparkNotes summary not found for Removals
# https://www.sparknotes.com/lit/fever/summary/
# Summary for Cook saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Satisfying saved successfully.
# None
# Error: SparkNotes summary not found for Realized
# https://www.sparknotes.com/lit/souls-of-black-folk/summary/
# Summary for Folks saved successfully.
# None
# Error: SparkNotes summary not found for Espouse
# https://www.sparknotes.com/lit/medea/summary/
# Summary for Famed saved successfully.
# None
# Error: SparkNotes summary not found for Avenues
# None
# Error: SparkNotes summary not found for Superintendent
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Fisheries saved successfully.
# None
# Error: SparkNotes summary not found for Inlets
# None
# Error: SparkNotes summary not found for Willing
# None
# Error: SparkNotes summary not found for Healthy
# https://www.sparknotes.com/lit/orientexpress/summary/
# Summary for Orient saved successfully.
# None
# Error: SparkNotes summary not found for Continuing
# https://www.sparknotes.com/lit/goaskalice/summary/
# Summary for Residue saved successfully.
# None
# Error: SparkNotes summary not found for Misrepresentation
# https://www.sparknotes.com/lit/ordinarypeople/summary/
# Summary for Usual saved successfully.
# None
# Error: SparkNotes summary not found for Hearers
# https://www.sparknotes.com/lit/jekyll/summary/
# Summary for Eminently saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Conceiving saved successfully.
# https://www.sparknotes.com/lit/antonia/summary/
# Summary for My saved successfully.
# https://www.sparknotes.com/lit/walden2/summary/
# Summary for Feasibility saved successfully.
# None
# Error: SparkNotes summary not found for Consideration
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Blaze saved successfully.
# None
# Error: SparkNotes summary not found for Presidential
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Midst saved successfully.
# None
# Error: SparkNotes summary not found for Unquestioning
# None
# Error: SparkNotes summary not found for Channel
# https://www.sparknotes.com/lit/portraitartist/summary/
# Summary for Arts saved successfully.
# https://www.sparknotes.com/lit/sun/summary/
# Summary for Sunlight saved successfully.
# https://www.sparknotes.com/lit/trial/summary/
# Summary for Court saved successfully.
# https://www.sparknotes.com/lit/tristram/summary/
# Summary for Volume saved successfully.
# https://www.sparknotes.com/lit/siddhartha/summary/
# Summary for Flows saved successfully.
# https://www.sparknotes.com/lit/the-canterbury-tales/summary/
# Summary for Forbear saved successfully.
# None
# Error: SparkNotes summary not found for Irresponsible
# None
# Error: SparkNotes summary not found for Supplanted
# https://www.sparknotes.com/lit/pointzero/summary/
# Summary for Prostitutes saved successfully.
# https://www.sparknotes.com/lit/oldtestament/summary/
# Summary for Covenants saved successfully.
# None
# Error: SparkNotes summary not found for Instrumentalities
# None
# Error: SparkNotes summary not found for Porch
# https://www.sparknotes.com/lit/thousand-splendid-suns/summary/
# Summary for Suns saved successfully.
# https://www.sparknotes.com/lit/lightning-thief/summary/
# Summary for Lightening saved successfully.
# None
# Error: SparkNotes summary not found for Michael
# https://www.sparknotes.com/lit/goodsoldier/summary/
# Summary for Respectable saved successfully.
# https://www.sparknotes.com/lit/enemyofthepeople/summary/
# Summary for Enemies saved successfully.
# None
# Error: SparkNotes summary not found for Wreckage
# None
# Error: SparkNotes summary not found for Outset
# None
# Error: SparkNotes summary not found for Whip
# https://www.sparknotes.com/lit/elegantuniverse/summary/
# Summary for Physicists saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Burns saved successfully.
# None
# Error: SparkNotes summary not found for Opening
# None
# Error: SparkNotes summary not found for Contemplated
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Disciplined saved successfully.
# https://www.sparknotes.com/lit/harrypotter5/summary/
# Summary for Ordered saved successfully.
# None
# Error: SparkNotes summary not found for Mad
# https://www.sparknotes.com/lit/midnightschildren/summary/
# Summary for Children saved successfully.
# None
# Error: SparkNotes summary not found for Welcome
# None
# Error: SparkNotes summary not found for Confessedly
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Incomes saved successfully.
# None
# Error: SparkNotes summary not found for Stamina
# None
# Error: SparkNotes summary not found for Essentially
# https://www.sparknotes.com/lit/night/summary/
# Summary for Night saved successfully.
# https://www.sparknotes.com/lit/a-worn-path/summary/
# Summary for Paths saved successfully.
# None
# Error: SparkNotes summary not found for Humanize
# https://www.sparknotes.com/lit/separate/summary/
# Summary for Peaceful saved successfully.
# None
# Error: SparkNotes summary not found for Moderation
# https://www.sparknotes.com/lit/immortal-life/summary/
# Summary for Markers saved successfully.
# None
# Error: SparkNotes summary not found for Acting
# None
# Error: SparkNotes summary not found for Threatens
# None
# Error: SparkNotes summary not found for Flattering
# https://www.sparknotes.com/lit/beowulf/summary/
# Summary for Battle saved successfully.
# None
# Error: SparkNotes summary not found for Freedom
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Rigorous saved successfully.
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Completion saved successfully.
# None
# Error: SparkNotes summary not found for Indicators
# None
# Error: SparkNotes summary not found for Undeviating
# https://www.sparknotes.com/lit/allquiet/summary/
# Summary for Combat saved successfully.
# None
# Error: SparkNotes summary not found for Unwilling
# https://www.sparknotes.com/lit/nativeson/summary/
# Summary for Violative saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Gains saved successfully.
# https://www.sparknotes.com/lit/lookingbackward/summary/
# Summary for Looked saved successfully.
# https://www.sparknotes.com/lit/mockingjay/summary/
# Summary for Capitol saved successfully.
# None
# Error: SparkNotes summary not found for Edge
# None
# Error: SparkNotes summary not found for Usurpation
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Government saved successfully.
# None
# Error: SparkNotes summary not found for Americanism
# None
# Error: SparkNotes summary not found for Boastfulness
# None
# Error: SparkNotes summary not found for Interval
# None
# Error: SparkNotes summary not found for Embattled
# https://www.sparknotes.com/lit/souls-of-black-folk/summary/
# Summary for Freedmen saved successfully.
# https://www.sparknotes.com/lit/a-game-of-thrones/summary/
# Summary for Sworn saved successfully.
# None
# Error: SparkNotes summary not found for Renunciation
# https://www.sparknotes.com/lit/opioneers/summary/
# Summary for Untamed saved successfully.
# https://www.sparknotes.com/lit/freak-the-mighty/summary/
# Summary for Grim saved successfully.
# None
# Error: SparkNotes summary not found for Ennobled
# None
# Error: SparkNotes summary not found for Alienate
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Insuring saved successfully.
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Brotherhood saved successfully.
# https://www.sparknotes.com/lit/killerangels/summary/
# Summary for Union saved successfully.
# None
# Error: SparkNotes summary not found for Authorities
# None
# Error: SparkNotes summary not found for Piety
# None
# Error: SparkNotes summary not found for Republicans
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Entirety saved successfully.
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Standing saved successfully.
# None
# Error: SparkNotes summary not found for Constituent
# https://www.sparknotes.com/lit/thousand-splendid-suns/summary/
# Summary for Splendid saved successfully.
# None
# Error: SparkNotes summary not found for Responsibly
# None
# Error: SparkNotes summary not found for Almost
# None
# Error: SparkNotes summary not found for Descendants
# https://www.sparknotes.com/lit/band-of-brothers/summary/
# Summary for Hasty saved successfully.
# None
# Error: SparkNotes summary not found for Hardheartedness
# Summary for World already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Consequently
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Assertions saved successfully.
# https://www.sparknotes.com/lit/johnnygun/summary/
# Summary for Guns saved successfully.
# https://www.sparknotes.com/lit/virginsuicides/summary/
# Summary for Suicide saved successfully.
# None
# Error: SparkNotes summary not found for Micah
# None
# Error: SparkNotes summary not found for Dares
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Offered saved successfully.
# None
# Error: SparkNotes summary not found for Deliberating
# None
# Error: SparkNotes summary not found for Eroded
# None
# Error: SparkNotes summary not found for Depths
# https://www.sparknotes.com/lit/ragtime/summary/
# Summary for Seaboards saved successfully.
# None
# Error: SparkNotes summary not found for Preeminent
# https://www.sparknotes.com/lit/out-of-my-mind/summary/
# Summary for Mind saved successfully.
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for Coasts saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Accounting saved successfully.
# None
# Error: SparkNotes summary not found for Cross
# None
# Error: SparkNotes summary not found for One
# None
# Error: SparkNotes summary not found for Preferment
# None
# Error: SparkNotes summary not found for Unplowed
# None
# Error: SparkNotes summary not found for Adhered
# None
# Error: SparkNotes summary not found for Rightness
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Prisoners saved successfully.
# None
# Error: SparkNotes summary not found for Associates
# None
# Error: SparkNotes summary not found for Unconquerable
# None
# Error: SparkNotes summary not found for Aims
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Administer saved successfully.
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Tax saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Visible saved successfully.
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Throw saved successfully.
# https://www.sparknotes.com/lit/godot/summary/
# Summary for Goad saved successfully.
# None
# Error: SparkNotes summary not found for Compelled
# None
# Error: SparkNotes summary not found for Sympathy
# None
# Error: SparkNotes summary not found for Maturing
# https://www.sparknotes.com/lit/northangerabbey/summary/
# Summary for Northern saved successfully.
# https://www.sparknotes.com/lit/looking-for-alaska/summary/
# Summary for Finding saved successfully.
# None
# Error: SparkNotes summary not found for Heightened
# None
# Error: SparkNotes summary not found for Indirectly

# %%
import os
import pandas as pd

# Path to the directory containing the txt files
txt_dir = '/content/summaries/'

# Lists to store the titles and cleaned contents of the txt files
titles = []
contents = []

# Iterate over all files in the directory
for file_name in os.listdir(txt_dir):
    if file_name.endswith('_summary.txt'):
        # Extract the title from the file name
        title = file_name.replace('_summary.txt', '')
        titles.append(title)

        # Read the contents of each txt file
        with open(os.path.join(txt_dir, file_name), 'r') as file:
            content = file.read()
            # Clean the content by replacing newline and tab characters with a space
            cleaned_content = content.replace('\n\t\t\t', ' ')
            contents.append(cleaned_content)

# Create a DataFrame with the titles and cleaned contents
df = pd.DataFrame({'Title': titles, 'Abstract': contents})

# Save the DataFrame to a CSV file
df.to_csv('output9000-9993.csv', index=False)

# %%
df
# Out:
#                Title                                           Abstract
# 0    Comprehensively  The narrator begins telling his story with the...
# 1           Animated  Video SparkNotes: A Summary of Mary Shelley's ...
# 2          Eloquence  In a series of letters, Robert Walton, the cap...
# 3              Freer  Frederick Douglass was born into slavery somet...
# 4            Kindred  On June 9, 1976, it is the twenty-sixth birthd...
# ..               ...                                                ...
# 456          Settled  In the late nineteenth century, a man named Sa...
# 457         Colonial  In Common Sense, Thomas Paine argues for Ameri...
# 458         Freedmen  In this book, originally published in 1903, W....
# 459       Measurable  The convict Jean Valjean is released from a Fr...
# 460        Mechanism  Darwin’s theory is based on the notion of vari...
#
# [461 rows x 2 columns]

# %%
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book

# %%
# Print the first few book titles to verify
print(book_titles[:100])
# Out:
# ['Vibrant', 'Beneficent', 'Faiths', 'Beware', 'Everywhere', 'Detect', 'Cordially', 'Electors', 'Extraneous', 'Seat', 'Signify', 'Stripped', 'Indissoluble', 'Tools', 'Historical', 'Widen', 'Tomorrows', 'Embraced', 'Augustine', 'Richer', 'Suppressing', 'Cultural', 'Deprivation', 'Respite', 'Ornament', 'Tolerate', '1790', 'Members', 'Touch', 'Dome', 'Outline', 'Shrink', 'Closely', 'Circle', 'Extenuating', 'Clarified', 'Distributer', 'Today', 'Mankind', 'Existence', 'Concentrating', 'Pardoned', 'Thereby', 'Churches', 'Shows', 'Discord', 'Confusion', 'Commandments', 'Rock', 'Meliorate', 'Warriors', 'Overturning', 'Mockery', 'Pleasing', 'Portray', 'Impropriety', 'Representatives', 'Systematic', 'Sternest', 'Protection', 'Opening', 'Noted', 'Expenditures', 'Naturally', 'East', 'Present', 'Gathered', 'Authorized', 'Informed', 'Challenged', 'Derived', 'Unsurpassed', 'Confident', 'Invader', 'Requirements', 'Wide', 'Operatives', 'Government', 'Teaching', 'January', 'Shunned', 'Bimetallism', 'Communications', 'Reappear', 'Besides', 'Localized', 'Prior', 'Watchful', 'Sorrow', 'Resounding', 'Foreboding', 'Outgo', 'Reflect', 'Virus', 'Transcendent', 'Casualties', 'Neglect', 'Heavily', 'Xthough', 'Near']

# %%
from googlesearch import search

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url:
            return url
    return None

def get_summary_from_sparknotes(book_title):
    sparknotes_url = get_sparknotes_url(book_title)
    print(sparknotes_url)
    if sparknotes_url:
        response = requests.get(sparknotes_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        summary_div = soup.find('div', class_='mainTextContent main-container')
        if summary_div:
            summary = summary_div.text.strip()
            return summary
        else:
            print(f"Error: Summary not found for {book_title}")
            return None
    else:
        print(f"Error: SparkNotes summary not found for {book_title}")
        return None

book_title = "1984"  # Example book title
summary = get_summary_from_sparknotes(book_title)
if summary:
    print(summary)
# Out:
# https://www.sparknotes.com/lit/1984/summary/
# Winston Smith is a low-ranking member of the ruling Party in London, in the nation of Oceania. Everywhere Winston goes, even his own home, the Party watches him through telescreens; everywhere he looks he sees the face of the Party’s seemingly omniscient leader, a figure known only as Big Brother. The Party controls everything in Oceania, even the people’s history and language. Currently, the Party is forcing the implementation of an invented language called Newspeak, which attempts to prevent political rebellion by eliminating all words related to it. Even thinking rebellious thoughts is illegal. Such thoughtcrime is, in fact, the worst of all crimes.
# As the novel opens, Winston feels frustrated by the oppression and rigid control of the Party, which prohibits free thought, sex, and any expression of individuality. Winston dislikes the party and has illegally purchased a diary in which to write his criminal thoughts. He has also become fixated on a powerful Party member named O’Brien, whom Winston believes is a secret member of the Brotherhood—the mysterious, legendary group that works to overthrow the Party.
# Winston works in the Ministry of Truth, where he alters historical records to fit the needs of the Party. He notices a coworker, a beautiful dark-haired girl, staring at him, and worries that she is an informant who will turn him in for his thoughtcrime. He is troubled by the Party’s control of history: the Party claims that Oceania has always been allied with Eastasia in a war against Eurasia, but Winston seems to recall a time when this was not true. The Party also claims that Emmanuel Goldstein, the alleged leader of the Brotherhood, is the most dangerous man alive, but this does not seem plausible to Winston. Winston spends his evenings wandering through the poorest neighborhoods in London, where the proletarians, or proles, live squalid lives, relatively free of Party monitoring.
# One day, Winston receives a note from the dark-haired girl that reads “I love you.” She tells him her name, Julia, and they begin a covert affair, always on the lookout for signs of Party monitoring. Eventually they rent a room above the secondhand store in the prole district where Winston bought the diary. This relationship lasts for some time. Winston is sure that they will be caught and punished sooner or later (the fatalistic Winston knows that he has been doomed since he wrote his first diary entry), while Julia is more pragmatic and optimistic. As Winston’s affair with Julia progresses, his hatred for the Party grows more and more intense. At last, he receives the message that he has been waiting for: O’Brien wants to see him.
# Winston and Julia travel to O’Brien’s luxurious apartment. As a member of the powerful Inner Party (Winston belongs to the Outer Party), O’Brien leads a life of luxury that Winston can only imagine. O’Brien confirms to Winston and Julia that, like them, he hates the Party, and says that he works against it as a member of the Brotherhood. He indoctrinates Winston and Julia into the Brotherhood, and gives Winston a copy of Emmanuel Goldstein’s book, the manifesto of the Brotherhood. Winston reads the book—an amalgam of several forms of class-based twentieth-century social theory—to Julia in the room above the store. Suddenly, soldiers barge in and seize them. Mr. Charrington, the proprietor of the store, is revealed as having been a member of the Thought Police all along.
# Torn away from Julia and taken to a place called the Ministry of Love, Winston finds that O’Brien, too, is a Party spy who simply pretended to be a member of the Brotherhood in order to trap Winston into committing an open act of rebellion against the Party. O’Brien spends months torturing and brainwashing Winston, who struggles to resist. At last, O’Brien sends him to the dreaded Room 101, the final destination for anyone who opposes the Party. Here, O’Brien tells Winston that he will be forced to confront his worst fear. Throughout the novel, Winston has had recurring nightmares about rats; O’Brien now straps a cage full of rats onto Winston’s head and prepares to allow the rats to eat his face. Winston snaps, pleading with O’Brien to do it to Julia, not to him.
# Giving up Julia is what O’Brien wanted from Winston all along. His spirit broken, Winston is released to the outside world. He meets Julia but no longer feels anything for her. He has accepted the Party entirely and has learned to love Big Brother.
