# %%
# !pip install requests
# !pip install beautifulsoup4
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Mounted at /content/drive

# %%
# books_to_scrape = [
#     "1984",
#     "To Kill a Mockingbird",
#     "The Great Gatsby",
#     "Pride and Prejudice",
#     "The Catcher in the Rye",
#     "Lord of the Flies",
#     "Animal Farm",
#     "Brave New World",
#     "The Lord of the Rings",
#     "The Hobbit",
#     "Fahrenheit 451",
#     "The Grapes of Wrath",
#     "The Old Man and the Sea",
#     "The Adventures of Huckleberry Finn",
#     "Moby-Dick",
#     "War and Peace",
#     "Crime and Punishment",
#     "The Brothers Karamazov",
#     "Don Quixote",
#     "Hamlet",
#     "Romeo and Juliet",
#     "Macbeth",
#     "Othello",
#     "The Merchant of Venice",
#     "Frankenstein",
#     "Dracula",
#     "Wuthering Heights",
#     "Jane Eyre",
#     "Great Expectations",
#     "The Scarlet Letter",
#     "The Picture of Dorian Gray",
#     "Heart of Darkness",
#     "One Hundred Years of Solitude",
#     "The Bell Jar",
#     "The Stranger",
#     "Slaughterhouse-Five",
#     "Catch-22",
#     "Beloved",
#     "A Tale of Two Cities",
#     "Les Misérables",
#     "Anna Karenina",
#     "The Odyssey",
#     "The Iliad",
#     "The Aeneid",
#     "The Canterbury Tales",
#     "The Divine Comedy",
#     "Paradise Lost",
#     "Walden",
#     "The Adventures of Tom Sawyer",
#     "Adventures of Huckleberry Finn",
#     "Little Women",
#     "The Grapes of Wrath",
#     "The Sound and the Fury",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "As I Lay Dying",
#     "Their Eyes Were Watching God",
#     "The Color Purple",
#     "Invisible Man",
#     "Native Son",
#     "The Call of the Wild",
#     "White Fang",
#     "The War of the Worlds",
#     "20,000 Leagues Under the Sea",
#     "Journey to the Center of the Earth",
#     "The Three Musketeers",
#     "Robinson Crusoe",
#     "Gulliver's Travels",
#     "The Time Machine",
#     "Dr. Jekyll and Mr. Hyde",
#     "The Adventures of Sherlock Holmes",
#     "The Hound of the Baskervilles",
#     "The Count of Monte Cristo",
#     "The Invisible Man",
#     "The Island of Dr. Moreau",
#     "The Metamorphosis",
#     "The Trial",
#     "One Flew Over the Cuckoo's Nest",
#     "The Jungle",
#     "The Age of Innocence",
#     "The Bostonians",
#     "The Red Badge of Courage",
#     "The Portrait of a Lady",
#     "The Turn of the Screw",
#     "Sister Carrie",
#     "Winesburg, Ohio",
#     "A Farewell to Arms",
#     "For Whom the Bell Tolls",
#     "The Old Man and the Sea",
#     "A Farewell to Arms",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "The Good Soldier",
#     "The Heart of the Matter",
#     "The End of the Affair",
#     "The Power and the Glory",
#     "The Quiet American",
#     "The Third Man",
#     "The Human Factor",
#     "The Tale of Genji",
#     "One Hundred Years of Solitude",
#     "The Master and Margarita",
#     "The Book Thief",
#     "The Kite Runner",
#     "Norwegian Wood",
#     "The Alchemist",
#     "The Joy Luck Club",
#     "Things Fall Apart",
#     "The God of Small Things",
#     "The Hitchhiker's Guide to the Galaxy",
#     "The Handmaid's Tale",
#     "The Road",
#     "The Martian",
#     "Dune",
#     "Harry Potter and the Sorcerer's Stone",
#     "The Hunger Games",
#     "The Help",
#     "The Girl with the Dragon Tattoo",
#     "Gone Girl",
#     "The Girl on the Train",
#     "The Da Vinci Code",
#     "Life of Pi",
#     "The Curious Incident of the Dog in the Night-Time",
#     "The Secret Life of Bees",
#     "The Lovely Bones",
#     "The Book of Negroes",
#     "The Night Circus",
#     "The Catcher in the Rye",
#     "The Perks of Being a Wallflower",
#     "The Fault in Our Stars",
#     "Eleanor Oliphant Is Completely Fine",
#     "Educated",
#     "Where the Crawdads Sing",
#     "Circe",
#     "The Nightingale",
#     "All the Light We Cannot See",
#     "Before We Were Yours",
#     "A Man Called Ove",
#     "The Silent Patient",
#     "The Goldfinch",
#     "Big Little Lies",
#     "The Tattooist of Auschwitz",
#     "The Rosie Project",
#     "The Underground Railroad",
#     "Orphan Train",
#     "A Gentleman in Moscow",
#     "The Light Between Oceans",
#     "The Night Circus",
#     "The Miniaturist",
#     "The Girl With All the Gifts",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Circle",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Luminaries"
# ]
# # Ensure uniqueness of titles
# books_to_scrape = list(set(books_to_scrape))

# # # Truncate the list to 100 titles or less
# # books_to_scrape = books_to_scrape[:100]

# # Print the first few book titles to verify
# print(books_to_scrape[:100])

# %%
import nltk
nltk.download('book')

from nltk.book import text4  # Using text4, which contains a collection of texts from the Gutenberg project

# Extracting unique book titles from the Gutenberg corpus
book_titles = list(set(text4))

# Filtering out non-alphanumeric characters and ensuring titles are capitalized
book_titles = [title.strip().capitalize() for title in book_titles if title.isalnum()]
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(len(book_titles))
books_to_scrape = book_titles[7000:8000]
# books_to_scrape = book_titles[1000:2000]
# etc
print(len(books_to_scrape))
print(books_to_scrape)
# Out:
# 9993
# 1000
# ['Xtested', 'Knowing', 'Suggested', 'Fatal', 'Illumines', 'Begins', 'Believe', 'Agony', 'Impresses', 'Participating', 'Functions', 'Immediate', 'Natural', 'Glory', 'Battle', 'Assisting', 'Fulfilled', 'Battalions', 'Invasions', 'Elevate', 'Outlawry', 'Outgrown', 'Agree', 'Stringent', 'Frankly', 'Impoverishment', 'Declared', 'Navigable', 'Deeply', 'Bounties', 'Communicating', 'Burger', 'Lawless', 'Cuban', 'Fulfillment', 'Disaster', 'Insurmountable', 'Bicentennial', 'Value', 'Unreclaimed', 'Terrible', 'Friendsâ', 'Ennobled', 'Studied', 'Unexceptionable', 'Speedily', 'Felicitation', 'Needful', 'Months', 'Substantial', 'Facile', 'Occupancy', 'Orphans', 'Polygamy', 'President', 'Unrestrained', 'Enriched', 'Bleakest', 'Prisoners', 'Brutus', 'Facts', 'Fully', 'Pronounce', 'Responsibly', 'Heirs', 'Mislead', 'Frontier', 'Sprawl', 'Aspire', 'Admirably', 'Consistency', 'Designates', 'Logic', 'Servant', 'Paralyzes', 'Antiquity', 'Outworn', 'Firmness', 'Consciences', 'Pitted', 'Reduction', 'Embittered', 'Changed', 'Car', 'Much', 'Roads', 'Red', 'Fills', 'Unwilling', 'Adoption', 'Expressing', 'Pretense', 'Universities', 'Helpless', 'Onto', 'Tribes', 'Entwined', 'Scrupulously', 'Loss', 'Finishing', 'Have', 'House', 'Entertain', 'Depletion', 'Curiosity', 'Crimes', 'Connive', 'Excursions', 'Interoceanic', 'Values', 'Corresponding', 'Fuller', 'Childhood', 'Proclaiming', 'Care', 'Citizenry', 'Aloofness', 'Imports', 'Soldiers', 'Cuts', 'Real', 'Xwe', 'Unprecedented', 'Michelle', 'Incoming', 'Ready', 'Encroaches', 'Fallen', 'Franchise', 'Selections', 'Preferable', 'Fourteenth', 'Compliment', 'Camillus', 'Uprooted', 'Phase', 'Alluring', 'Speak', 'Hardly', 'Sights', 'Superior', 'Theory', 'Neighborhood', 'Parallel', 'Joy', 'Vigilance', 'Traveler', 'Persecute', 'Strengths', 'Check', 'Preceded', 'Xon', 'Necessaries', 'Underneath', 'February', 'Inaugurate', 'Corporations', 'Distresses', '1899', 'Mrs', 'Bond', 'Modification', 'Unexaggerated', 'Jungles', 'Dispensations', 'Auguring', 'Introduced', 'Suffering', 'Details', 'Cynics', 'Aims', 'Cardinal', 'Conformity', 'Inequity', 'Overwhelmingly', 'Strive', 'Whole', 'Prohibiting', 'Tended', 'Manifestly', 'Batavian', 'Had', 'Obtain', 'Ruler', 'International', 'Coldest', 'Cardinal', 'Incurring', 'Research', 'Changeless', 'Mediocrity', 'Gifts', 'California', 'Sanitary', 'Comprised', 'Networks', 'Absolutism', 'Parcel', 'Mixed', 'Brave', 'Juggler', 'Diary', 'Eradication', 'Arts', 'Neighborhoods', 'Admirable', 'Outstanding', 'Noblest', 'Swollen', 'Station', 'Merit', 'Those', 'Superintendent', 'Constitution', 'Franchises', 'Presenting', 'Scheming', 'Dew', 'Wavering', 'Manifesting', 'Marts', 'Sink', 'Counteract', 'Corrupted', 'Who', 'Correctly', 'Ragged', 'Promptness', 'Him', 'Savages', 'Timidity', 'Soviet', 'Tower', 'Induce', 'Prison', 'Distinctly', 'Melancholy', 'Affirm', 'Train', 'Belongs', 'Partially', 'Belief', 'Partaking', 'Intimately', 'Lightening', 'Closeness', 'Entrust', 'Surprised', 'Unequal', 'Nationalistic', 'Expressly', 'Foolish', 'Faithful', 'Stature', 'Encourages', 'Reduced', 'Employees', 'Hall', 'Block', 'Phrases', 'Declares', 'Inflations', '1893', 'Awarded', 'Congressional', 'Emulation', 'Bitterness', 'Degradation', 'Rend', 'Lit', 'Obsessions', 'Lady', 'Rebuilt', 'Postulations', 'Similarly', 'Wisely', 'Initiate', 'Wasted', 'Criminal', 'Postponed', 'Think', 'Curb', 'Rebuild', 'Stopping', 'Relieve', 'Cannot', 'Penalizes', 'Grandeur', 'Diversification', 'Stunning', 'Suggests', 'Crave', 'Due', 'Pardoning', 'Residue', 'Contain', 'Allured', 'Economical', 'Borrowing', 'Gained', 'Previous', 'Enemies', 'Fascism', 'Doth', 'Profligacy', 'Sides', 'Ratify', 'Discretionary', 'Policies', 'Democracy', 'Guaranty', 'Search', 'During', 'Bless', 'Candle', 'Paved', 'Boast', 'Xa', 'Idle', 'Strictly', 'Restrain', 'Grown', 'Earth', 'Submit', 'Deliverance', 'Accompanied', 'Withdrew', 'Frustrated', 'Activism', 'Fractured', 'Literally', 'Negotiation', 'Wane', 'Demand', 'Rising', 'Employment', 'Even', 'Comprehensive', 'Distances' ...

# %%
import requests
from googlesearch import search
from bs4 import BeautifulSoup
import os

# def get_summary(book_title):
#     url = f"https://www.sparknotes.com/lit/{book_title}/summary/"
#     response = requests.get(url)
#     # print(response)
#     soup = BeautifulSoup(response.text, 'html.parser')

#     summary_div = soup.find('div', class_='mainTextContent main-container')
#     # print(summary_div)
#     if summary_div:
#         summary = summary_div.text.strip()
#         return summary
#     else:
#         print(f"Error: Summary not found for {book_title}")
#         return None

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url and 'summary' in url:
            return url
    return None


def get_summary_from_sparknotes(book_title):
    # Check if the summary file already exists
    filename = f"{output_dir}/{book_title}_summary.txt"
    if os.path.exists(filename):
      print(f"Summary for {book_title} already exists. Reading from file.")
    else:
      sparknotes_url = get_sparknotes_url(book_title)
      print(sparknotes_url)
      if sparknotes_url:
          response = requests.get(sparknotes_url)
          soup = BeautifulSoup(response.text, 'html.parser')
          summary_div = soup.find('div', class_='mainTextContent main-container')
          if summary_div:
              summary = summary_div.text.strip()
              return summary
          else:
              print(f"Error: Summary not found for {book_title}")
              return None
      else:
          print(f"Error: SparkNotes summary not found for {book_title}")
          return None


def save_summary_to_file(book_title, summary, output_dir = "summaries"):
    if summary is not None:  # Check if summary is not None
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        filename = f"{output_dir}/{book_title}_summary.txt"
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(summary)
            print(f"Summary for {book_title} saved successfully.")
    # else:
    #     print(f"No summary found for {book_title}. Skipping saving to file.")

# books_to_scrape = ["1984", "ToKillAMockingbird", "TheGreatGatsby"]  # Add more book titles as needed

for book_title in books_to_scrape:
    try:
        output_dir = "summaries"
        summary = get_summary_from_sparknotes(book_title)
        # print(summary)

        save_summary_to_file(book_title, summary,)
    except Exception as e:
        print(f"Error processing {book_title}: {e}")
# Out:
# None
# Error: SparkNotes summary not found for Xtested
# None
# Error: SparkNotes summary not found for Knowing
# None
# Error: SparkNotes summary not found for Suggested
# None
# Error: SparkNotes summary not found for Fatal
# None
# Error: SparkNotes summary not found for Illumines
# https://www.sparknotes.com/lit/it-starts-with-us/summary/
# Summary for Begins saved successfully.
# None
# Error: SparkNotes summary not found for Believe
# None
# Error: SparkNotes summary not found for Agony
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Impresses saved successfully.
# None
# Error: SparkNotes summary not found for Participating
# None
# Error: SparkNotes summary not found for Functions
# None
# Error: SparkNotes summary not found for Immediate
# https://www.sparknotes.com/lit/natural/summary/
# Summary for Natural saved successfully.
# https://www.sparknotes.com/lit/powerglory/summary/
# Summary for Glory saved successfully.
# https://www.sparknotes.com/lit/beowulf/summary/
# Summary for Battle saved successfully.
# https://www.sparknotes.com/lit/assistant/summary/
# Summary for Assisting saved successfully.
# None
# Error: SparkNotes summary not found for Fulfilled
# None
# Error: SparkNotes summary not found for Battalions
# https://www.sparknotes.com/lit/allbutmylife/summary/
# Summary for Invasions saved successfully.
# None
# Error: SparkNotes summary not found for Elevate
# https://www.sparknotes.com/lit/robin-hood/summary/
# Summary for Outlawry saved successfully.
# None
# Error: SparkNotes summary not found for Outgrown
# None
# Error: SparkNotes summary not found for Agree
# None
# Error: SparkNotes summary not found for Stringent
# https://www.sparknotes.com/lit/andthenthere/summary/
# Summary for Frankly saved successfully.
# None
# Error: SparkNotes summary not found for Impoverishment
# https://www.sparknotes.com/lit/the-decameron/summary/
# Summary for Declared saved successfully.
# None
# Error: SparkNotes summary not found for Navigable
# https://www.sparknotes.com/lit/extremelyloud/summary/
# Summary for Deeply saved successfully.
# https://www.sparknotes.com/lit/do-androids-dream-of-electric-sheep/summary/
# Summary for Bounties saved successfully.
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Communicating saved successfully.
# None
# Error: SparkNotes summary not found for Burger
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Lawless saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Cuban saved successfully.
# None
# Error: SparkNotes summary not found for Fulfillment
# https://www.sparknotes.com/lit/tristram/summary/
# Summary for Disaster saved successfully.
# None
# Error: SparkNotes summary not found for Insurmountable
# None
# Error: SparkNotes summary not found for Bicentennial
# https://www.sparknotes.com/lit/451/summary/
# Summary for Value saved successfully.
# None
# Error: SparkNotes summary not found for Unreclaimed
# None
# Error: SparkNotes summary not found for Terrible
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Friendsâ saved successfully.
# None
# Error: SparkNotes summary not found for Ennobled
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Studied saved successfully.
# None
# Error: SparkNotes summary not found for Unexceptionable
# https://www.sparknotes.com/lit/other-wes-moore/summary/
# Summary for Speedily saved successfully.
# None
# Error: SparkNotes summary not found for Felicitation
# None
# Error: SparkNotes summary not found for Needful
# https://www.sparknotes.com/lit/likewater/summary/
# Summary for Months saved successfully.
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Substantial saved successfully.
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Facile saved successfully.
# None
# Error: SparkNotes summary not found for Occupancy
# https://www.sparknotes.com/lit/anneofgreengables/summary/
# Summary for Orphans saved successfully.
# https://www.sparknotes.com/lit/changes/summary/
# Summary for Polygamy saved successfully.
# None
# Error: SparkNotes summary not found for President
# None
# Error: SparkNotes summary not found for Unrestrained
# None
# Error: SparkNotes summary not found for Enriched
# https://www.sparknotes.com/lit/bleakhouse/summary/
# Summary for Bleakest saved successfully.
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Prisoners saved successfully.
# https://www.sparknotes.com/lit/if-we-were-villains/summary/
# Summary for Brutus saved successfully.
# None
# Error: SparkNotes summary not found for Facts
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Fully saved successfully.
# None
# Error: SparkNotes summary not found for Pronounce
# None
# Error: SparkNotes summary not found for Responsibly
# https://www.sparknotes.com/lit/the-westing-game/summary/
# Summary for Heirs saved successfully.
# None
# Error: SparkNotes summary not found for Mislead
# None
# Error: SparkNotes summary not found for Frontier
# https://www.sparknotes.com/lit/borderpassage/summary/
# Summary for Sprawl saved successfully.
# https://www.sparknotes.com/lit/nativeson/summary/
# Summary for Aspire saved successfully.
# None
# Error: SparkNotes summary not found for Admirably
# None
# Error: SparkNotes summary not found for Consistency
# None
# Error: SparkNotes summary not found for Designates
# None
# Error: SparkNotes summary not found for Logic
# None
# Error: SparkNotes summary not found for Servant
# None
# Error: SparkNotes summary not found for Paralyzes
# None
# Error: SparkNotes summary not found for Antiquity
# None
# Error: SparkNotes summary not found for Outworn
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Firmness saved successfully.
# None
# Error: SparkNotes summary not found for Consciences
# None
# Error: SparkNotes summary not found for Pitted
# None
# Error: SparkNotes summary not found for Reduction
# None
# Error: SparkNotes summary not found for Embittered
# https://www.sparknotes.com/lit/changes/summary/
# Summary for Changed saved successfully.
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Car saved successfully.
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Much saved successfully.
# https://www.sparknotes.com/lit/road/summary/
# Summary for Roads saved successfully.
# https://www.sparknotes.com/lit/redblack/summary/
# Summary for Red saved successfully.
# None
# Error: SparkNotes summary not found for Fills
# None
# Error: SparkNotes summary not found for Unwilling
# https://www.sparknotes.com/lit/there-there/summary/
# Summary for Adoption saved successfully.
# https://www.sparknotes.com/lit/orientexpress/summary/
# Summary for Expressing saved successfully.
# None
# Error: SparkNotes summary not found for Pretense
# None
# Error: SparkNotes summary not found for Universities
# None
# Error: SparkNotes summary not found for Helpless
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Onto saved successfully.
# None
# Error: SparkNotes summary not found for Tribes
# None
# Error: SparkNotes summary not found for Entwined
# None
# Error: SparkNotes summary not found for Scrupulously
# None
# Error: SparkNotes summary not found for Loss
# None
# Error: SparkNotes summary not found for Finishing
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Have saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for House saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Entertain saved successfully.
# None
# Error: SparkNotes summary not found for Depletion
# https://www.sparknotes.com/lit/the-curious-incident-of-the-dog-in-the-night-time/summary/
# Summary for Curiosity saved successfully.
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Crimes saved successfully.
# None
# Error: SparkNotes summary not found for Connive
# None
# Error: SparkNotes summary not found for Excursions
# None
# Error: SparkNotes summary not found for Interoceanic
# None
# Error: SparkNotes summary not found for Values
# None
# Error: SparkNotes summary not found for Corresponding
# None
# Error: SparkNotes summary not found for Fuller
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Childhood saved successfully.
# None
# Error: SparkNotes summary not found for Proclaiming
# None
# Error: SparkNotes summary not found for Care
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Citizenry saved successfully.
# https://www.sparknotes.com/lit/eyes/summary/
# Summary for Aloofness saved successfully.
# None
# Error: SparkNotes summary not found for Imports
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Soldiers saved successfully.
# None
# Error: SparkNotes summary not found for Cuts
# https://www.sparknotes.com/lit/the-absolutely-true-diary-of-a-part-time-indian/summary/
# Summary for Real saved successfully.
# https://www.sparknotes.com/lit/we-were-liars/summary/
# Summary for Xwe saved successfully.
# https://www.sparknotes.com/lit/immortal-life/summary/
# Summary for Unprecedented saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Michelle saved successfully.
# None
# Error: SparkNotes summary not found for Incoming
# https://www.sparknotes.com/lit/ready-player-one/summary/
# Summary for Ready saved successfully.
# None
# Error: SparkNotes summary not found for Encroaches
# https://www.sparknotes.com/lit/fallenangels/summary/
# Summary for Fallen saved successfully.
# None
# Error: SparkNotes summary not found for Franchise
# None
# Error: SparkNotes summary not found for Selections
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Preferable saved successfully.
# None
# Error: SparkNotes summary not found for Fourteenth
# None
# Error: SparkNotes summary not found for Compliment
# https://www.sparknotes.com/lit/stranger/summary/
# Summary for Camillus saved successfully.
# https://www.sparknotes.com/lit/americanah/summary/
# Summary for Uprooted saved successfully.
# None
# Error: SparkNotes summary not found for Phase
# None
# Error: SparkNotes summary not found for Alluring
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Speak saved successfully.
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Hardly saved successfully.
# None
# Error: SparkNotes summary not found for Sights
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Superior saved successfully.
# https://www.sparknotes.com/lit/origin/summary/
# Summary for Theory saved successfully.
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Neighborhood saved successfully.
# None
# Error: SparkNotes summary not found for Parallel
# https://www.sparknotes.com/lit/joyluck/summary/
# Summary for Joy saved successfully.
# None
# Error: SparkNotes summary not found for Vigilance
# https://www.sparknotes.com/lit/timemachine/summary/
# Summary for Traveler saved successfully.
# None
# Error: SparkNotes summary not found for Persecute
# None
# Error: SparkNotes summary not found for Strengths
# None
# Error: SparkNotes summary not found for Check
# https://www.sparknotes.com/lit/chrondeath/summary/
# Summary for Preceded saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Xon saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Necessaries saved successfully.
# https://www.sparknotes.com/lit/under-the-feet-of-jesus/summary/
# Summary for Underneath saved successfully.
# https://www.sparknotes.com/lit/awakening/summary/
# Summary for February saved successfully.
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Inaugurate saved successfully.
# None
# Error: SparkNotes summary not found for Corporations
# https://www.sparknotes.com/lit/in-the-time-of-butterflies/summary/
# Summary for Distresses saved successfully.
# https://www.sparknotes.com/lit/heart-of-darkness/summary/
# Summary for 1899 saved successfully.
# https://www.sparknotes.com/lit/dalloway/summary/
# Summary for Mrs saved successfully.
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Bond saved successfully.
# None
# Error: SparkNotes summary not found for Modification
# None
# Error: SparkNotes summary not found for Unexaggerated
# https://www.sparknotes.com/lit/jungle/summary/
# Summary for Jungles saved successfully.
# None
# Error: SparkNotes summary not found for Dispensations
# None
# Error: SparkNotes summary not found for Auguring
# None
# Error: SparkNotes summary not found for Introduced
# None
# Error: SparkNotes summary not found for Suffering
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Details saved successfully.
# None
# Error: SparkNotes summary not found for Cynics
# None
# Error: SparkNotes summary not found for Aims
# None
# Error: SparkNotes summary not found for Cardinal
# None
# Error: SparkNotes summary not found for Conformity
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Inequity saved successfully.
# None
# Error: SparkNotes summary not found for Overwhelmingly
# https://www.sparknotes.com/lit/circe/summary/
# Summary for Strive saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Whole saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Prohibiting saved successfully.
# None
# Error: SparkNotes summary not found for Tended
# None
# Error: SparkNotes summary not found for Manifestly
# None
# Error: SparkNotes summary not found for Batavian
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Had saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Obtain saved successfully.
# None
# Error: SparkNotes summary not found for Ruler
# None
# Error: SparkNotes summary not found for International
# https://www.sparknotes.com/lit/coldmountain/summary/
# Summary for Coldest saved successfully.
# None
# Error: SparkNotes summary not found for Cardinal
# https://www.sparknotes.com/lit/ceremony/summary/
# Summary for Incurring saved successfully.
# None
# Error: SparkNotes summary not found for Research
# None
# Error: SparkNotes summary not found for Changeless
# https://www.sparknotes.com/lit/song-of-achilles/summary/
# Summary for Mediocrity saved successfully.
# None
# Error: SparkNotes summary not found for Gifts
# None
# Error: SparkNotes summary not found for California
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Sanitary saved successfully.
# https://www.sparknotes.com/lit/divergent/summary/
# Summary for Comprised saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Networks saved successfully.
# None
# Error: SparkNotes summary not found for Absolutism
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Parcel saved successfully.
# https://www.sparknotes.com/lit/born-a-crime/summary/
# Summary for Mixed saved successfully.
# https://www.sparknotes.com/lit/bravenew/summary/
# Summary for Brave saved successfully.
# None
# Error: SparkNotes summary not found for Juggler
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Diary saved successfully.
# None
# Error: SparkNotes summary not found for Eradication
# https://www.sparknotes.com/lit/portraitartist/summary/
# Summary for Arts saved successfully.
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Neighborhoods saved successfully.
# None
# Error: SparkNotes summary not found for Admirable
# None
# Error: SparkNotes summary not found for Outstanding
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Noblest saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Swollen saved successfully.
# https://www.sparknotes.com/lit/station-eleven/summary/
# Summary for Station saved successfully.
# None
# Error: SparkNotes summary not found for Merit
# None
# Error: SparkNotes summary not found for Those
# None
# Error: SparkNotes summary not found for Superintendent
# None
# Error: SparkNotes summary not found for Constitution
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Franchises saved successfully.
# https://www.sparknotes.com/lit/into-the-wild/summary/
# Summary for Presenting saved successfully.
# None
# Error: SparkNotes summary not found for Scheming
# None
# Error: SparkNotes summary not found for Dew
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Wavering saved successfully.
# None
# Error: SparkNotes summary not found for Manifesting
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Marts saved successfully.
# None
# Error: SparkNotes summary not found for Sink
# None
# Error: SparkNotes summary not found for Counteract
# None
# Error: SparkNotes summary not found for Corrupted
# https://www.sparknotes.com/lit/afraidofwoolf/summary/
# Summary for Who saved successfully.
# https://www.sparknotes.com/lit/stranger/summary/
# Summary for Correctly saved successfully.
# None
# Error: SparkNotes summary not found for Ragged
# https://www.sparknotes.com/lit/up-from-slavery/summary/
# Summary for Promptness saved successfully.
# None
# Error: SparkNotes summary not found for Him
# None
# Error: SparkNotes summary not found for Savages
# None
# Error: SparkNotes summary not found for Timidity
# None
# Error: SparkNotes summary not found for Soviet
# https://www.sparknotes.com/lit/twotowers/summary/
# Summary for Tower saved successfully.
# https://www.sparknotes.com/lit/iliad/summary/
# Summary for Induce saved successfully.
# https://www.sparknotes.com/lit/letter-from-birmingham-jail/summary/
# Summary for Prison saved successfully.
# None
# Error: SparkNotes summary not found for Distinctly
# https://www.sparknotes.com/lit/sorrows-of-young-werther/summary/
# Summary for Melancholy saved successfully.
# None
# Error: SparkNotes summary not found for Affirm
# None
# Error: SparkNotes summary not found for Train
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Belongs saved successfully.
# https://www.sparknotes.com/lit/joyluck/summary/
# Summary for Partially saved successfully.
# None
# Error: SparkNotes summary not found for Belief
# None
# Error: SparkNotes summary not found for Partaking
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Intimately saved successfully.
# https://www.sparknotes.com/lit/lightning-thief/summary/
# Summary for Lightening saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Closeness saved successfully.
# https://www.sparknotes.com/lit/nectar/summary/
# Summary for Entrust saved successfully.
# None
# Error: SparkNotes summary not found for Surprised
# None
# Error: SparkNotes summary not found for Unequal
# None
# Error: SparkNotes summary not found for Nationalistic
# https://www.sparknotes.com/lit/orientexpress/summary/
# Summary for Expressly saved successfully.
# None
# Error: SparkNotes summary not found for Foolish
# https://www.sparknotes.com/lit/pilgrims/summary/
# Summary for Faithful saved successfully.
# None
# Error: SparkNotes summary not found for Stature
# None
# Error: SparkNotes summary not found for Encourages
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Reduced saved successfully.
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Employees saved successfully.
# None
# Error: SparkNotes summary not found for Hall
# https://www.sparknotes.com/lit/the-curious-incident-of-the-dog-in-the-night-time/summary/
# Summary for Block saved successfully.
# None
# Error: SparkNotes summary not found for Phrases
# None
# Error: SparkNotes summary not found for Declares
# https://www.sparknotes.com/lit/childofthedark/summary/
# Summary for Inflations saved successfully.
# https://www.sparknotes.com/lit/fever/summary/
# Summary for 1893 saved successfully.
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Awarded saved successfully.
# https://www.sparknotes.com/lit/incidents/summary/
# Summary for Congressional saved successfully.
# None
# Error: SparkNotes summary not found for Emulation
# None
# Error: SparkNotes summary not found for Bitterness
# None
# Error: SparkNotes summary not found for Degradation
# None
# Error: SparkNotes summary not found for Rend
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Lit saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Obsessions saved successfully.
# https://www.sparknotes.com/lit/portraitlady/summary/
# Summary for Lady saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Rebuilt saved successfully.
# https://www.sparknotes.com/lit/elegantuniverse/summary/
# Summary for Postulations saved successfully.
# None
# Error: SparkNotes summary not found for Similarly
# None
# Error: SparkNotes summary not found for Wisely
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Initiate saved successfully.
# None
# Error: SparkNotes summary not found for Wasted
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Criminal saved successfully.
# None
# Error: SparkNotes summary not found for Postponed
# https://www.sparknotes.com/lit/yearmagical/summary/
# Summary for Think saved successfully.
# None
# Error: SparkNotes summary not found for Curb
# None
# Error: SparkNotes summary not found for Rebuild
# https://www.sparknotes.com/lit/noexit/summary/
# Summary for Stopping saved successfully.
# https://www.sparknotes.com/lit/nolonger/summary/
# Summary for Relieve saved successfully.
# https://www.sparknotes.com/lit/all-the-light/summary/
# Summary for Cannot saved successfully.
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Penalizes saved successfully.
# https://www.sparknotes.com/lit/yellowwallpaper/summary/
# Summary for Grandeur saved successfully.
# None
# Error: SparkNotes summary not found for Diversification
# https://www.sparknotes.com/lit/beautiful-and-the-damned/summary/
# Summary for Stunning saved successfully.
# None
# Error: SparkNotes summary not found for Suggests
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Crave saved successfully.
# https://www.sparknotes.com/lit/dune/summary/
# Summary for Due saved successfully.
# https://www.sparknotes.com/lit/the-canterbury-tales/summary/
# Summary for Pardoning saved successfully.
# https://www.sparknotes.com/lit/goaskalice/summary/
# Summary for Residue saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Contain saved successfully.
# https://www.sparknotes.com/lit/shadow-and-bone/summary/
# Summary for Allured saved successfully.
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Economical saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Borrowing saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Gained saved successfully.
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Previous saved successfully.
# https://www.sparknotes.com/lit/enemyofthepeople/summary/
# Summary for Enemies saved successfully.
# https://www.sparknotes.com/lit/belltolls/summary/
# Summary for Fascism saved successfully.
# None
# Error: SparkNotes summary not found for Doth
# None
# Error: SparkNotes summary not found for Profligacy
# None
# Error: SparkNotes summary not found for Sides
# None
# Error: SparkNotes summary not found for Ratify
# None
# Error: SparkNotes summary not found for Discretionary
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Policies saved successfully.
# None
# Error: SparkNotes summary not found for Democracy
# None
# Error: SparkNotes summary not found for Guaranty
# None
# Error: SparkNotes summary not found for Search
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for During saved successfully.
# https://www.sparknotes.com/lit/ultima/summary/
# Summary for Bless saved successfully.
# None
# Error: SparkNotes summary not found for Candle
# None
# Error: SparkNotes summary not found for Paved
# None
# Error: SparkNotes summary not found for Boast
# https://www.sparknotes.com/lit/malcolmx/summary/
# Summary for Xa saved successfully.
# https://www.sparknotes.com/lit/ulysses/summary/
# Summary for Idle saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Strictly saved successfully.
# None
# Error: SparkNotes summary not found for Restrain
# https://www.sparknotes.com/lit/redfern/summary/
# Summary for Grown saved successfully.
# https://www.sparknotes.com/lit/goodearth/summary/
# Summary for Earth saved successfully.
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Submit saved successfully.
# None
# Error: SparkNotes summary not found for Deliverance
# None
# Error: SparkNotes summary not found for Accompanied
# https://www.sparknotes.com/lit/the-perks-of-being-a-wallflower/summary/
# Summary for Withdrew saved successfully.
# None
# Error: SparkNotes summary not found for Frustrated
# None
# Error: SparkNotes summary not found for Activism
# None
# Error: SparkNotes summary not found for Fractured
# https://www.sparknotes.com/lit/iliad/summary/
# Summary for Literally saved successfully.
# None
# Error: SparkNotes summary not found for Negotiation
# None
# Error: SparkNotes summary not found for Wane
# None
# Error: SparkNotes summary not found for Demand
# https://www.sparknotes.com/lit/esperanza-rising/summary/
# Summary for Rising saved successfully.
# None
# Error: SparkNotes summary not found for Employment
# None
# Error: SparkNotes summary not found for Even
# https://www.sparknotes.com/lit/medea/summary/?quickquiz_id=2150
# Summary for Comprehensive saved successfully.
# None
# Error: SparkNotes summary not found for Distances
# None
# Error: SparkNotes summary not found for Liberties
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Repeated saved successfully.
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Fisheries saved successfully.
# None
# Error: SparkNotes summary not found for Useless
# https://www.sparknotes.com/lit/heart-of-darkness/summary/
# Summary for Sunk saved successfully.
# https://www.sparknotes.com/lit/it-starts-with-us/summary/
# Summary for Available saved successfully.
# None
# Error: SparkNotes summary not found for Courageously
# https://www.sparknotes.com/lit/idiot/summary/
# Summary for Ardent saved successfully.
# None
# Error: SparkNotes summary not found for Formulate
# None
# Error: SparkNotes summary not found for Treaties
# None
# Error: SparkNotes summary not found for Unhappy
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Creative saved successfully.
# https://www.sparknotes.com/lit/freak-the-mighty/summary/
# Summary for Almighty saved successfully.
# None
# Error: SparkNotes summary not found for Leads
# None
# Error: SparkNotes summary not found for Estimates
# https://www.sparknotes.com/lit/arms-and-the-man/summary/
# Summary for Armaments saved successfully.
# None
# Error: SparkNotes summary not found for Especially
# None
# Error: SparkNotes summary not found for Ardor
# None
# Error: SparkNotes summary not found for Tumultuous
# None
# Error: SparkNotes summary not found for Forbearing
# None
# Error: SparkNotes summary not found for Prevalence
# https://www.sparknotes.com/lit/whirlwind/summary/
# Summary for Whirlwind saved successfully.
# None
# Error: SparkNotes summary not found for Employs
# None
# Error: SparkNotes summary not found for Incumbency
# None
# Error: SparkNotes summary not found for Rapidity
# None
# Error: SparkNotes summary not found for Rather
# https://www.sparknotes.com/lit/mohicans/summary/
# Summary for 1826 saved successfully.
# None
# Error: SparkNotes summary not found for Smoothly
# https://www.sparknotes.com/lit/littleprince/summary/
# Summary for Small saved successfully.
# https://www.sparknotes.com/lit/out-of-my-mind/summary/
# Summary for Out saved successfully.
# https://www.sparknotes.com/lit/it-starts-with-us/summary/
# Summary for Including saved successfully.
# None
# Error: SparkNotes summary not found for Ascribe
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Stay saved successfully.
# None
# Error: SparkNotes summary not found for Conclusion
# None
# Error: SparkNotes summary not found for Reestablish
# None
# Error: SparkNotes summary not found for Aboriginal
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Forward saved successfully.
# None
# Error: SparkNotes summary not found for Efforts
# None
# Error: SparkNotes summary not found for Penury
# None
# Error: SparkNotes summary not found for Satisfy
# https://www.sparknotes.com/lit/grapesofwrath/summary/
# Summary for Endeavored saved successfully.
# https://www.sparknotes.com/lit/arabian-nights/summary/
# Summary for Envious saved successfully.
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Senator saved successfully.
# None
# Error: SparkNotes summary not found for Contended
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Gulf saved successfully.
# https://www.sparknotes.com/lit/fever/summary/
# Summary for Above saved successfully.
# None
# Error: SparkNotes summary not found for Guarded
# None
# Error: SparkNotes summary not found for Agents
# https://www.sparknotes.com/lit/christmascarol/summary/
# Summary for Warms saved successfully.
# None
# Error: SparkNotes summary not found for Votes
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Brink saved successfully.
# None
# Error: SparkNotes summary not found for Tariffs
# https://www.sparknotes.com/lit/grendel/summary/
# Summary for Gradual saved successfully.
# None
# Error: SparkNotes summary not found for Improvements
# None
# Error: SparkNotes summary not found for Strained
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Popular saved successfully.
# https://www.sparknotes.com/lit/20000-leagues-under-the-sea/summary/
# Summary for League saved successfully.
# None
# Error: SparkNotes summary not found for Tyrants
# None
# Error: SparkNotes summary not found for Conclusion
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Desires saved successfully.
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Materially saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Produce saved successfully.
# None
# Error: SparkNotes summary not found for Agencies
# None
# Error: SparkNotes summary not found for Reflects
# None
# Error: SparkNotes summary not found for Valley
# None
# Error: SparkNotes summary not found for Wily
# None
# Error: SparkNotes summary not found for Calculated
# https://www.sparknotes.com/lit/homegoing/summary/
# Summary for Mining saved successfully.
# None
# Error: SparkNotes summary not found for Cascading
# None
# Error: SparkNotes summary not found for Suit
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Panoply saved successfully.
# None
# Error: SparkNotes summary not found for Rebuilds
# None
# Error: SparkNotes summary not found for Metallic
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Practices saved successfully.
# https://www.sparknotes.com/lit/homegoing/summary/
# Summary for Foregoing saved successfully.
# None
# Error: SparkNotes summary not found for Right
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Lest saved successfully.
# None
# Error: SparkNotes summary not found for Merited
# None
# Error: SparkNotes summary not found for Scientific
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Offenders saved successfully.
# None
# Error: SparkNotes summary not found for Representative
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Meaning saved successfully.
# None
# Error: SparkNotes summary not found for Reserve
# https://www.sparknotes.com/lit/sovereignty/summary/
# Summary for Goodness saved successfully.
# None
# Error: SparkNotes summary not found for Latent
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Backs saved successfully.
# https://www.sparknotes.com/lit/band-of-brothers/summary/
# Summary for Band saved successfully.
# None
# Error: SparkNotes summary not found for Plainly
# https://www.sparknotes.com/lit/into-the-wild/summary/
# Summary for Wilderness saved successfully.
# https://www.sparknotes.com/lit/all-the-light/summary/
# Summary for Seen saved successfully.
# None
# Error: SparkNotes summary not found for Tarawa
# https://www.sparknotes.com/lit/walden/summary/
# Summary for Zone saved successfully.
# None
# Error: SparkNotes summary not found for Chair
# https://www.sparknotes.com/lit/the-summer-i-turned-pretty/summary/
# Summary for Turned saved successfully.
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Iraq saved successfully.
# https://www.sparknotes.com/lit/station-eleven/summary/
# Summary for Revive saved successfully.
# https://www.sparknotes.com/lit/lot49/summary/
# Summary for Waste saved successfully.
# https://www.sparknotes.com/lit/tarbaby/summary/
# Summary for Croix saved successfully.
# https://www.sparknotes.com/lit/siddhartha/summary/
# Summary for Instructive saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Professionals saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Outlines saved successfully.
# None
# Error: SparkNotes summary not found for Imposes
# None
# Error: SparkNotes summary not found for Dearer
# None
# Error: SparkNotes summary not found for Defended
# None
# Error: SparkNotes summary not found for Feature
# None
# Error: SparkNotes summary not found for Offends
# None
# Error: SparkNotes summary not found for Seek
# None
# Error: SparkNotes summary not found for Shop
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for This saved successfully.
# https://www.sparknotes.com/lit/opioneers/summary/
# Summary for Prospered saved successfully.
# None
# Error: SparkNotes summary not found for Coin
# None
# Error: SparkNotes summary not found for Technologies
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Earnings saved successfully.
# None
# Error: SparkNotes summary not found for Cultivation
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Pres saved successfully.
# None
# Error: SparkNotes summary not found for Impossibility
# None
# Error: SparkNotes summary not found for Tide
# None
# Error: SparkNotes summary not found for Immeasurable
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Goes saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Example saved successfully.
# None
# Error: SparkNotes summary not found for Bosoms
# https://www.sparknotes.com/lit/changes/summary/
# Summary for Revisions saved successfully.
# https://www.sparknotes.com/lit/catch22/summary/
# Summary for Discharged saved successfully.
# None
# Error: SparkNotes summary not found for Preparatory
# None
# Error: SparkNotes summary not found for Distinct
# https://www.sparknotes.com/lit/wuthering/summary/
# Summary for Heading saved successfully.
# https://www.sparknotes.com/lit/allthepretty/summary/
# Summary for Horseback saved successfully.
# None
# Error: SparkNotes summary not found for Celebrate
# None
# Error: SparkNotes summary not found for Difficulty
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Shouldn saved successfully.
# https://www.sparknotes.com/lit/fiveaprils/summary/
# Summary for Deserters saved successfully.
# https://www.sparknotes.com/lit/band-of-brothers/summary/
# Summary for Amid saved successfully.
# None
# Error: SparkNotes summary not found for Opposition
# https://www.sparknotes.com/lit/siddhartha/summary/
# Summary for Needed saved successfully.
# None
# Error: SparkNotes summary not found for Shackles
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Moment saved successfully.
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for Ports saved successfully.
# None
# Error: SparkNotes summary not found for Wisest
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Illustrated saved successfully.
# https://www.sparknotes.com/lit/the-curious-incident-of-the-dog-in-the-night-time/summary/
# Summary for Conducts saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Govern saved successfully.
# None
# Error: SparkNotes summary not found for Dedication
# None
# Error: SparkNotes summary not found for Fortified
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Misinterpret saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Applicants saved successfully.
# None
# Error: SparkNotes summary not found for Happy
# None
# Error: SparkNotes summary not found for Inquietude
# https://www.sparknotes.com/lit/451/summary/
# Summary for Fear saved successfully.
# None
# Error: SparkNotes summary not found for Steadfastness
# None
# Error: SparkNotes summary not found for Untried
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Products saved successfully.
# https://www.sparknotes.com/lit/vanishing-half/summary/
# Summary for Disappearing saved successfully.
# None
# Error: SparkNotes summary not found for Scene
# None
# Error: SparkNotes summary not found for Relief
# None
# Error: SparkNotes summary not found for Shine
# None
# Error: SparkNotes summary not found for Wisdom
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Expense saved successfully.
# None
# Error: SparkNotes summary not found for Inspires
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Conferred saved successfully.
# https://www.sparknotes.com/lit/rosencrantz/summary/
# Summary for Usurped saved successfully.
# Summary for Invasions already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Overtaxed
# None
# Error: SparkNotes summary not found for Expenditure
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Political saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Derives saved successfully.
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Amongst saved successfully.
# https://www.sparknotes.com/lit/bravenew/summary/
# Summary for Bravery saved successfully.
# None
# Error: SparkNotes summary not found for Winter
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Independent saved successfully.
# None
# Error: SparkNotes summary not found for Presage
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Momentum saved successfully.
# https://www.sparknotes.com/lit/modestproposal/summary/?quickquiz_id=1996
# Summary for Glut saved successfully.
# None
# Error: SparkNotes summary not found for Willingly
# None
# Error: SparkNotes summary not found for Essence
# None
# Error: SparkNotes summary not found for Spoliation
# None
# Error: SparkNotes summary not found for Scenes
# None
# Error: SparkNotes summary not found for Deplore
# None
# Error: SparkNotes summary not found for Stead
# https://www.sparknotes.com/lit/everything-everything/summary/
# Summary for Whatever saved successfully.
# None
# Error: SparkNotes summary not found for Literary
# None
# Error: SparkNotes summary not found for Unknowing
# None
# Error: SparkNotes summary not found for Withdrawal
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Reverent saved successfully.
# None
# Error: SparkNotes summary not found for Elementary
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Cases saved successfully.
# https://www.sparknotes.com/lit/childofthedark/summary/
# Summary for Dark saved successfully.
# None
# Error: SparkNotes summary not found for Carnage
# https://www.sparknotes.com/lit/immortal-life/summary/
# Summary for Immortal saved successfully.
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Apology saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Specialized saved successfully.
# None
# Error: SparkNotes summary not found for Targets
# None
# Error: SparkNotes summary not found for Usurpations
# Summary for Who already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Agreeing
# None
# Error: SparkNotes summary not found for Vista
# None
# Error: SparkNotes summary not found for Estimation
# https://www.sparknotes.com/lit/afraidofwoolf/summary/
# Summary for Afraid saved successfully.
# None
# Error: SparkNotes summary not found for Vouchsafed
# None
# Error: SparkNotes summary not found for Guards
# None
# Error: SparkNotes summary not found for Visit
# None
# Error: SparkNotes summary not found for Speeches
# None
# Error: SparkNotes summary not found for Month
# None
# Error: SparkNotes summary not found for Cordial
# None
# Error: SparkNotes summary not found for 14th
# https://www.sparknotes.com/lit/the-absolutely-true-diary-of-a-part-time-indian/summary/
# Summary for Actual saved successfully.
# https://www.sparknotes.com/lit/girlinterrupted/summary/
# Summary for Interruptions saved successfully.
# None
# Error: SparkNotes summary not found for Manliness
# None
# Error: SparkNotes summary not found for Negative
# None
# Error: SparkNotes summary not found for Might
# None
# Error: SparkNotes summary not found for Accounted
# None
# Error: SparkNotes summary not found for Failures
# https://www.sparknotes.com/lit/awakening/summary/
# Summary for Kindles saved successfully.
# None
# Error: SparkNotes summary not found for Compass
# None
# Error: SparkNotes summary not found for Direct
# None
# Error: SparkNotes summary not found for Riding
# None
# Error: SparkNotes summary not found for Privilege
# https://www.sparknotes.com/lit/asher/summary/
# Summary for Arouse saved successfully.
# None
# Error: SparkNotes summary not found for Producing
# https://www.sparknotes.com/lit/souls-of-black-folk/summary/
# Summary for Effects saved successfully.
# https://www.sparknotes.com/lit/algernon/summary/
# Summary for Operated saved successfully.
# None
# Error: SparkNotes summary not found for Volunteer
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Prisons saved successfully.
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Commending saved successfully.
# None
# Error: SparkNotes summary not found for Inapplicable
# None
# Error: SparkNotes summary not found for Interpreters
# https://www.sparknotes.com/lit/screw/summary/
# Summary for Turning saved successfully.
# None
# Error: SparkNotes summary not found for England
# None
# Error: SparkNotes summary not found for Disinterested
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Mentioned saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Run saved successfully.
# https://www.sparknotes.com/lit/slaughter/summary/
# Summary for Sweep saved successfully.
# https://www.sparknotes.com/lit/fountainhead/summary/
# Summary for Head saved successfully.
# None
# Error: SparkNotes summary not found for Uncounted
# None
# Error: SparkNotes summary not found for Yourself
# None
# Error: SparkNotes summary not found for Ruggedness
# https://www.sparknotes.com/lit/rip-van-winkle/summary/
# Summary for Attentive saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Reflections saved successfully.
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Arrive saved successfully.
# None
# Error: SparkNotes summary not found for Derive
# https://www.sparknotes.com/lit/brief-wondrous-life-oscar-wao/summary/
# Summary for Observed saved successfully.
# None
# Error: SparkNotes summary not found for Resentment
# https://www.sparknotes.com/lit/pilgrims/summary/
# Summary for Progress saved successfully.
# None
# Error: SparkNotes summary not found for Denial
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Experiment saved successfully.
# None
# Error: SparkNotes summary not found for Benevolence
# None
# Error: SparkNotes summary not found for Worst
# None
# Error: SparkNotes summary not found for Subject
# https://www.sparknotes.com/lit/alice/summary/
# Summary for Shrunken saved successfully.
# None
# Error: SparkNotes summary not found for Mission
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Removed saved successfully.
# None
# Error: SparkNotes summary not found for Consolidated
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Reduce saved successfully.
# None
# Error: SparkNotes summary not found for Formulation
# https://www.sparknotes.com/lit/yellowwallpaper/summary/
# Summary for Journal saved successfully.
# https://www.sparknotes.com/lit/lake-of-the-woods/summary/
# Summary for Lakes saved successfully.
# None
# Error: SparkNotes summary not found for Demoralization
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Yields saved successfully.
# https://www.sparknotes.com/lit/boy-in-striped-pajamas/summary/
# Summary for Exploring saved successfully.
# None
# Error: SparkNotes summary not found for Waging
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Parents saved successfully.
# None
# Error: SparkNotes summary not found for Deceive
# None
# Error: SparkNotes summary not found for Distribution
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Endured saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Morbid saved successfully.
# None
# Error: SparkNotes summary not found for Insist
# None
# Error: SparkNotes summary not found for Literature
# None
# Error: SparkNotes summary not found for Copartnership
# None
# Error: SparkNotes summary not found for Southern
# None
# Error: SparkNotes summary not found for Utterance
# None
# Error: SparkNotes summary not found for Truest
# https://www.sparknotes.com/lit/451/summary/
# Summary for Federal saved successfully.
# None
# Error: SparkNotes summary not found for Thereto
# None
# Error: SparkNotes summary not found for Becloud
# None
# Error: SparkNotes summary not found for Cereals
# https://www.sparknotes.com/lit/allquiet/summary/
# Summary for Western saved successfully.
# https://www.sparknotes.com/lit/it-starts-with-us/summary/
# Summary for Already saved successfully.
# https://www.sparknotes.com/lit/so-you-want-to-talk-about-race/summary/
# Summary for Discussing saved successfully.
# https://www.sparknotes.com/lit/breatheyes/summary/
# Summary for Breath saved successfully.
# None
# Error: SparkNotes summary not found for Sheet
# https://www.sparknotes.com/lit/antonia/summary/
# Summary for Burdened saved successfully.
# None
# Error: SparkNotes summary not found for Evinced
# https://www.sparknotes.com/lit/a-little-life/summary/
# Summary for Valiantly saved successfully.
# https://www.sparknotes.com/lit/ordinarypeople/summary/
# Summary for Regular saved successfully.
# None
# Error: SparkNotes summary not found for 1800
# None
# Error: SparkNotes summary not found for Rediscover
# None
# Error: SparkNotes summary not found for Pillars
# None
# Error: SparkNotes summary not found for Armies
# None
# Error: SparkNotes summary not found for Creator
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Spiritual saved successfully.
# https://www.sparknotes.com/lit/belltolls/summary/
# Summary for Whom saved successfully.
# None
# Error: SparkNotes summary not found for Oppression
# None
# Error: SparkNotes summary not found for Channels
# None
# Error: SparkNotes summary not found for Destructive
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Applying saved successfully.
# https://www.sparknotes.com/lit/outsiders/summary/
# Summary for Scrutiny saved successfully.
# None
# Error: SparkNotes summary not found for Tranquillity
# https://www.sparknotes.com/lit/come-up/summary/
# Summary for Decisively saved successfully.
# https://www.sparknotes.com/lit/wonder/summary/
# Summary for Wander saved successfully.
# None
# Error: SparkNotes summary not found for Righteousness
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Behalf saved successfully.
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Extended saved successfully.
# https://www.sparknotes.com/lit/agamemnon/summary/
# Summary for Fleet saved successfully.
# None
# Error: SparkNotes summary not found for Signifies
# None
# Error: SparkNotes summary not found for Animates
# None
# Error: SparkNotes summary not found for Custom
# None
# Error: SparkNotes summary not found for Instance
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Losing saved successfully.
# None
# Error: SparkNotes summary not found for Revise
# None
# Error: SparkNotes summary not found for Dwarfed
# https://www.sparknotes.com/lit/awakening/summary/
# Summary for Awake saved successfully.
# None
# Error: SparkNotes summary not found for Interior
# https://www.sparknotes.com/lit/chains/summary/
# Summary for Chains saved successfully.
# https://www.sparknotes.com/lit/breatheyes/summary/
# Summary for Memory saved successfully.
# None
# Error: SparkNotes summary not found for Universal
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Executions saved successfully.
# https://www.sparknotes.com/lit/carrie/summary/
# Summary for Carries saved successfully.
# None
# Error: SparkNotes summary not found for Propositions
# https://www.sparknotes.com/lit/jungle/summary/
# Summary for Jungle saved successfully.
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Designation saved successfully.
# None
# Error: SparkNotes summary not found for Exasperated
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Lesson saved successfully.
# None
# Error: SparkNotes summary not found for Acceptance
# None
# Error: SparkNotes summary not found for Altercation
# https://www.sparknotes.com/lit/boy-who-harnessed-the-wind/summary/
# Summary for Harness saved successfully.
# https://www.sparknotes.com/lit/night/summary/
# Summary for While saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# ...
# None
# Error: SparkNotes summary not found for Treating
# None
# Error: SparkNotes summary not found for Perpetuate
# https://www.sparknotes.com/lit/room/summary/
# Summary for Room saved successfully.
# https://www.sparknotes.com/lit/sensibility/summary/
# Summary for Sensibility saved successfully.
# None
# Error: SparkNotes summary not found for Descending
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Nourished saved successfully.
# https://www.sparknotes.com/lit/opioneers/summary/
# Summary for Entrusting saved successfully.
# None
# Error: SparkNotes summary not found for Rulers
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Blazed saved successfully.
# None
# Error: SparkNotes summary not found for Computer
# None
# Error: SparkNotes summary not found for Mathias
# None
# Error: SparkNotes summary not found for Capped
# https://www.sparknotes.com/lit/thinair/summary/
# Summary for Flimsy saved successfully.
# https://www.sparknotes.com/lit/a-tale-of-two-cities/summary/
# Summary for Pledges saved successfully.
# None
# Error: SparkNotes summary not found for Descending
# None
# Error: SparkNotes summary not found for Uncorrupted
# None
# Error: SparkNotes summary not found for Issuing
# None
# Error: SparkNotes summary not found for Pleasant
# https://www.sparknotes.com/lit/aeneid/summary/
# Summary for Rome saved successfully.
# None
# Error: SparkNotes summary not found for Aids
# None
# Error: SparkNotes summary not found for Endowed
# None
# Error: SparkNotes summary not found for Tribe
# None
# Error: SparkNotes summary not found for Mischief
# https://www.sparknotes.com/lit/long-walk-to-water/summary/
# Summary for Well saved successfully.
# None
# Error: SparkNotes summary not found for Extension
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Toppled saved successfully.
# https://www.sparknotes.com/lit/the-midnight-library/summary/
# Summary for Lives saved successfully.
# None
# Error: SparkNotes summary not found for Impressions
# https://www.sparknotes.com/lit/power/summary/
# Summary for Power saved successfully.
# None
# Error: SparkNotes summary not found for Alteration
# None
# Error: SparkNotes summary not found for Lasting
# None
# Error: SparkNotes summary not found for Fortify
# https://www.sparknotes.com/lit/oranges/summary/
# Summary for Fruits saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Struck saved successfully.
# None
# Error: SparkNotes summary not found for Brutal
# https://www.sparknotes.com/lit/algernon/summary/
# Summary for Disabled saved successfully.
# None
# Error: SparkNotes summary not found for Stupefies
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Burthened saved successfully.
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Recommend saved successfully.
# https://www.sparknotes.com/lit/beowulf/summary/
# Summary for Unworthy saved successfully.
# None
# Error: SparkNotes summary not found for Opposing
# None
# Error: SparkNotes summary not found for Instead
# None
# Error: SparkNotes summary not found for Retained
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Practical saved successfully.
# https://www.sparknotes.com/lit/childhoodsend/summary/
# Summary for Wings saved successfully.
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Tax saved successfully.
# https://www.sparknotes.com/lit/room/summary/
# Summary for View saved successfully.
# https://www.sparknotes.com/lit/herland/summary/
# Summary for Freely saved successfully.
# None
# Error: SparkNotes summary not found for Embarrassed
# None
# Error: SparkNotes summary not found for Subterfuges
# None
# Error: SparkNotes summary not found for Mother
# None
# Error: SparkNotes summary not found for Inclination
# https://www.sparknotes.com/lit/puddnhead/summary/
# Summary for Extraordinary saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Evidences saved successfully.
# None
# Error: SparkNotes summary not found for Churchill
# None
# Error: SparkNotes summary not found for Stability
# None
# Error: SparkNotes summary not found for Diamonds
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Vision saved successfully.
# https://www.sparknotes.com/lit/aeneid/summary/
# Summary for Descends saved successfully.
# https://www.sparknotes.com/lit/outsiders/summary/
# Summary for Hurry saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Succession saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Fortuitous saved successfully.
# None
# Error: SparkNotes summary not found for Depressed
# None
# Error: SparkNotes summary not found for Baker
# None
# Error: SparkNotes summary not found for Hardship
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Renewing saved successfully.
# None
# Error: SparkNotes summary not found for Frightful
# https://www.sparknotes.com/lit/salesman/summary/
# Summary for Brightens saved successfully.
# None
# Error: SparkNotes summary not found for Youngest
# None
# Error: SparkNotes summary not found for Goals
# None
# Error: SparkNotes summary not found for Variance
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Excises saved successfully.
# None
# Error: SparkNotes summary not found for Effort
# https://www.sparknotes.com/lit/tristram/summary/
# Summary for Confound saved successfully.
# None
# Error: SparkNotes summary not found for Rocky
# None
# Error: SparkNotes summary not found for Dominate
# None
# Error: SparkNotes summary not found for Grand
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Perform saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Firm saved successfully.
# https://www.sparknotes.com/lit/sensibility/summary/
# Summary for Squandered saved successfully.
# None
# Error: SparkNotes summary not found for Complex
# None
# Error: SparkNotes summary not found for Ours
# None
# Error: SparkNotes summary not found for Disguises
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Herself saved successfully.
# None
# Error: SparkNotes summary not found for Commission
# https://www.sparknotes.com/lit/homegoing/summary/
# Summary for Civil saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Explanation saved successfully.
# None
# Error: SparkNotes summary not found for Continues
# None
# Error: SparkNotes summary not found for Retard
# https://www.sparknotes.com/lit/lion/summary/
# Summary for Can saved successfully.
# None
# Error: SparkNotes summary not found for Asserts
# https://www.sparknotes.com/lit/haunting-of-hill-house/summary/
# Summary for Undisturbed saved successfully.
# None
# Error: SparkNotes summary not found for Prowess
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Honest saved successfully.
# None
# Error: SparkNotes summary not found for Respective
# None
# Error: SparkNotes summary not found for Primitive
# None
# Error: SparkNotes summary not found for Duly
# https://www.sparknotes.com/lit/a-court-of-thorns-and-roses/summary/
# Summary for Taskâ saved successfully.
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Delirium saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Executive saved successfully.
# None
# Error: SparkNotes summary not found for Corresponded
# None
# Error: SparkNotes summary not found for Ample
# None
# Error: SparkNotes summary not found for Rush
# None
# Error: SparkNotes summary not found for Endurance
# https://www.sparknotes.com/lit/potter7/summary/
# Summary for Diadem saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Varying saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Subsidized saved successfully.
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Preparing saved successfully.
# None
# Error: SparkNotes summary not found for Abounds
# https://www.sparknotes.com/lit/the-midnight-library/summary/
# Summary for Regretted saved successfully.
# None
# Error: SparkNotes summary not found for Unwarrantable
# https://www.sparknotes.com/lit/educated/summary/
# Summary for College saved successfully.
# https://www.sparknotes.com/lit/brief-wondrous-life-oscar-wao/summary/
# Summary for Aloof saved successfully.
# https://www.sparknotes.com/lit/allquiet/summary/
# Summary for Remake saved successfully.
# None
# Error: SparkNotes summary not found for Fullness
# None
# Error: SparkNotes summary not found for Blowing
# None
# Error: SparkNotes summary not found for Commands
# None
# Error: SparkNotes summary not found for Precise
# None
# Error: SparkNotes summary not found for Injure
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Minimum saved successfully.
# None
# Error: SparkNotes summary not found for Comfort
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Commander saved successfully.
# https://www.sparknotes.com/lit/homegoing/summary/
# Summary for Mines saved successfully.
# https://www.sparknotes.com/lit/catcher/summary/
# Summary for Capture saved successfully.
# None
# Error: SparkNotes summary not found for Throng
# None
# Error: SparkNotes summary not found for Seacoast
# None
# Error: SparkNotes summary not found for Obedience
# None
# Error: SparkNotes summary not found for Refrain
# https://www.sparknotes.com/lit/red-white-and-royal-blue/summary/
# Summary for Reelected saved successfully.
# None
# Error: SparkNotes summary not found for Measured
# None
# Error: SparkNotes summary not found for Edge
# None
# Error: SparkNotes summary not found for Inquiry
# None
# Error: SparkNotes summary not found for Expenditure
# https://www.sparknotes.com/lit/gatsby/summary/
# Summary for Wealthy saved successfully.
# None
# Error: SparkNotes summary not found for Flattery
# https://www.sparknotes.com/lit/divergent/summary/
# Summary for Entails saved successfully.
# https://www.sparknotes.com/lit/a-little-life/summary/
# Summary for Abuse saved successfully.
# None
# Error: SparkNotes summary not found for Ignorant
# None
# Error: SparkNotes summary not found for Abandon
# None
# Error: SparkNotes summary not found for Empires
# None
# Error: SparkNotes summary not found for Theme
# None
# Error: SparkNotes summary not found for Investigate
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for At saved successfully.
# None
# Error: SparkNotes summary not found for Harsh
# https://www.sparknotes.com/lit/yearmagical/summary/
# Summary for Magic saved successfully.
# None
# Error: SparkNotes summary not found for Continuum
# https://www.sparknotes.com/lit/chains/summary/
# Summary for Patriotic saved successfully.
# https://www.sparknotes.com/lit/seize/summary/
# Summary for Day saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Invested saved successfully.
# None
# Error: SparkNotes summary not found for Kept
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Ascertain saved successfully.
# None
# Error: SparkNotes summary not found for Embattled
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for As saved successfully.
# https://www.sparknotes.com/lit/thirteen-reasons-why/summary/
# Summary for Purposes saved successfully.
# Summary for At already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Engineers
# None
# Error: SparkNotes summary not found for Attributed
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Assigned saved successfully.
# None
# Error: SparkNotes summary not found for Murmur
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Give saved successfully.
# None
# Error: SparkNotes summary not found for Begets
# None
# Error: SparkNotes summary not found for Suitably
# https://www.sparknotes.com/lit/solitude/summary/
# Summary for Ceaseless saved successfully.
# https://www.sparknotes.com/lit/luckyjim/summary/
# Summary for Lucky saved successfully.
# None
# Error: SparkNotes summary not found for Humanize
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Transmit saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for 1850 saved successfully.
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Conventions saved successfully.
# None
# Error: SparkNotes summary not found for Controlling
# Summary for Idle already exists. Reading from file.
# https://www.sparknotes.com/lit/origin/summary/
# Summary for Offspring saved successfully.
# None
# Error: SparkNotes summary not found for Correspondent
# https://www.sparknotes.com/lit/millonthefloss/summary/
# Summary for Mills saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Shallow saved successfully.
# None
# Error: SparkNotes summary not found for Ranges
# None
# Error: SparkNotes summary not found for Surging
# https://www.sparknotes.com/lit/oldtestament/summary/
# Summary for Verse saved successfully.
# https://www.sparknotes.com/lit/catcher/summary/
# Summary for Holder saved successfully.
# https://www.sparknotes.com/lit/wonder/summary/
# Summary for Precept saved successfully.
# None
# Error: SparkNotes summary not found for Split
# https://www.sparknotes.com/lit/451/summary/
# Summary for Abolish saved successfully.
# None
# Error: SparkNotes summary not found for Handful
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Restores saved successfully.
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Buy saved successfully.
# https://www.sparknotes.com/lit/circe/summary/
# Summary for Cease saved successfully.
# None
# Error: SparkNotes summary not found for Sources
# https://www.sparknotes.com/lit/mobydick/summary/
# Summary for Ship saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Abused saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Therefore saved successfully.
# https://www.sparknotes.com/lit/jekyll/summary/
# Summary for Frequency saved successfully.
# None
# Error: SparkNotes summary not found for Observation
# None
# Error: SparkNotes summary not found for Tonnage
# None
# Error: SparkNotes summary not found for Sentiment
# None
# Error: SparkNotes summary not found for Safer
# None
# Error: SparkNotes summary not found for Prefers
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Succeed saved successfully.
# https://www.sparknotes.com/lit/secondsex/summary/
# Summary for Situation saved successfully.
# None
# Error: SparkNotes summary not found for Excellence
# https://www.sparknotes.com/lit/gulliver/summary/
# Summary for Travelled saved successfully.
# https://www.sparknotes.com/lit/frankenstein/summary/
# Summary for Impassable saved successfully.
# https://www.sparknotes.com/lit/incidents/summary/
# Summary for 1861 saved successfully.
# None
# Error: SparkNotes summary not found for Construct
# None
# Error: SparkNotes summary not found for Noninterference
# https://www.sparknotes.com/lit/chains/summary/
# Summary for Cause saved successfully.
# None
# Error: SparkNotes summary not found for Consume
# None
# Error: SparkNotes summary not found for Irresistible
# https://www.sparknotes.com/lit/portraitartist/summary/
# Summary for Art saved successfully.
# None
# Error: SparkNotes summary not found for Afresh
# None
# Error: SparkNotes summary not found for Tones
# None
# Error: SparkNotes summary not found for Cherish
# None
# Error: SparkNotes summary not found for Mindful
# None
# Error: SparkNotes summary not found for Restlessness
# https://www.sparknotes.com/lit/catcher/summary/
# Summary for Mental saved successfully.
# Summary for Mental already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Save
# https://www.sparknotes.com/lit/breadgivers/summary/
# Summary for Supplement saved successfully.
# None
# Error: SparkNotes summary not found for Equip
# https://www.sparknotes.com/lit/millionlittle/summary/
# Summary for Pieces saved successfully.
# None
# Error: SparkNotes summary not found for Devastates
# None
# Error: SparkNotes summary not found for Prized
# None
# Error: SparkNotes summary not found for Objects
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Housed saved successfully.
# None
# Error: SparkNotes summary not found for Fugitives
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Avert saved successfully.
# None
# Error: SparkNotes summary not found for Reluctance
# https://www.sparknotes.com/lit/mocking/summary/
# Summary for Killing saved successfully.

# %%
import os
import pandas as pd

# Path to the directory containing the txt files
txt_dir = '/content/summaries/'

# Lists to store the titles and cleaned contents of the txt files
titles = []
contents = []

# Iterate over all files in the directory
for file_name in os.listdir(txt_dir):
    if file_name.endswith('_summary.txt'):
        # Extract the title from the file name
        title = file_name.replace('_summary.txt', '')
        titles.append(title)

        # Read the contents of each txt file
        with open(os.path.join(txt_dir, file_name), 'r') as file:
            content = file.read()
            # Clean the content by replacing newline and tab characters with a space
            cleaned_content = content.replace('\n\t\t\t', ' ')
            contents.append(cleaned_content)

# Create a DataFrame with the titles and cleaned contents
df = pd.DataFrame({'Title': titles, 'Abstract': contents})

# Save the DataFrame to a CSV file
df.to_csv('output7000-8000.csv', index=False)

# %%
df
# Out:
#              Title                                           Abstract
# 0             Onto  Bri Jackson, the narrator of the novel, is a 1...
# 1          Gradual  Grendel, a large bearlike monster, has spent t...
# 2    Comprehensive  1 of\n                        5\n\n           ...
# 3         Withered  In the late winter months of 1801, a man named...
# 4         Bleakest  Esther Summerson describes her childhood and s...
# ..             ...                                                ...
# 465       Immortal  In 1951, an African American woman named Henri...
# 466            Are  Jack Worthing, the play’s protagonist, is a pi...
# 467       Criminal  Rodion Romanovich Raskolnikov, a former studen...
# 468       Transmit  Irene Redfield is a light-skinned Black woman ...
# 469          Lucky  Jim Dixon, a junior lecturer in history at a p...
#
# [470 rows x 2 columns]

# %%
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book

# %%
# Print the first few book titles to verify
print(book_titles[:100])
# Out:
# ['Vibrant', 'Beneficent', 'Faiths', 'Beware', 'Everywhere', 'Detect', 'Cordially', 'Electors', 'Extraneous', 'Seat', 'Signify', 'Stripped', 'Indissoluble', 'Tools', 'Historical', 'Widen', 'Tomorrows', 'Embraced', 'Augustine', 'Richer', 'Suppressing', 'Cultural', 'Deprivation', 'Respite', 'Ornament', 'Tolerate', '1790', 'Members', 'Touch', 'Dome', 'Outline', 'Shrink', 'Closely', 'Circle', 'Extenuating', 'Clarified', 'Distributer', 'Today', 'Mankind', 'Existence', 'Concentrating', 'Pardoned', 'Thereby', 'Churches', 'Shows', 'Discord', 'Confusion', 'Commandments', 'Rock', 'Meliorate', 'Warriors', 'Overturning', 'Mockery', 'Pleasing', 'Portray', 'Impropriety', 'Representatives', 'Systematic', 'Sternest', 'Protection', 'Opening', 'Noted', 'Expenditures', 'Naturally', 'East', 'Present', 'Gathered', 'Authorized', 'Informed', 'Challenged', 'Derived', 'Unsurpassed', 'Confident', 'Invader', 'Requirements', 'Wide', 'Operatives', 'Government', 'Teaching', 'January', 'Shunned', 'Bimetallism', 'Communications', 'Reappear', 'Besides', 'Localized', 'Prior', 'Watchful', 'Sorrow', 'Resounding', 'Foreboding', 'Outgo', 'Reflect', 'Virus', 'Transcendent', 'Casualties', 'Neglect', 'Heavily', 'Xthough', 'Near']

# %%
from googlesearch import search

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url:
            return url
    return None

def get_summary_from_sparknotes(book_title):
    sparknotes_url = get_sparknotes_url(book_title)
    print(sparknotes_url)
    if sparknotes_url:
        response = requests.get(sparknotes_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        summary_div = soup.find('div', class_='mainTextContent main-container')
        if summary_div:
            summary = summary_div.text.strip()
            return summary
        else:
            print(f"Error: Summary not found for {book_title}")
            return None
    else:
        print(f"Error: SparkNotes summary not found for {book_title}")
        return None

book_title = "1984"  # Example book title
summary = get_summary_from_sparknotes(book_title)
if summary:
    print(summary)
# Out:
# https://www.sparknotes.com/lit/1984/summary/
# Winston Smith is a low-ranking member of the ruling Party in London, in the nation of Oceania. Everywhere Winston goes, even his own home, the Party watches him through telescreens; everywhere he looks he sees the face of the Party’s seemingly omniscient leader, a figure known only as Big Brother. The Party controls everything in Oceania, even the people’s history and language. Currently, the Party is forcing the implementation of an invented language called Newspeak, which attempts to prevent political rebellion by eliminating all words related to it. Even thinking rebellious thoughts is illegal. Such thoughtcrime is, in fact, the worst of all crimes.
# As the novel opens, Winston feels frustrated by the oppression and rigid control of the Party, which prohibits free thought, sex, and any expression of individuality. Winston dislikes the party and has illegally purchased a diary in which to write his criminal thoughts. He has also become fixated on a powerful Party member named O’Brien, whom Winston believes is a secret member of the Brotherhood—the mysterious, legendary group that works to overthrow the Party.
# Winston works in the Ministry of Truth, where he alters historical records to fit the needs of the Party. He notices a coworker, a beautiful dark-haired girl, staring at him, and worries that she is an informant who will turn him in for his thoughtcrime. He is troubled by the Party’s control of history: the Party claims that Oceania has always been allied with Eastasia in a war against Eurasia, but Winston seems to recall a time when this was not true. The Party also claims that Emmanuel Goldstein, the alleged leader of the Brotherhood, is the most dangerous man alive, but this does not seem plausible to Winston. Winston spends his evenings wandering through the poorest neighborhoods in London, where the proletarians, or proles, live squalid lives, relatively free of Party monitoring.
# One day, Winston receives a note from the dark-haired girl that reads “I love you.” She tells him her name, Julia, and they begin a covert affair, always on the lookout for signs of Party monitoring. Eventually they rent a room above the secondhand store in the prole district where Winston bought the diary. This relationship lasts for some time. Winston is sure that they will be caught and punished sooner or later (the fatalistic Winston knows that he has been doomed since he wrote his first diary entry), while Julia is more pragmatic and optimistic. As Winston’s affair with Julia progresses, his hatred for the Party grows more and more intense. At last, he receives the message that he has been waiting for: O’Brien wants to see him.
# Winston and Julia travel to O’Brien’s luxurious apartment. As a member of the powerful Inner Party (Winston belongs to the Outer Party), O’Brien leads a life of luxury that Winston can only imagine. O’Brien confirms to Winston and Julia that, like them, he hates the Party, and says that he works against it as a member of the Brotherhood. He indoctrinates Winston and Julia into the Brotherhood, and gives Winston a copy of Emmanuel Goldstein’s book, the manifesto of the Brotherhood. Winston reads the book—an amalgam of several forms of class-based twentieth-century social theory—to Julia in the room above the store. Suddenly, soldiers barge in and seize them. Mr. Charrington, the proprietor of the store, is revealed as having been a member of the Thought Police all along.
# Torn away from Julia and taken to a place called the Ministry of Love, Winston finds that O’Brien, too, is a Party spy who simply pretended to be a member of the Brotherhood in order to trap Winston into committing an open act of rebellion against the Party. O’Brien spends months torturing and brainwashing Winston, who struggles to resist. At last, O’Brien sends him to the dreaded Room 101, the final destination for anyone who opposes the Party. Here, O’Brien tells Winston that he will be forced to confront his worst fear. Throughout the novel, Winston has had recurring nightmares about rats; O’Brien now straps a cage full of rats onto Winston’s head and prepares to allow the rats to eat his face. Winston snaps, pleading with O’Brien to do it to Julia, not to him.
# Giving up Julia is what O’Brien wanted from Winston all along. His spirit broken, Winston is released to the outside world. He meets Julia but no longer feels anything for her. He has accepted the Party entirely and has learned to love Big Brother.
