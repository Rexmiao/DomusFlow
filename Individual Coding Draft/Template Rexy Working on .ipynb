# %%
# !pip install requests
# !pip install beautifulsoup4
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Mounted at /content/drive

# %%
# books_to_scrape = [
#     "1984",
#     "To Kill a Mockingbird",
#     "The Great Gatsby",
#     "Pride and Prejudice",
#     "The Catcher in the Rye",
#     "Lord of the Flies",
#     "Animal Farm",
#     "Brave New World",
#     "The Lord of the Rings",
#     "The Hobbit",
#     "Fahrenheit 451",
#     "The Grapes of Wrath",
#     "The Old Man and the Sea",
#     "The Adventures of Huckleberry Finn",
#     "Moby-Dick",
#     "War and Peace",
#     "Crime and Punishment",
#     "The Brothers Karamazov",
#     "Don Quixote",
#     "Hamlet",
#     "Romeo and Juliet",
#     "Macbeth",
#     "Othello",
#     "The Merchant of Venice",
#     "Frankenstein",
#     "Dracula",
#     "Wuthering Heights",
#     "Jane Eyre",
#     "Great Expectations",
#     "The Scarlet Letter",
#     "The Picture of Dorian Gray",
#     "Heart of Darkness",
#     "One Hundred Years of Solitude",
#     "The Bell Jar",
#     "The Stranger",
#     "Slaughterhouse-Five",
#     "Catch-22",
#     "Beloved",
#     "A Tale of Two Cities",
#     "Les Misérables",
#     "Anna Karenina",
#     "The Odyssey",
#     "The Iliad",
#     "The Aeneid",
#     "The Canterbury Tales",
#     "The Divine Comedy",
#     "Paradise Lost",
#     "Walden",
#     "The Adventures of Tom Sawyer",
#     "Adventures of Huckleberry Finn",
#     "Little Women",
#     "The Grapes of Wrath",
#     "The Sound and the Fury",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "As I Lay Dying",
#     "Their Eyes Were Watching God",
#     "The Color Purple",
#     "Invisible Man",
#     "Native Son",
#     "The Call of the Wild",
#     "White Fang",
#     "The War of the Worlds",
#     "20,000 Leagues Under the Sea",
#     "Journey to the Center of the Earth",
#     "The Three Musketeers",
#     "Robinson Crusoe",
#     "Gulliver's Travels",
#     "The Time Machine",
#     "Dr. Jekyll and Mr. Hyde",
#     "The Adventures of Sherlock Holmes",
#     "The Hound of the Baskervilles",
#     "The Count of Monte Cristo",
#     "The Invisible Man",
#     "The Island of Dr. Moreau",
#     "The Metamorphosis",
#     "The Trial",
#     "One Flew Over the Cuckoo's Nest",
#     "The Jungle",
#     "The Age of Innocence",
#     "The Bostonians",
#     "The Red Badge of Courage",
#     "The Portrait of a Lady",
#     "The Turn of the Screw",
#     "Sister Carrie",
#     "Winesburg, Ohio",
#     "A Farewell to Arms",
#     "For Whom the Bell Tolls",
#     "The Old Man and the Sea",
#     "A Farewell to Arms",
#     "The Sun Also Rises",
#     "A Farewell to Arms",
#     "The Good Soldier",
#     "The Heart of the Matter",
#     "The End of the Affair",
#     "The Power and the Glory",
#     "The Quiet American",
#     "The Third Man",
#     "The Human Factor",
#     "The Tale of Genji",
#     "One Hundred Years of Solitude",
#     "The Master and Margarita",
#     "The Book Thief",
#     "The Kite Runner",
#     "Norwegian Wood",
#     "The Alchemist",
#     "The Joy Luck Club",
#     "Things Fall Apart",
#     "The God of Small Things",
#     "The Hitchhiker's Guide to the Galaxy",
#     "The Handmaid's Tale",
#     "The Road",
#     "The Martian",
#     "Dune",
#     "Harry Potter and the Sorcerer's Stone",
#     "The Hunger Games",
#     "The Help",
#     "The Girl with the Dragon Tattoo",
#     "Gone Girl",
#     "The Girl on the Train",
#     "The Da Vinci Code",
#     "Life of Pi",
#     "The Curious Incident of the Dog in the Night-Time",
#     "The Secret Life of Bees",
#     "The Lovely Bones",
#     "The Book of Negroes",
#     "The Night Circus",
#     "The Catcher in the Rye",
#     "The Perks of Being a Wallflower",
#     "The Fault in Our Stars",
#     "Eleanor Oliphant Is Completely Fine",
#     "Educated",
#     "Where the Crawdads Sing",
#     "Circe",
#     "The Nightingale",
#     "All the Light We Cannot See",
#     "Before We Were Yours",
#     "A Man Called Ove",
#     "The Silent Patient",
#     "The Goldfinch",
#     "Big Little Lies",
#     "The Tattooist of Auschwitz",
#     "The Rosie Project",
#     "The Underground Railroad",
#     "Orphan Train",
#     "A Gentleman in Moscow",
#     "The Light Between Oceans",
#     "The Night Circus",
#     "The Miniaturist",
#     "The Girl With All the Gifts",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Ocean at the End of the Lane",
#     "The Goldfinch",
#     "The Luminaries",
#     "The Circle",
#     "The Nightingale",
#     "The Rosie Project",
#     "The Book Thief",
#     "The Husband's Secret",
#     "The Light Between Oceans",
#     "The Invention of Wings",
#     "The Goldfinch",
#     "The Fault in Our Stars",
#     "The Ocean at the End of the Lane",
#     "The Signature of All Things",
#     "The Lowland",
#     "The Bone Season",
#     "The Luminaries"
# ]
# # Ensure uniqueness of titles
# books_to_scrape = list(set(books_to_scrape))

# # # Truncate the list to 100 titles or less
# # books_to_scrape = books_to_scrape[:100]

# # Print the first few book titles to verify
# print(books_to_scrape[:100])

# %%
import nltk
nltk.download('book')

from nltk.book import text4  # Using text4, which contains a collection of texts from the Gutenberg project

# Extracting unique book titles from the Gutenberg corpus
book_titles = list(set(text4))

# Filtering out non-alphanumeric characters and ensuring titles are capitalized
book_titles = [title.strip().capitalize() for title in book_titles if title.isalnum()]
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book

# %%
print(len(book_titles))
books_to_scrape = book_titles[0:1000]
# books_to_scrape = book_titles[1000:2000]
# etc
print(len(books_to_scrape))
print(books_to_scrape)
# Out:
# 9993
# 1000
# ['Dedicate', 'Attacks', 'Steadfast', 'Grasping', 'Anywhere', 'Riotous', 'Secures', 'Vulnerable', 'Little', 'Disease', 'Revengeful', 'Republicans', 'Compromise', 'Homage', 'Adopted', 'Cheered', 'Proverbial', 'Flatterer', 'Aggregate', 'Artisans', 'Payable', 'Distress', '1812', 'Spain', 'Visit', 'Jailed', 'Conclusive', 'Exercised', 'Allegations', 'Hardworking', 'Notification', 'Page', 'Unprovided', 'Benevolence', 'Unsurpassed', 'Guided', 'Hurtful', 'Territories', 'Object', 'Rank', 'Divided', 'Fourth', 'Reflections', 'Shock', 'Path', 'Revolutionary', 'Explanation', 'Lifted', 'Initiated', 'Remuneration', 'Ensign', 'Conventional', 'Palliation', 'Demands', 'Rehabilitated', 'Structures', 'Old', 'Very', 'Despotic', 'Disheartened', 'Third', 'Magical', 'Forum', 'Affections', 'Waterway', 'Although', 'Preacher', 'Barbarism', 'Restrained', 'Reunite', 'Varieties', 'Unjustified', 'Light', 'Sets', 'Fills', 'Forbid', 'Remake', 'Two', 'Construed', 'Forests', 'Discriminating', 'Entrance', 'Additions', 'Driven', 'Petitions', 'Floats', 'Wiser', 'Confident', 'Grant', 'Entrepreneurial', 'Efficiently', 'Attributed', 'Accordance', 'Distinctions', 'Language', 'Fathers', 'Lesser', 'Blast', 'Unlike', 'Tragically', 'Swollen', 'Northerners', 'Satisfied', 'Abilities', 'Becoming', 'Exonerated', 'Observance', 'Discord', 'Superfluous', 'Joined', 'Utterance', 'Preserving', 'Privilege', 'Gathering', 'Impaired', 'Harvests', '1776', 'Untrammeled', 'Indulged', 'Cupidity', 'Inconvenient', 'Forefathers', 'Operation', 'Generous', 'Narrow', 'Cemented', 'Return', 'Languishes', 'Christs', 'Financial', 'Unpracticed', 'Advanced', 'Refinements', 'Statutes', 'Prefers', 'Pestilence', 'Temper', 'Fractured', 'Island', 'Disrepair', 'Hardly', 'Alone', 'Targets', 'Bleak', 'Dissent', 'Absence', 'Impression', 'Infrastructure', 'Bottom', 'Manifested', 'Benign', 'Republicans', 'Instrument', 'Fabrics', 'Wheels', 'Surging', 'Felicity', 'Ambition', 'Immunity', 'Lands', 'Unification', 'Surface', 'Completeness', 'Interpose', 'Latitude', 'Sources', 'Mortifications', 'Risks', 'Conceived', 'Unselfishness', 'Human', 'Dictators', 'Lived', 'Sects', 'Falling', 'Stunning', 'Paths', 'Confer', 'Seems', 'Rode', 'Eternity', 'Constitutional', 'Throes', 'Defied', 'Proudly', 'Renewing', 'Lawyer', 'Combinations', 'Fullest', 'Adoption', 'Result', 'Uncorrupted', 'Purified', 'Covenant', 'Weed', 'Invited', 'Guide', 'Men', 'Causes', 'Restated', 'Sense', 'Bigotry', 'Goods', 'Golden', 'Lessen', 'Majesty', 'Department', 'Flourishes', 'Proportions', 'Terms', 'Shelter', 'Bulk', 'Each', 'Impairment', 'Activity', 'Blown', 'Proclamation', 'Nowhere', 'Fruition', 'Moves', 'Fomenting', 'Attending', 'Unhonored', 'Befitting', 'How', 'Jefferson', 'Administered', 'Whomsoever', 'Pursuance', 'Situated', 'Deserves', 'Undertake', 'Expectations', 'Incidental', 'Dole', 'Introduced', 'Settlers', 'Rededicate', 'Hall', 'Criminality', 'Accumulation', 'Degrees', 'Transmit', 'As', 'Order', 'Litigation', 'Distressing', 'Animated', 'Cosmos', 'Qualifications', 'Agonizing', 'Looks', 'Defeat', 'Ingenuity', 'Season', 'Sustaining', 'Annals', 'Unalienable', 'Supporting', 'Conscious', 'Propositions', 'Color', 'Acquiring', 'Act', 'Reinvent', 'Allows', 'Beneath', 'Reckoning', 'Corporations', 'Lead', 'Abiding', 'Giants', 'Raw', 'Fervently', 'Recognizing', 'Criminals', 'Overtaxed', 'Guilty', 'Revolution', 'Sharp', 'Example', 'Subsistence', 'Content', 'Marching', 'Opinion', 'Recognitions', 'Mistakes', 'Peoples', 'Bosoms', 'Fortunes', 'Languishing', 'Approved', 'Happen', 'Persecute', 'Dirksen', 'Cling', 'Court', 'Channels', 'Gentlemen', 'Help', 'Bankrupt', 'Cottons', 'Representation', 'Opponent', 'Reviewed', 'Aggrandizement', 'Quietly', 'Understood', 'Rested', 'Match', 'Devise', 'Colors', 'Sleep', 'Assembly', 'Abundance', 'Violative', 'Interest', 'Province', 'Approximate', 'Premeditation', 'Baneful', 'Hands', 'Folks', 'Ripped', 'Electorate', 'Gaining', 'Participation', 'United', 'Organization', 'Denounced', 'Appropriations', 'Image', 'Chosen', 'Precaut ...

# %%
import requests
from googlesearch import search
from bs4 import BeautifulSoup
import os

# def get_summary(book_title):
#     url = f"https://www.sparknotes.com/lit/{book_title}/summary/"
#     response = requests.get(url)
#     # print(response)
#     soup = BeautifulSoup(response.text, 'html.parser')

#     summary_div = soup.find('div', class_='mainTextContent main-container')
#     # print(summary_div)
#     if summary_div:
#         summary = summary_div.text.strip()
#         return summary
#     else:
#         print(f"Error: Summary not found for {book_title}")
#         return None

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url and 'summary' in url:
            return url
    return None


def get_summary_from_sparknotes(book_title):
    # Check if the summary file already exists
    filename = f"{output_dir}/{book_title}_summary.txt"
    if os.path.exists(filename):
      print(f"Summary for {book_title} already exists. Reading from file.")
    else:
      sparknotes_url = get_sparknotes_url(book_title)
      print(sparknotes_url)
      if sparknotes_url:
          response = requests.get(sparknotes_url)
          soup = BeautifulSoup(response.text, 'html.parser')
          summary_div = soup.find('div', class_='mainTextContent main-container')
          if summary_div:
              summary = summary_div.text.strip()
              return summary
          else:
              print(f"Error: Summary not found for {book_title}")
              return None
      else:
          print(f"Error: SparkNotes summary not found for {book_title}")
          return None


def save_summary_to_file(book_title, summary, output_dir = "summaries"):
    if summary is not None:  # Check if summary is not None
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        filename = f"{output_dir}/{book_title}_summary.txt"
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(summary)
            print(f"Summary for {book_title} saved successfully.")
    # else:
    #     print(f"No summary found for {book_title}. Skipping saving to file.")

# books_to_scrape = ["1984", "ToKillAMockingbird", "TheGreatGatsby"]  # Add more book titles as needed

for book_title in books_to_scrape:
    try:
        output_dir = "summaries"
        summary = get_summary_from_sparknotes(book_title)
        # print(summary)

        save_summary_to_file(book_title, summary,)
    except Exception as e:
        print(f"Error processing {book_title}: {e}")
# Out:
# None
# Error: SparkNotes summary not found for Dedicate
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Attacks saved successfully.
# None
# Error: SparkNotes summary not found for Steadfast
# None
# Error: SparkNotes summary not found for Grasping
# https://www.sparknotes.com/lit/sounder/summary/
# Summary for Anywhere saved successfully.
# https://www.sparknotes.com/lit/the-canterbury-tales/summary/
# Summary for Riotous saved successfully.
# https://www.sparknotes.com/lit/nectar/summary/
# Summary for Secures saved successfully.
# None
# Error: SparkNotes summary not found for Vulnerable
# https://www.sparknotes.com/lit/littleprince/summary/
# Summary for Little saved successfully.
# None
# Error: SparkNotes summary not found for Disease
# None
# Error: SparkNotes summary not found for Revengeful
# None
# Error: SparkNotes summary not found for Republicans
# None
# Error: SparkNotes summary not found for Compromise
# None
# Error: SparkNotes summary not found for Homage
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Adopted saved successfully.
# None
# Error: SparkNotes summary not found for Cheered
# None
# Error: SparkNotes summary not found for Proverbial
# https://www.sparknotes.com/lit/pilgrims/summary/
# Summary for Flatterer saved successfully.
# https://www.sparknotes.com/lit/iliad/summary/
# Summary for Aggregate saved successfully.
# None
# Error: SparkNotes summary not found for Artisans
# https://www.sparknotes.com/lit/pygmalion/summary/
# Summary for Payable saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Distress saved successfully.
# https://www.sparknotes.com/lit/warandpeace/summary/
# Summary for 1812 saved successfully.
# https://www.sparknotes.com/lit/lieutenantnun/summary/
# Summary for Spain saved successfully.
# None
# Error: SparkNotes summary not found for Visit
# https://www.sparknotes.com/lit/letter-from-birmingham-jail/summary/
# Summary for Jailed saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Conclusive saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Exercised saved successfully.
# None
# Error: SparkNotes summary not found for Allegations
# None
# Error: SparkNotes summary not found for Hardworking
# None
# Error: SparkNotes summary not found for Notification
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Page saved successfully.
# None
# Error: SparkNotes summary not found for Unprovided
# None
# Error: SparkNotes summary not found for Benevolence
# None
# Error: SparkNotes summary not found for Unsurpassed
# None
# Error: SparkNotes summary not found for Guided
# None
# Error: SparkNotes summary not found for Hurtful
# None
# Error: SparkNotes summary not found for Territories
# None
# Error: SparkNotes summary not found for Object
# None
# Error: SparkNotes summary not found for Rank
# https://www.sparknotes.com/lit/divergent/summary/
# Summary for Divided saved successfully.
# None
# Error: SparkNotes summary not found for Fourth
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Reflections saved successfully.
# None
# Error: SparkNotes summary not found for Shock
# https://www.sparknotes.com/lit/a-worn-path/summary/
# Summary for Path saved successfully.
# None
# Error: SparkNotes summary not found for Revolutionary
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Explanation saved successfully.
# https://www.sparknotes.com/lit/holes/summary/
# Summary for Lifted saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Initiated saved successfully.
# None
# Error: SparkNotes summary not found for Remuneration
# https://www.sparknotes.com/lit/lieutenantnun/summary/
# Summary for Ensign saved successfully.
# None
# Error: SparkNotes summary not found for Conventional
# None
# Error: SparkNotes summary not found for Palliation
# None
# Error: SparkNotes summary not found for Demands
# None
# Error: SparkNotes summary not found for Rehabilitated
# None
# Error: SparkNotes summary not found for Structures
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Old saved successfully.
# https://www.sparknotes.com/lit/very-large-expanse-of-sea/summary/
# Summary for Very saved successfully.
# None
# Error: SparkNotes summary not found for Despotic
# None
# Error: SparkNotes summary not found for Disheartened
# None
# Error: SparkNotes summary not found for Third
# https://www.sparknotes.com/lit/yearmagical/summary/
# Summary for Magical saved successfully.
# None
# Error: SparkNotes summary not found for Forum
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Affections saved successfully.
# None
# Error: SparkNotes summary not found for Waterway
# https://www.sparknotes.com/lit/wuthering/summary/
# Summary for Although saved successfully.
# None
# Error: SparkNotes summary not found for Preacher
# None
# Error: SparkNotes summary not found for Barbarism
# None
# Error: SparkNotes summary not found for Restrained
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Reunite saved successfully.
# None
# Error: SparkNotes summary not found for Varieties
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Unjustified saved successfully.
# https://www.sparknotes.com/lit/all-the-light/summary/
# Summary for Light saved successfully.
# https://www.sparknotes.com/lit/go-set-a-watchman/summary/
# Summary for Sets saved successfully.
# None
# Error: SparkNotes summary not found for Fills
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Forbid saved successfully.
# None
# Error: SparkNotes summary not found for Remake
# https://www.sparknotes.com/lit/walden2/summary/
# Summary for Two saved successfully.
# None
# Error: SparkNotes summary not found for Construed
# https://www.sparknotes.com/lit/lightforest/summary/
# Summary for Forests saved successfully.
# None
# Error: SparkNotes summary not found for Discriminating
# None
# Error: SparkNotes summary not found for Entrance
# None
# Error: SparkNotes summary not found for Additions
# None
# Error: SparkNotes summary not found for Driven
# None
# Error: SparkNotes summary not found for Petitions
# https://www.sparknotes.com/lit/gulliver/summary/
# Summary for Floats saved successfully.
# None
# Error: SparkNotes summary not found for Wiser
# None
# Error: SparkNotes summary not found for Confident
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Grant saved successfully.
# None
# Error: SparkNotes summary not found for Entrepreneurial
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Efficiently saved successfully.
# None
# Error: SparkNotes summary not found for Attributed
# https://www.sparknotes.com/lit/a-court-of-thorns-and-roses/summary/
# Summary for Accordance saved successfully.
# None
# Error: SparkNotes summary not found for Distinctions
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Language saved successfully.
# None
# Error: SparkNotes summary not found for Fathers
# None
# Error: SparkNotes summary not found for Lesser
# https://www.sparknotes.com/lit/sounder/summary/
# Summary for Blast saved successfully.
# None
# Error: SparkNotes summary not found for Unlike
# https://www.sparknotes.com/lit/ultima/summary/
# Summary for Tragically saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Swollen saved successfully.
# None
# Error: SparkNotes summary not found for Northerners
# None
# Error: SparkNotes summary not found for Satisfied
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Abilities saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Becoming saved successfully.
# None
# Error: SparkNotes summary not found for Exonerated
# None
# Error: SparkNotes summary not found for Observance
# None
# Error: SparkNotes summary not found for Discord
# None
# Error: SparkNotes summary not found for Superfluous
# None
# Error: SparkNotes summary not found for Joined
# None
# Error: SparkNotes summary not found for Utterance
# None
# Error: SparkNotes summary not found for Preserving
# None
# Error: SparkNotes summary not found for Privilege
# https://www.sparknotes.com/lit/gatheringofoldmen/summary/
# Summary for Gathering saved successfully.
# https://www.sparknotes.com/lit/algernon/summary/
# Summary for Impaired saved successfully.
# None
# Error: SparkNotes summary not found for Harvests
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for 1776 saved successfully.
# None
# Error: SparkNotes summary not found for Untrammeled
# None
# Error: SparkNotes summary not found for Indulged
# None
# Error: SparkNotes summary not found for Cupidity
# None
# Error: SparkNotes summary not found for Inconvenient
# https://www.sparknotes.com/lit/shipping/summary/
# Summary for Forefathers saved successfully.
# https://www.sparknotes.com/lit/algernon/summary/
# Summary for Operation saved successfully.
# None
# Error: SparkNotes summary not found for Generous
# https://www.sparknotes.com/lit/littleprince/summary/
# Summary for Narrow saved successfully.
# https://www.sparknotes.com/lit/concrete-rose/summary/
# Summary for Cemented saved successfully.
# https://www.sparknotes.com/lit/returnofnative/summary/
# Summary for Return saved successfully.
# https://www.sparknotes.com/lit/ulysses/summary/
# Summary for Languishes saved successfully.
# None
# Error: SparkNotes summary not found for Christs
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Financial saved successfully.
# None
# Error: SparkNotes summary not found for Unpracticed
# https://www.sparknotes.com/lit/lifeofpi/summary/
# Summary for Advanced saved successfully.
# None
# Error: SparkNotes summary not found for Refinements
# None
# Error: SparkNotes summary not found for Statutes
# None
# Error: SparkNotes summary not found for Prefers
# None
# Error: SparkNotes summary not found for Pestilence
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Temper saved successfully.
# None
# Error: SparkNotes summary not found for Fractured
# https://www.sparknotes.com/lit/treasure/summary/
# Summary for Island saved successfully.
# None
# Error: SparkNotes summary not found for Disrepair
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Hardly saved successfully.
# None
# Error: SparkNotes summary not found for Alone
# None
# Error: SparkNotes summary not found for Targets
# https://www.sparknotes.com/lit/bleakhouse/summary/
# Summary for Bleak saved successfully.
# None
# Error: SparkNotes summary not found for Dissent
# None
# Error: SparkNotes summary not found for Absence
# None
# Error: SparkNotes summary not found for Impression
# None
# Error: SparkNotes summary not found for Infrastructure
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Bottom saved successfully.
# None
# Error: SparkNotes summary not found for Manifested
# None
# Error: SparkNotes summary not found for Benign
# None
# Error: SparkNotes summary not found for Republicans
# None
# Error: SparkNotes summary not found for Instrument
# None
# Error: SparkNotes summary not found for Fabrics
# https://www.sparknotes.com/lit/hound/summary/
# Summary for Wheels saved successfully.
# None
# Error: SparkNotes summary not found for Surging
# None
# Error: SparkNotes summary not found for Felicity
# None
# Error: SparkNotes summary not found for Ambition
# None
# Error: SparkNotes summary not found for Immunity
# https://www.sparknotes.com/lit/land/summary/
# Summary for Lands saved successfully.
# None
# Error: SparkNotes summary not found for Unification
# https://www.sparknotes.com/lit/surfacing/summary/
# Summary for Surface saved successfully.
# None
# Error: SparkNotes summary not found for Completeness
# None
# Error: SparkNotes summary not found for Interpose
# None
# Error: SparkNotes summary not found for Latitude
# https://www.sparknotes.com/lit/the-perks-of-being-a-wallflower/summary/
# Summary for Sources saved successfully.
# None
# Error: SparkNotes summary not found for Mortifications
# None
# Error: SparkNotes summary not found for Risks
# https://www.sparknotes.com/lit/born-a-crime/summary/
# Summary for Conceived saved successfully.
# None
# Error: SparkNotes summary not found for Unselfishness
# None
# Error: SparkNotes summary not found for Human
# None
# Error: SparkNotes summary not found for Dictators
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Lived saved successfully.
# None
# Error: SparkNotes summary not found for Sects
# https://www.sparknotes.com/lit/cedars/summary/
# Summary for Falling saved successfully.
# https://www.sparknotes.com/lit/beautiful-and-the-damned/summary/
# Summary for Stunning saved successfully.
# https://www.sparknotes.com/lit/a-worn-path/summary/
# Summary for Paths saved successfully.
# None
# Error: SparkNotes summary not found for Confer
# None
# Error: SparkNotes summary not found for Seems
# https://www.sparknotes.com/lit/incoldblood/summary/
# Summary for Rode saved successfully.
# None
# Error: SparkNotes summary not found for Eternity
# https://www.sparknotes.com/lit/gulliver/summary/
# Summary for Constitutional saved successfully.
# None
# Error: SparkNotes summary not found for Throes
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Defied saved successfully.
# https://www.sparknotes.com/lit/deathbenot/summary/
# Summary for Proudly saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Renewing saved successfully.
# https://www.sparknotes.com/lit/melvillestories/summary/
# Summary for Lawyer saved successfully.
# None
# Error: SparkNotes summary not found for Combinations
# https://www.sparknotes.com/lit/they-both-die-at-the-end/summary/
# Summary for Fullest saved successfully.
# None
# Error: SparkNotes summary not found for Adoption
# https://www.sparknotes.com/lit/stranger/summary/
# Summary for Result saved successfully.
# None
# Error: SparkNotes summary not found for Uncorrupted
# None
# Error: SparkNotes summary not found for Purified
# https://www.sparknotes.com/lit/oldtestament/summary/
# Summary for Covenant saved successfully.
# None
# Error: SparkNotes summary not found for Weed
# https://www.sparknotes.com/lit/andthenthere/summary/
# Summary for Invited saved successfully.
# https://www.sparknotes.com/lit/hitchhikers-guide-to-the-galaxy/summary/
# Summary for Guide saved successfully.
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Men saved successfully.
# None
# Error: SparkNotes summary not found for Causes
# None
# Error: SparkNotes summary not found for Restated
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Sense saved successfully.
# None
# Error: SparkNotes summary not found for Bigotry
# https://www.sparknotes.com/lit/salesman/summary/
# Summary for Goods saved successfully.
# None
# Error: SparkNotes summary not found for Golden
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Lessen saved successfully.
# None
# Error: SparkNotes summary not found for Majesty
# None
# Error: SparkNotes summary not found for Department
# None
# Error: SparkNotes summary not found for Flourishes
# None
# Error: SparkNotes summary not found for Proportions
# https://www.sparknotes.com/lit/the-alchemist/summary/
# Summary for Terms saved successfully.
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Shelter saved successfully.
# https://www.sparknotes.com/lit/iliad/summary/
# Summary for Bulk saved successfully.
# None
# Error: SparkNotes summary not found for Each
# None
# Error: SparkNotes summary not found for Impairment
# None
# Error: SparkNotes summary not found for Activity
# None
# Error: SparkNotes summary not found for Blown
# https://www.sparknotes.com/lit/missjane/summary/
# Error: Summary not found for Proclamation
# https://www.sparknotes.com/lit/puddnhead/summary/
# Summary for Nowhere saved successfully.
# None
# Error: SparkNotes summary not found for Fruition
# None
# Error: SparkNotes summary not found for Moves
# None
# Error: SparkNotes summary not found for Fomenting
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Attending saved successfully.
# None
# Error: SparkNotes summary not found for Unhonored
# https://www.sparknotes.com/lit/shabanu/summary/
# Summary for Befitting saved successfully.
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for How saved successfully.
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Jefferson saved successfully.
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Administered saved successfully.
# None
# Error: SparkNotes summary not found for Whomsoever
# None
# Error: SparkNotes summary not found for Pursuance
# https://www.sparknotes.com/lit/noexit/summary/
# Summary for Situated saved successfully.
# None
# Error: SparkNotes summary not found for Deserves
# https://www.sparknotes.com/lit/the-namesake/summary/
# Summary for Undertake saved successfully.
# https://www.sparknotes.com/lit/greatex/summary/
# Summary for Expectations saved successfully.
# https://www.sparknotes.com/lit/incidents/summary/
# Summary for Incidental saved successfully.
# None
# Error: SparkNotes summary not found for Dole
# None
# Error: SparkNotes summary not found for Introduced
# https://www.sparknotes.com/lit/martianchronicles/summary/
# Summary for Settlers saved successfully.
# https://www.sparknotes.com/lit/portraitartist/summary/
# Summary for Rededicate saved successfully.
# None
# Error: SparkNotes summary not found for Hall
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Criminality saved successfully.
# None
# Error: SparkNotes summary not found for Accumulation
# https://www.sparknotes.com/lit/451/summary/
# Summary for Degrees saved successfully.
# https://www.sparknotes.com/lit/manhattan-transfer/summary/
# Summary for Transmit saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for As saved successfully.
# https://www.sparknotes.com/lit/harrypotter5/summary/
# Summary for Order saved successfully.
# None
# Error: SparkNotes summary not found for Litigation
# None
# Error: SparkNotes summary not found for Distressing
# https://www.sparknotes.com/lit/frankenstein/video-summary/
# Summary for Animated saved successfully.
# https://www.sparknotes.com/lit/elegantuniverse/summary/
# Summary for Cosmos saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Qualifications saved successfully.
# None
# Error: SparkNotes summary not found for Agonizing
# https://www.sparknotes.com/lit/looking-for-alaska/summary/
# Summary for Looks saved successfully.
# None
# Error: SparkNotes summary not found for Defeat
# None
# Error: SparkNotes summary not found for Ingenuity
# https://www.sparknotes.com/lit/amanforallseasons/summary/
# Summary for Season saved successfully.
# None
# Error: SparkNotes summary not found for Sustaining
# None
# Error: SparkNotes summary not found for Annals
# None
# Error: SparkNotes summary not found for Unalienable
# None
# Error: SparkNotes summary not found for Supporting
# https://www.sparknotes.com/lit/underground/summary/
# Error: Summary not found for Conscious
# None
# Error: SparkNotes summary not found for Propositions
# https://www.sparknotes.com/lit/purple/summary/
# Summary for Color saved successfully.
# None
# Error: SparkNotes summary not found for Acquiring
# None
# Error: SparkNotes summary not found for Act
# None
# Error: SparkNotes summary not found for Reinvent
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Allows saved successfully.
# None
# Error: SparkNotes summary not found for Beneath
# None
# Error: SparkNotes summary not found for Reckoning
# None
# Error: SparkNotes summary not found for Corporations
# https://www.sparknotes.com/lit/hunchback/summary/?quickquiz_id=4930
# Summary for Lead saved successfully.
# None
# Error: SparkNotes summary not found for Abiding
# https://www.sparknotes.com/lit/giants/summary/
# Summary for Giants saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Raw saved successfully.
# None
# Error: SparkNotes summary not found for Fervently
# https://www.sparknotes.com/lit/lieutenantnun/summary/
# Summary for Recognizing saved successfully.
# https://www.sparknotes.com/lit/crime/summary/
# Summary for Criminals saved successfully.
# None
# Error: SparkNotes summary not found for Overtaxed
# None
# Error: SparkNotes summary not found for Guilty
# None
# Error: SparkNotes summary not found for Revolution
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Sharp saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Example saved successfully.
# https://www.sparknotes.com/lit/gonewith/summary/
# Summary for Subsistence saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Content saved successfully.
# None
# Error: SparkNotes summary not found for Marching
# https://www.sparknotes.com/lit/tristram/summary/
# Summary for Opinion saved successfully.
# None
# Error: SparkNotes summary not found for Recognitions
# None
# Error: SparkNotes summary not found for Mistakes
# https://www.sparknotes.com/lit/normal-people/summary/
# Summary for Peoples saved successfully.
# None
# Error: SparkNotes summary not found for Bosoms
# https://www.sparknotes.com/lit/mollflanders/summary/
# Summary for Fortunes saved successfully.
# https://www.sparknotes.com/lit/incoldblood/summary/
# Summary for Languishing saved successfully.
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Approved saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Happen saved successfully.
# None
# Error: SparkNotes summary not found for Persecute
# None
# Error: SparkNotes summary not found for Dirksen
# None
# Error: SparkNotes summary not found for Cling
# https://www.sparknotes.com/lit/a-court-of-thorns-and-roses/summary/
# Summary for Court saved successfully.
# None
# Error: SparkNotes summary not found for Channels
# https://www.sparknotes.com/lit/gentleman-in-moscow/summary/
# Summary for Gentlemen saved successfully.
# https://www.sparknotes.com/lit/the-help/summary/
# Summary for Help saved successfully.
# https://www.sparknotes.com/lit/millonthefloss/summary/
# Summary for Bankrupt saved successfully.
# None
# Error: SparkNotes summary not found for Cottons
# None
# Error: SparkNotes summary not found for Representation
# https://www.sparknotes.com/lit/enemyofthepeople/summary/
# Summary for Opponent saved successfully.
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Reviewed saved successfully.
# None
# Error: SparkNotes summary not found for Aggrandizement
# https://www.sparknotes.com/lit/the-quiet-american/summary/
# Summary for Quietly saved successfully.
# None
# Error: SparkNotes summary not found for Understood
# None
# Error: SparkNotes summary not found for Rested
# None
# Error: SparkNotes summary not found for Match
# https://www.sparknotes.com/lit/odyssey/summary/
# Summary for Devise saved successfully.
# https://www.sparknotes.com/lit/colorofwater/summary/
# Summary for Colors saved successfully.
# https://www.sparknotes.com/lit/bigsleep/summary/
# Summary for Sleep saved successfully.
# None
# Error: SparkNotes summary not found for Assembly
# https://www.sparknotes.com/lit/abundance-of-katherines/summary/
# Summary for Abundance saved successfully.
# None
# Error: SparkNotes summary not found for Violative
# None
# Error: SparkNotes summary not found for Interest
# None
# Error: SparkNotes summary not found for Province
# https://www.sparknotes.com/lit/wuthering/summary/
# Summary for Approximate saved successfully.
# None
# Error: SparkNotes summary not found for Premeditation
# None
# Error: SparkNotes summary not found for Baneful
# https://www.sparknotes.com/lit/winesburgohio/summary/
# Summary for Hands saved successfully.
# https://www.sparknotes.com/lit/souls-of-black-folk/summary/
# Summary for Folks saved successfully.
# https://www.sparknotes.com/lit/rip-van-winkle/summary/
# Summary for Ripped saved successfully.
# https://www.sparknotes.com/lit/meridian/summary/
# Summary for Electorate saved successfully.
# None
# Error: SparkNotes summary not found for Gaining
# None
# Error: SparkNotes summary not found for Participation
# https://www.sparknotes.com/lit/american/summary/
# Summary for United saved successfully.
# https://www.sparknotes.com/lit/hunchback/summary/?quickquiz_id=4930
# Summary for Organization saved successfully.
# None
# Error: SparkNotes summary not found for Denounced
# None
# Error: SparkNotes summary not found for Appropriations
# https://www.sparknotes.com/lit/doriangray/summary/
# Summary for Image saved successfully.
# https://www.sparknotes.com/lit/chosen/summary/
# Summary for Chosen saved successfully.
# https://www.sparknotes.com/lit/circe/summary/
# Summary for Precautions saved successfully.
# https://www.sparknotes.com/lit/it-ends-with-us/summary/
# Summary for Hurt saved successfully.
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Guardians saved successfully.
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Thrown saved successfully.
# https://www.sparknotes.com/lit/millonthefloss/summary/
# Summary for Mill saved successfully.
# None
# Error: SparkNotes summary not found for Tonnage
# None
# Error: SparkNotes summary not found for Unite
# None
# Error: SparkNotes summary not found for Confrontation
# None
# Error: SparkNotes summary not found for Experts
# None
# Error: SparkNotes summary not found for Subjects
# https://www.sparknotes.com/lit/allbutmylife/summary/
# Summary for Fraction saved successfully.
# None
# Error: SparkNotes summary not found for Discouragement
# https://www.sparknotes.com/lit/tangerine/summary/
# Summary for Teem saved successfully.
# None
# Error: SparkNotes summary not found for Importunity
# https://www.sparknotes.com/lit/sorrows-of-young-werther/summary/
# Summary for Sorrow saved successfully.
# None
# Error: SparkNotes summary not found for Documents
# None
# Error: SparkNotes summary not found for Ours
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Surrendered saved successfully.
# None
# Error: SparkNotes summary not found for Negative
# None
# Error: SparkNotes summary not found for Illuminated
# https://www.sparknotes.com/lit/love-medicine/summary/
# Summary for Love saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Mingling saved successfully.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Fulfilling saved successfully.
# None
# Error: SparkNotes summary not found for Advantages
# None
# Error: SparkNotes summary not found for Untruths
# None
# Error: SparkNotes summary not found for Transpire
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Deter saved successfully.
# None
# Error: SparkNotes summary not found for Testing
# https://www.sparknotes.com/lit/rollofthunder/summary/
# Error: Summary not found for Boycott
# https://www.sparknotes.com/lit/vanishing-half/summary/
# Summary for Half saved successfully.
# None
# Error: SparkNotes summary not found for Disappearing
# None
# Error: SparkNotes summary not found for Overruling
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Communicating saved successfully.
# None
# Error: SparkNotes summary not found for Incentive
# None
# Error: SparkNotes summary not found for Parity
# None
# Error: SparkNotes summary not found for Stakes
# None
# Error: SparkNotes summary not found for Impartial
# None
# Error: SparkNotes summary not found for Patchwork
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Beloved saved successfully.
# https://www.sparknotes.com/lit/legend/summary/
# Summary for Elector saved successfully.
# None
# Error: SparkNotes summary not found for Virtues
# None
# Error: SparkNotes summary not found for Communism
# https://www.sparknotes.com/lit/andthenthere/summary/
# Summary for None saved successfully.
# None
# Error: SparkNotes summary not found for Forty
# None
# Error: SparkNotes summary not found for Expositions
# https://www.sparknotes.com/lit/poestories/summary/
# Summary for Pits saved successfully.
# None
# Error: SparkNotes summary not found for Protest
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Surrender saved successfully.
# None
# Error: SparkNotes summary not found for Exile
# None
# Error: SparkNotes summary not found for Driving
# None
# Error: SparkNotes summary not found for Bind
# None
# Error: SparkNotes summary not found for Unafraid
# https://www.sparknotes.com/lit/maus/summary/
# Summary for Safe saved successfully.
# https://www.sparknotes.com/lit/frome/summary/
# Summary for From saved successfully.
# https://www.sparknotes.com/lit/redfern/summary/
# Summary for Grow saved successfully.
# https://www.sparknotes.com/lit/so-you-want-to-talk-about-race/summary/
# Summary for Wants saved successfully.
# None
# Error: SparkNotes summary not found for Doth
# None
# Error: SparkNotes summary not found for Decency
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Insisted saved successfully.
# None
# Error: SparkNotes summary not found for Troubled
# https://www.sparknotes.com/lit/screw/summary/
# Summary for Predecessors saved successfully.
# None
# Error: SparkNotes summary not found for Territorial
# https://www.sparknotes.com/lit/arms-and-the-man/summary/
# Summary for Arm saved successfully.
# https://www.sparknotes.com/lit/slaughter/summary/
# Summary for Someone saved successfully.
# None
# Error: SparkNotes summary not found for Rewards
# None
# Error: SparkNotes summary not found for Inevitably
# https://www.sparknotes.com/lit/never-let-me-go/summary/
# Summary for Creative saved successfully.
# https://www.sparknotes.com/lit/dune/summary/
# Summary for Depth saved successfully.
# None
# Error: SparkNotes summary not found for Resting
# https://www.sparknotes.com/lit/eyes/summary/
# Summary for Smooth saved successfully.
# None
# Error: SparkNotes summary not found for 6
# None
# Error: SparkNotes summary not found for Voting
# None
# Error: SparkNotes summary not found for England
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Encouraging saved successfully.
# None
# Error: SparkNotes summary not found for Indicators
# https://www.sparknotes.com/lit/onthebeach/summary/
# Summary for Hemisphere saved successfully.
# https://www.sparknotes.com/lit/haunting-of-hill-house/summary/
# Summary for Hills saved successfully.
# https://www.sparknotes.com/lit/bend-in-the-river/summary/
# Summary for Bush saved successfully.
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Doors saved successfully.
# https://www.sparknotes.com/lit/underground/summary/
# Error: Summary not found for Proofs
# None
# Error: SparkNotes summary not found for Defects
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Moments saved successfully.
# None
# Error: SparkNotes summary not found for Appreciating
# None
# Error: SparkNotes summary not found for Clouds
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Neighborhoods saved successfully.
# None
# Error: SparkNotes summary not found for Prescribe
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Guarding saved successfully.
# None
# Error: SparkNotes summary not found for Pecuniary
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Resolves saved successfully.
# https://www.sparknotes.com/lit/betweentheworld/summary/
# Summary for Xand saved successfully.
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Profitably saved successfully.
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Richer saved successfully.
# None
# Error: SparkNotes summary not found for Owes
# None
# Error: SparkNotes summary not found for Directly
# None
# Error: SparkNotes summary not found for Dictated
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Bloated saved successfully.
# None
# Error: SparkNotes summary not found for Diligence
# None
# Error: SparkNotes summary not found for Reborn
# None
# Error: SparkNotes summary not found for Possession
# https://www.sparknotes.com/lit/wonderful-wizard-of-oz/summary/
# Summary for Kansas saved successfully.
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Honesty saved successfully.
# None
# Error: SparkNotes summary not found for Maintaining
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Deliver saved successfully.
# None
# Error: SparkNotes summary not found for 7
# None
# Error: SparkNotes summary not found for Administration
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Harbors saved successfully.
# None
# Error: SparkNotes summary not found for Relative
# None
# Error: SparkNotes summary not found for Chords
# None
# Error: SparkNotes summary not found for Impartiality
# None
# Error: SparkNotes summary not found for Capability
# None
# Error: SparkNotes summary not found for Abstaining
# None
# Error: SparkNotes summary not found for Articulated
# None
# Error: SparkNotes summary not found for Approaching
# https://www.sparknotes.com/lit/cuckoo/summary/
# Summary for Conformity saved successfully.
# https://www.sparknotes.com/lit/call/summary/
# Summary for Master saved successfully.
# https://www.sparknotes.com/lit/hunchback/summary/
# Summary for Inaugurated saved successfully.
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Added saved successfully.
# None
# Error: SparkNotes summary not found for Pretext
# None
# Error: SparkNotes summary not found for Facilitate
# None
# Error: SparkNotes summary not found for Auspiciously
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Throwing saved successfully.
# https://www.sparknotes.com/lit/slaughter/summary/
# Summary for Umpire saved successfully.
# None
# Error: SparkNotes summary not found for Profligacy
# None
# Error: SparkNotes summary not found for Crude
# https://www.sparknotes.com/lit/crusoe/summary/
# Summary for Elementary saved successfully.
# https://www.sparknotes.com/lit/war-of-the-worlds/summary/
# Summary for Wars saved successfully.
# None
# Error: SparkNotes summary not found for Range
# None
# Error: SparkNotes summary not found for Corporations
# https://www.sparknotes.com/lit/lookingbackward/summary/
# Summary for Look saved successfully.
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Monarchical saved successfully.
# https://www.sparknotes.com/lit/silence/summary/
# Summary for Silent saved successfully.
# None
# Error: SparkNotes summary not found for Imperfect
# https://www.sparknotes.com/lit/salesman/summary/
# Summary for Willingly saved successfully.
# https://www.sparknotes.com/lit/giver/summary/
# Summary for Afforded saved successfully.
# None
# Error: SparkNotes summary not found for Mcconnell
# https://www.sparknotes.com/lit/agamemnon/summary/
# Summary for Performs saved successfully.
# https://www.sparknotes.com/lit/secondsex/summary/
# Summary for Inessential saved successfully.
# None
# Error: SparkNotes summary not found for Reassuring
# None
# Error: SparkNotes summary not found for Whenever
# https://www.sparknotes.com/lit/shipping/summary/
# Summary for Newspaper saved successfully.
# None
# Error: SparkNotes summary not found for Formulating
# https://www.sparknotes.com/lit/unbroken/summary/
# Summary for Unbroken saved successfully.
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Treading saved successfully.
# None
# Error: SparkNotes summary not found for Inefficiently
# None
# Error: SparkNotes summary not found for Levers
# https://www.sparknotes.com/lit/afraidofwoolf/summary/
# Summary for Fearing saved successfully.
# None
# Error: SparkNotes summary not found for Tariff
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Hand saved successfully.
# None
# Error: SparkNotes summary not found for Rediscovered
# None
# Error: SparkNotes summary not found for Still
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Numerous saved successfully.
# https://www.sparknotes.com/lit/the-book-thief/summary/
# Summary for Portion saved successfully.
# https://www.sparknotes.com/lit/remains/summary/
# Summary for Sympathized saved successfully.
# None
# Error: SparkNotes summary not found for Planter
# https://www.sparknotes.com/lit/goodsoldier/summary/
# Summary for Respectfully saved successfully.
# https://www.sparknotes.com/lit/eyes/summary/
# Summary for Their saved successfully.
# https://www.sparknotes.com/lit/montecristo/summary/
# Summary for Counter saved successfully.
# None
# Error: SparkNotes summary not found for Part
# None
# Error: SparkNotes summary not found for Exports
# None
# Error: SparkNotes summary not found for Confidently
# None
# Error: SparkNotes summary not found for Freeman
# https://www.sparknotes.com/lit/other-wes-moore/summary/
# Summary for Additional saved successfully.
# None
# Error: SparkNotes summary not found for Avowal
# None
# Error: SparkNotes summary not found for Indispensably
# None
# Error: SparkNotes summary not found for Engine
# None
# Error: SparkNotes summary not found for Unanswerably
# https://www.sparknotes.com/lit/sistercarrie/summary/
# Summary for Sister saved successfully.
# https://www.sparknotes.com/lit/ceremony/summary/
# Summary for Commencing saved successfully.
# None
# Error: SparkNotes summary not found for Addition
# None
# Error: SparkNotes summary not found for Preserved
# None
# Error: SparkNotes summary not found for Adhere
# https://www.sparknotes.com/lit/herland/summary/
# Summary for Equipping saved successfully.
# None
# Error: SparkNotes summary not found for Scrupulously
# None
# Error: SparkNotes summary not found for Quarters
# None
# Error: SparkNotes summary not found for Bureau
# None
# Error: SparkNotes summary not found for Vestige
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Escapes saved successfully.
# https://www.sparknotes.com/lit/gesture-life/summary/
# Summary for Bedrock saved successfully.
# None
# Error: SparkNotes summary not found for Illness
# None
# Error: SparkNotes summary not found for Unobtrusive
# https://www.sparknotes.com/lit/things/summary/
# Summary for Any saved successfully.
# None
# Error: SparkNotes summary not found for Accomplish
# https://www.sparknotes.com/lit/dollhouse/summary/
# Summary for Contracts saved successfully.
# https://www.sparknotes.com/lit/things/summary/
# Summary for Admonish saved successfully.
# None
# Error: SparkNotes summary not found for Opprobrium
# None
# Error: SparkNotes summary not found for Conquering
# None
# Error: SparkNotes summary not found for Toward
# https://www.sparknotes.com/lit/goodearth/summary/
# Summary for Beneficial saved successfully.
# None
# Error: SparkNotes summary not found for Taxation
# None
# Error: SparkNotes summary not found for Signified
# https://www.sparknotes.com/lit/the-last-wish/summary/
# Summary for Last saved successfully.
# https://www.sparknotes.com/lit/silas/summary/
# Summary for Several saved successfully.
# None
# Error: SparkNotes summary not found for 30th
# https://www.sparknotes.com/lit/gulliver/summary/
# Summary for Bounds saved successfully.
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Claiming saved successfully.
# https://www.sparknotes.com/lit/yearmagical/summary/
# Summary for Year saved successfully.
# None
# Error: SparkNotes summary not found for Doers
# None
# Error: SparkNotes summary not found for Fluctuation
# https://www.sparknotes.com/lit/greatex/summary/
# Summary for Greatest saved successfully.
# https://www.sparknotes.com/lit/distantview/summary/
# Summary for Distant saved successfully.
# None
# Error: SparkNotes summary not found for Academies
# None
# Error: SparkNotes summary not found for Pave
# None
# Error: SparkNotes summary not found for Farthing
# https://www.sparknotes.com/lit/goaskalice/summary/
# Summary for Drugs saved successfully.
# None
# Error: SparkNotes summary not found for Landmarks
# https://www.sparknotes.com/lit/regeneration/summary/
# Summary for Regaining saved successfully.
# None
# Error: SparkNotes summary not found for Riches
# None
# Error: SparkNotes summary not found for Redistributed
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Consolation saved successfully.
# https://www.sparknotes.com/lit/wrinkle/summary/
# Summary for Above saved successfully.
# None
# Error: SparkNotes summary not found for Ahead
# https://www.sparknotes.com/lit/girlinterrupted/summary/
# Summary for Gladly saved successfully.
# None
# Error: SparkNotes summary not found for Sympathies
# None
# Error: SparkNotes summary not found for Swerved
# None
# Error: SparkNotes summary not found for Cutting
# None
# Error: SparkNotes summary not found for Inventions
# None
# Error: SparkNotes summary not found for Therewith
# https://www.sparknotes.com/lit/call/summary/
# Summary for Powerful saved successfully.
# None
# Error: SparkNotes summary not found for Guards
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Cuba saved successfully.
# None
# Error: SparkNotes summary not found for Helped
# None
# Error: SparkNotes summary not found for Speed
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Accurately saved successfully.
# None
# Error: SparkNotes summary not found for Liberate
# None
# Error: SparkNotes summary not found for Preparations
# None
# Error: SparkNotes summary not found for Intact
# None
# Error: SparkNotes summary not found for Destinies
# None
# Error: SparkNotes summary not found for Unbending
# None
# Error: SparkNotes summary not found for Characteristic
# None
# Error: SparkNotes summary not found for Unmindful
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Mortgaging saved successfully.
# https://www.sparknotes.com/lit/lion/summary/
# Summary for Your saved successfully.
# None
# Error: SparkNotes summary not found for Repugnant
# https://www.sparknotes.com/lit/beloved/summary/
# Summary for Please saved successfully.
# None
# Error: SparkNotes summary not found for Sumter
# https://www.sparknotes.com/lit/regeneration/summary/
# Summary for Permanency saved successfully.
# https://www.sparknotes.com/lit/eyes/summary/
# Summary for Watched saved successfully.
# None
# Error: SparkNotes summary not found for Intuitive
# None
# Error: SparkNotes summary not found for Equal
# https://www.sparknotes.com/lit/americanized/summary/
# Summary for Emigrating saved successfully.
# None
# Error: SparkNotes summary not found for Friendship
# None
# Error: SparkNotes summary not found for Tenure
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Expiration saved successfully.
# https://www.sparknotes.com/lit/medea/summary/
# Summary for Current saved successfully.
# https://www.sparknotes.com/lit/the-fault-in-our-stars/summary/
# Summary for Stars saved successfully.
# None
# Error: SparkNotes summary not found for Unanimity
# https://www.sparknotes.com/lit/numberthestars/summary/
# Summary for Number saved successfully.
# None
# Error: SparkNotes summary not found for Enjoyments
# https://www.sparknotes.com/lit/feed/summary/
# Summary for Feed saved successfully.
# https://www.sparknotes.com/lit/lake-of-the-woods/summary/
# Summary for Wood saved successfully.
# None
# Error: SparkNotes summary not found for Decayed
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Practically saved successfully.
# None
# Error: SparkNotes summary not found for Contests
# https://www.sparknotes.com/lit/regeneration/summary/
# Summary for Reposed saved successfully.
# None
# Error: SparkNotes summary not found for Upheavals
# None
# Error: SparkNotes summary not found for Displayed
# None
# Error: SparkNotes summary not found for Direct
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Florida saved successfully.
# None
# Error: SparkNotes summary not found for Existence
# None
# Error: SparkNotes summary not found for Withstood
# None
# Error: SparkNotes summary not found for Plenty
# https://www.sparknotes.com/lit/robin-hood/summary/
# Summary for Outlaws saved successfully.
# None
# Error: SparkNotes summary not found for Contriving
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Straight saved successfully.
# None
# Error: SparkNotes summary not found for Perplexed
# None
# Error: SparkNotes summary not found for Liberator
# None
# Error: SparkNotes summary not found for Needs
# https://www.sparknotes.com/lit/sula/summary/
# Summary for Harmoniously saved successfully.
# https://www.sparknotes.com/lit/oldman/summary/
# Summary for Bygone saved successfully.
# None
# Error: SparkNotes summary not found for Prime
# None
# Error: SparkNotes summary not found for Improvised
# https://www.sparknotes.com/lit/through-the-looking-glass/summary/
# Summary for Using saved successfully.
# None
# Error: SparkNotes summary not found for Advocated
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Infringed saved successfully.
# None
# Error: SparkNotes summary not found for Collisions
# None
# Error: SparkNotes summary not found for Beware
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Opportunityâ saved successfully.
# None
# Error: SparkNotes summary not found for Listen
# None
# Error: SparkNotes summary not found for Census
# None
# Error: SparkNotes summary not found for Humbled
# https://www.sparknotes.com/lit/shadow-and-bone/summary/
# Summary for Firmly saved successfully.
# https://www.sparknotes.com/lit/verity/summary/
# Summary for Fitted saved successfully.
# https://www.sparknotes.com/lit/nativeson/summary/
# Summary for Enable saved successfully.
# None
# Error: SparkNotes summary not found for Line
# https://www.sparknotes.com/lit/normal-people/summary/
# Summary for Peopleâ saved successfully.
# None
# Error: SparkNotes summary not found for Capital
# None
# Error: SparkNotes summary not found for Gratitude
# None
# Error: SparkNotes summary not found for Estimate
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Speech saved successfully.
# https://www.sparknotes.com/lit/extremelyloud/summary/
# Summary for Severely saved successfully.
# https://www.sparknotes.com/lit/gawain/summary/
# Summary for Grounds saved successfully.
# None
# Error: SparkNotes summary not found for Enlarge
# https://www.sparknotes.com/lit/ulysses/summary/
# Summary for Appointment saved successfully.
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Toughest saved successfully.
# None
# Error: SparkNotes summary not found for Brightly
# https://www.sparknotes.com/lit/allquiet/summary/
# Summary for Front saved successfully.
# None
# Error: SparkNotes summary not found for Paraphrase
# None
# Error: SparkNotes summary not found for Overset
# None
# Error: SparkNotes summary not found for Prohibitory
# None
# Error: SparkNotes summary not found for Weakened
# None
# Error: SparkNotes summary not found for Leisure
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Contentions saved successfully.
# None
# Error: SparkNotes summary not found for Rejected
# https://www.sparknotes.com/lit/all-american-boys/summary/
# Summary for Absent saved successfully.
# https://www.sparknotes.com/lit/carrie/summary/
# Summary for Carries saved successfully.
# https://www.sparknotes.com/lit/night/summary/
# Summary for Camps saved successfully.
# https://www.sparknotes.com/lit/iliad/summary/
# Summary for Bulky saved successfully.
# https://www.sparknotes.com/lit/bluesteye/summary/
# Summary for Undercurrent saved successfully.
# None
# Error: SparkNotes summary not found for Contemplating
# https://www.sparknotes.com/lit/davincicode/summary/
# Summary for Code saved successfully.
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for Freeing saved successfully.
# None
# Error: SparkNotes summary not found for Abnormal
# None
# Error: SparkNotes summary not found for Heritage
# https://www.sparknotes.com/lit/so-you-want-to-talk-about-race/summary/
# Summary for Systemic saved successfully.
# https://www.sparknotes.com/lit/twomoons/summary/
# Summary for Moon saved successfully.
# None
# Error: SparkNotes summary not found for External
# https://www.sparknotes.com/lit/the-wave/summary/
# Summary for Waved saved successfully.
# None
# Error: SparkNotes summary not found for Curb
# None
# Error: SparkNotes summary not found for Unexampled
# None
# Error: SparkNotes summary not found for Fiat
# None
# Error: SparkNotes summary not found for Substance
# None
# Error: SparkNotes summary not found for Reality
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Commonwealth saved successfully.
# https://www.sparknotes.com/lit/enemyofthepeople/summary/
# Summary for Enemy saved successfully.
# None
# Error: SparkNotes summary not found for Initiatives
# None
# Error: SparkNotes summary not found for Promise
# https://www.sparknotes.com/lit/redbadge/summary/
# Summary for Badge saved successfully.
# https://www.sparknotes.com/lit/around-the-world-in-80-days/summary/
# Summary for Worldwide saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Lord saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Profess saved successfully.
# None
# Error: SparkNotes summary not found for Sloping
# Summary for Divided already exists. Reading from file.
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Check saved successfully.
# https://www.sparknotes.com/lit/lesmis/summary/
# Summary for However saved successfully.
# https://www.sparknotes.com/lit/childhoodsend/summary/
# Summary for Alien saved successfully.
# None
# Error: SparkNotes summary not found for Unwisely
# https://www.sparknotes.com/lit/earnest/summary/
# Summary for Indicates saved successfully.
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Settlement saved successfully.
# None
# Error: SparkNotes summary not found for Delights
# https://www.sparknotes.com/lit/origin/summary/
# Summary for Continents saved successfully.
# None
# Error: SparkNotes summary not found for Consequences
# None
# ...
# Summary for Expose saved successfully.
# None
# Error: SparkNotes summary not found for Considering
# None
# Error: SparkNotes summary not found for Business
# https://www.sparknotes.com/lit/mangostreet/summary/
# Summary for Someday saved successfully.
# https://www.sparknotes.com/lit/lot49/summary/
# Summary for Scope saved successfully.
# None
# Error: SparkNotes summary not found for Beseech
# https://www.sparknotes.com/lit/birdbybird/summary/
# Summary for Writing saved successfully.
# None
# Error: SparkNotes summary not found for Commensurate
# https://www.sparknotes.com/lit/medea/summary/
# Summary for Arrange saved successfully.
# None
# Error: SparkNotes summary not found for Include
# None
# Error: SparkNotes summary not found for Induces
# None
# Error: SparkNotes summary not found for Proceeded
# None
# Error: SparkNotes summary not found for Sundered
# None
# Error: SparkNotes summary not found for Shine
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Lose saved successfully.
# None
# Error: SparkNotes summary not found for Audacity
# None
# Error: SparkNotes summary not found for Distrust
# None
# Error: SparkNotes summary not found for Propriety
# https://www.sparknotes.com/lit/copperfield/summary/
# Summary for David saved successfully.
# None
# Error: SparkNotes summary not found for Summoned
# https://www.sparknotes.com/lit/giovannis-room/summary/
# Summary for Room saved successfully.
# https://www.sparknotes.com/lit/outliers/summary/
# Summary for Majority saved successfully.
# None
# Error: SparkNotes summary not found for Monday
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Entertained saved successfully.
# https://www.sparknotes.com/lit/speak/summary/
# Summary for Solace saved successfully.
# None
# Error: SparkNotes summary not found for Consumption
# https://www.sparknotes.com/lit/millionlittle/summary/
# Summary for Pieces saved successfully.
# https://www.sparknotes.com/lit/becoming/summary/
# Summary for Inaugural saved successfully.
# None
# Error: SparkNotes summary not found for Moment
# https://www.sparknotes.com/lit/lightforest/summary/
# Summary for Forest saved successfully.
# None
# Error: SparkNotes summary not found for Frugality
# https://www.sparknotes.com/lit/yellowwallpaper/summary/
# Summary for Pattern saved successfully.
# None
# Error: SparkNotes summary not found for Guardianship
# None
# Error: SparkNotes summary not found for Discord
# None
# Error: SparkNotes summary not found for Brown
# None
# Error: SparkNotes summary not found for Vitally
# None
# Error: SparkNotes summary not found for Memorial
# None
# Error: SparkNotes summary not found for Belonged
# None
# Error: SparkNotes summary not found for Spoliation
# None
# Error: SparkNotes summary not found for Trustees
# None
# Error: SparkNotes summary not found for Preach
# https://www.sparknotes.com/lit/divergent/summary/
# Summary for Warped saved successfully.
# None
# Error: SparkNotes summary not found for Measured
# None
# Error: SparkNotes summary not found for Traced
# https://www.sparknotes.com/lit/millionlittle/summary/
# Summary for Million saved successfully.
# https://www.sparknotes.com/lit/sargasso/summary/
# Summary for Wider saved successfully.
# https://www.sparknotes.com/lit/refugee/summary/
# Summary for Displaced saved successfully.
# https://www.sparknotes.com/lit/donquixote/summary/
# Summary for Don saved successfully.
# None
# Error: SparkNotes summary not found for Flattered
# None
# Error: SparkNotes summary not found for Improvement
# https://www.sparknotes.com/lit/gatheringofoldmen/summary/
# Summary for Gather saved successfully.
# https://www.sparknotes.com/lit/persuasion/summary/
# Summary for Reduce saved successfully.
# None
# Error: SparkNotes summary not found for Reminded
# https://www.sparknotes.com/lit/cityladies/summary/
# Summary for Supersede saved successfully.
# https://www.sparknotes.com/lit/ordinarypeople/summary/
# Summary for Individuals saved successfully.
# https://www.sparknotes.com/lit/fallenangels/summary/
# Summary for Terror saved successfully.
# None
# Error: SparkNotes summary not found for Multiplication
# None
# Error: SparkNotes summary not found for Learn
# None
# Error: SparkNotes summary not found for Expedient
# None
# Error: SparkNotes summary not found for Overburdened
# None
# Error: SparkNotes summary not found for Advocates
# None
# Error: SparkNotes summary not found for Describe
# https://www.sparknotes.com/lit/there-there/summary/
# Summary for These saved successfully.
# https://www.sparknotes.com/lit/war-of-the-worlds/summary/
# Summary for Worlds saved successfully.
# None
# Error: SparkNotes summary not found for Thirdly
# None
# Error: SparkNotes summary not found for Fragile
# None
# Error: SparkNotes summary not found for Intimidate
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Raging saved successfully.
# None
# Error: SparkNotes summary not found for Cortes
# None
# Error: SparkNotes summary not found for Exercising
# None
# Error: SparkNotes summary not found for Boundary
# None
# Error: SparkNotes summary not found for Principles
# https://www.sparknotes.com/lit/thousand-splendid-suns/summary/
# Summary for Splendid saved successfully.
# None
# Error: SparkNotes summary not found for Confers
# None
# Error: SparkNotes summary not found for Omen
# https://www.sparknotes.com/lit/everyman/summary/
# Summary for Everyone saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Unfair saved successfully.
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Commanders saved successfully.
# None
# Error: SparkNotes summary not found for Minor
# None
# Error: SparkNotes summary not found for Miracles
# https://www.sparknotes.com/lit/crucible/summary/
# Summary for Crucial saved successfully.
# Summary for Stars already exists. Reading from file.
# None
# Error: SparkNotes summary not found for Insurrection
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Pass saved successfully.
# https://www.sparknotes.com/lit/salesman/summary/
# Summary for Deaths saved successfully.
# https://www.sparknotes.com/lit/heart-of-darkness/summary/
# Summary for Sunk saved successfully.
# None
# Error: SparkNotes summary not found for Explore
# None
# Error: SparkNotes summary not found for Respect
# None
# Error: SparkNotes summary not found for Consoled
# https://www.sparknotes.com/lit/1984/summary/
# Summary for Abstract saved successfully.
# None
# Error: SparkNotes summary not found for Broils
# None
# Error: SparkNotes summary not found for Throw
# https://www.sparknotes.com/lit/hardtimes/summary/
# Summary for Spokesmen saved successfully.
# https://www.sparknotes.com/lit/the-hate-u-give/summary/
# Summary for Hatred saved successfully.
# None
# Error: SparkNotes summary not found for Monumental
# https://www.sparknotes.com/lit/fountainhead/summary/
# Summary for Head saved successfully.
# https://www.sparknotes.com/lit/shane/summary/
# Summary for Uprooting saved successfully.
# None
# Error: SparkNotes summary not found for Contributions
# https://www.sparknotes.com/lit/andthenthere/summary/
# Summary for Frankly saved successfully.
# None
# Error: SparkNotes summary not found for Justly
# None
# Error: SparkNotes summary not found for Plant
# https://www.sparknotes.com/lit/boy-in-striped-pajamas/summary/
# Summary for Disapproved saved successfully.
# https://www.sparknotes.com/lit/handmaid/summary/
# Summary for Commander saved successfully.
# None
# Error: SparkNotes summary not found for Yearning
# https://www.sparknotes.com/lit/swannsway/summary/
# Summary for Ways saved successfully.
# https://www.sparknotes.com/lit/modestproposal/summary/
# Summary for Favorable saved successfully.
# https://www.sparknotes.com/lit/robin-hood/summary/
# Summary for Outlawing saved successfully.
# None
# Error: SparkNotes summary not found for Cooperation
# https://www.sparknotes.com/lit/atonement/summary/
# Summary for Overturning saved successfully.
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for International saved successfully.
# None
# Error: SparkNotes summary not found for Intellectual
# None
# Error: SparkNotes summary not found for Trained
# https://www.sparknotes.com/lit/invisibleman/summary/
# Summary for Literally saved successfully.
# https://www.sparknotes.com/lit/fiveaprils/summary/
# Summary for April saved successfully.
# https://www.sparknotes.com/lit/streetcar/summary/
# Summary for Interfering saved successfully.
# None
# Error: SparkNotes summary not found for Somehow
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Tends saved successfully.
# None
# Error: SparkNotes summary not found for Exchanges
# https://www.sparknotes.com/lit/seize/summary/
# Summary for Assistance saved successfully.
# None
# Error: SparkNotes summary not found for Uncomplaining
# https://www.sparknotes.com/lit/denisovich/summary/
# Summary for Bays saved successfully.
# https://www.sparknotes.com/lit/greatex/summary/
# Summary for Great saved successfully.
# https://www.sparknotes.com/lit/flies/summary/
# Summary for Topic saved successfully.
# None
# Error: SparkNotes summary not found for Beating
# https://www.sparknotes.com/lit/medea/summary/
# Summary for Lamented saved successfully.
# None
# Error: SparkNotes summary not found for Strangled
# None
# Error: SparkNotes summary not found for Subsequent
# None
# Error: SparkNotes summary not found for Vigilance
# None
# Error: SparkNotes summary not found for Mexico
# https://www.sparknotes.com/lit/siddhartha/summary/
# Summary for Readjusts saved successfully.
# https://www.sparknotes.com/lit/treasure/summary/
# Summary for Piracy saved successfully.
# https://www.sparknotes.com/lit/margerykempe/summary/
# Summary for Contemplations saved successfully.
# https://www.sparknotes.com/lit/anthem/summary/
# Summary for Correctives saved successfully.
# None
# Error: SparkNotes summary not found for Recovering
# None
# Error: SparkNotes summary not found for Distorts
# https://www.sparknotes.com/lit/it-starts-with-us/summary/
# Summary for Starting saved successfully.
# None
# Error: SparkNotes summary not found for Diversity
# None
# Error: SparkNotes summary not found for Democrat
# None
# Error: SparkNotes summary not found for Infuriated
# None
# Error: SparkNotes summary not found for Ungrudging
# https://www.sparknotes.com/lit/the-decameron/summary/
# Summary for Declared saved successfully.
# https://www.sparknotes.com/lit/esperanza-rising/summary/
# Summary for Cherished saved successfully.
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Weighed saved successfully.
# None
# Error: SparkNotes summary not found for Technology
# https://www.sparknotes.com/lit/harrypotter5/summary/
# Summary for Orders saved successfully.
# None
# Error: SparkNotes summary not found for Energies
# https://www.sparknotes.com/lit/trial/summary/
# Summary for Sanctioning saved successfully.
# None
# Error: SparkNotes summary not found for Rage
# https://www.sparknotes.com/lit/sorrows-of-young-werther/summary/
# Summary for Young saved successfully.
# None
# Error: SparkNotes summary not found for Intervened
# None
# Error: SparkNotes summary not found for 1800
# None
# Error: SparkNotes summary not found for Flowing
# https://www.sparknotes.com/lit/do-androids-dream-of-electric-sheep/summary/
# Summary for Dream saved successfully.
# https://www.sparknotes.com/lit/locust/summary/
# Summary for Adore saved successfully.
# https://www.sparknotes.com/lit/thingscarried/summary/
# Summary for Mine saved successfully.
# None
# Error: SparkNotes summary not found for Broad
# https://www.sparknotes.com/lit/cry/summary/
# Summary for Gaping saved successfully.
# https://www.sparknotes.com/lit/turtles-all-the-way-down/summary/
# Summary for Obtrusive saved successfully.
# None
# Error: SparkNotes summary not found for Determination
# https://www.sparknotes.com/lit/thirteen-reasons-why/summary/
# Summary for Reason saved successfully.
# https://www.sparknotes.com/lit/trial/summary/
# Summary for Trials saved successfully.
# None
# Error: SparkNotes summary not found for Window
# https://www.sparknotes.com/lit/commonsense/summary/
# Summary for Colonial saved successfully.
# https://www.sparknotes.com/lit/just-mercy/summary/
# Summary for Legal saved successfully.
# https://www.sparknotes.com/lit/a-tale-of-two-cities/summary/
# Summary for Charged saved successfully.
# https://www.sparknotes.com/lit/agamemnon/summary/
# Summary for Beacon saved successfully.
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Perpetual saved successfully.
# https://www.sparknotes.com/lit/451/summary/
# Summary for Begun saved successfully.
# None
# Error: SparkNotes summary not found for Deficit
# None
# Error: SparkNotes summary not found for Indeed
# None
# Error: SparkNotes summary not found for Artificial
# None
# Error: SparkNotes summary not found for Unsolvable
# https://www.sparknotes.com/lit/comingofage/summary/
# Summary for Coming saved successfully.
# None
# Error: SparkNotes summary not found for Facts
# https://www.sparknotes.com/lit/raisin/summary/
# Summary for Investment saved successfully.
# https://www.sparknotes.com/lit/passing/summary/
# Summary for Pushing saved successfully.
# https://www.sparknotes.com/lit/invisibleman/summary/
# Summary for Indivisible saved successfully.
# https://www.sparknotes.com/lit/annefrank/summary/
# Summary for Monthly saved successfully.
# https://www.sparknotes.com/lit/garciagirls/summary/
# Summary for Troublesome saved successfully.
# None
# Error: SparkNotes summary not found for Arsenals
# None
# Error: SparkNotes summary not found for Eight
# None
# Error: SparkNotes summary not found for Steamers
# https://www.sparknotes.com/lit/so-you-want-to-talk-about-race/summary/
# Summary for Racial saved successfully.
# https://www.sparknotes.com/lit/rip-van-winkle/summary/
# Summary for Ribbon saved successfully.
# None
# Error: SparkNotes summary not found for Vicious
# https://www.sparknotes.com/lit/nickel-and-dimed/summary/
# Summary for Dimmed saved successfully.
# None
# Error: SparkNotes summary not found for Avow
# https://www.sparknotes.com/lit/micemen/summary/
# Summary for Amongst saved successfully.
# None
# Error: SparkNotes summary not found for Promptly
# None
# Error: SparkNotes summary not found for Relying
# None
# Error: SparkNotes summary not found for Unique
# https://www.sparknotes.com/lit/numberthestars/summary/
# Summary for Knowing saved successfully.
# https://www.sparknotes.com/lit/unbearablelightness/summary/
# Summary for Weak saved successfully.
# https://www.sparknotes.com/lit/elegantuniverse/summary/
# Summary for Billion saved successfully.
# https://www.sparknotes.com/lit/christmascarol/summary/
# Summary for Warmth saved successfully.
# None
# Error: SparkNotes summary not found for Chiefly
# https://www.sparknotes.com/lit/educated/summary/
# Summary for Recognized saved successfully.
# None
# Error: SparkNotes summary not found for Scapegoats
# None
# Error: SparkNotes summary not found for Augmentation
# None
# Error: SparkNotes summary not found for Exigencies
# None
# Error: SparkNotes summary not found for Marker
# https://www.sparknotes.com/lit/killerangels/summary/
# Summary for Angels saved successfully.
# None
# Error: SparkNotes summary not found for Wreckage
# https://www.sparknotes.com/lit/coldmountain/summary/
# Summary for Federal saved successfully.
# https://www.sparknotes.com/lit/lessonbefore/summary/
# Summary for Preceding saved successfully.
# None
# Error: SparkNotes summary not found for Descending
# https://www.sparknotes.com/lit/the-alchemist/summary/
# Summary for Solid saved successfully.
# https://www.sparknotes.com/lit/poestories/summary/
# Summary for Brilliant saved successfully.
# None
# Error: SparkNotes summary not found for Safeguarding
# None
# Error: SparkNotes summary not found for Argument
# None
# Error: SparkNotes summary not found for Profound
# https://www.sparknotes.com/lit/persepolis-the-story-of-a-childhood/summary/
# Summary for Hazard saved successfully.
# https://www.sparknotes.com/lit/a-clash-of-kings/summary/
# Summary for Rulers saved successfully.
# None
# Error: SparkNotes summary not found for Prevail
# None
# Error: SparkNotes summary not found for Impoverishment
# https://www.sparknotes.com/lit/ourtown/summary/
# Summary for Corner saved successfully.
# https://www.sparknotes.com/lit/houseofspirits/summary/
# Summary for Spirits saved successfully.
# https://www.sparknotes.com/lit/up-from-slavery/summary/
# Summary for Exposition saved successfully.
# https://www.sparknotes.com/lit/a-tale-of-two-cities/summary/
# Summary for Condemning saved successfully.

# %%
import os
import pandas as pd

# Path to the directory containing the txt files
txt_dir = '/content/summaries/'

# Lists to store the titles and cleaned contents of the txt files
titles = []
contents = []

# Iterate over all files in the directory
for file_name in os.listdir(txt_dir):
    if file_name.endswith('_summary.txt'):
        # Extract the title from the file name
        title = file_name.replace('_summary.txt', '')
        titles.append(title)

        # Read the contents of each txt file
        with open(os.path.join(txt_dir, file_name), 'r') as file:
            content = file.read()
            # Clean the content by replacing newline and tab characters with a space
            cleaned_content = content.replace('\n\t\t\t', ' ')
            contents.append(cleaned_content)

# Create a DataFrame with the titles and cleaned contents
df = pd.DataFrame({'Title': titles, 'Abstract': contents})

# Save the DataFrame to a CSV file
df.to_csv('output0-1000.csv', index=False)

# %%
df
# Out:
#             Title                                           Abstract
# 0           Legal  Lawyer Bryan Stevenson gives a first-person ac...
# 1         Someday  In a series of vignettes, The House on Mango S...
# 2        Animated  Video SparkNotes: A Summary of Mary Shelley's ...
# 3        Impaired  Charlie Gordon, an intellectually disabled thi...
# 4          Cosmos  In Part I of The Elegant Universe, “The Edge o...
# ..            ...                                                ...
# 454        Deaths  As a flute melody plays, Willy Loman returns t...
# 455      Colonial  In Common Sense, Thomas Paine argues for Ameri...
# 456  Undercurrent  Nine-year-old Claudia and ten-year-old Frieda ...
# 457      Transmit  Manhattan Transfer tells the story of multiple...
# 458      Systemic  Oluo uses the introduction to establish hersel...
#
# [459 rows x 2 columns]

# %%
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book

# %%
# Print the first few book titles to verify
print(book_titles[:100])
# Out:
# ['Vibrant', 'Beneficent', 'Faiths', 'Beware', 'Everywhere', 'Detect', 'Cordially', 'Electors', 'Extraneous', 'Seat', 'Signify', 'Stripped', 'Indissoluble', 'Tools', 'Historical', 'Widen', 'Tomorrows', 'Embraced', 'Augustine', 'Richer', 'Suppressing', 'Cultural', 'Deprivation', 'Respite', 'Ornament', 'Tolerate', '1790', 'Members', 'Touch', 'Dome', 'Outline', 'Shrink', 'Closely', 'Circle', 'Extenuating', 'Clarified', 'Distributer', 'Today', 'Mankind', 'Existence', 'Concentrating', 'Pardoned', 'Thereby', 'Churches', 'Shows', 'Discord', 'Confusion', 'Commandments', 'Rock', 'Meliorate', 'Warriors', 'Overturning', 'Mockery', 'Pleasing', 'Portray', 'Impropriety', 'Representatives', 'Systematic', 'Sternest', 'Protection', 'Opening', 'Noted', 'Expenditures', 'Naturally', 'East', 'Present', 'Gathered', 'Authorized', 'Informed', 'Challenged', 'Derived', 'Unsurpassed', 'Confident', 'Invader', 'Requirements', 'Wide', 'Operatives', 'Government', 'Teaching', 'January', 'Shunned', 'Bimetallism', 'Communications', 'Reappear', 'Besides', 'Localized', 'Prior', 'Watchful', 'Sorrow', 'Resounding', 'Foreboding', 'Outgo', 'Reflect', 'Virus', 'Transcendent', 'Casualties', 'Neglect', 'Heavily', 'Xthough', 'Near']

# %%
from googlesearch import search

def get_sparknotes_url(book_title):
    query = f"{book_title} site:sparknotes.com/lit summary"
    for url in search(query, num=5, stop=5, pause=2):
        if 'sparknotes.com/lit' in url:
            return url
    return None

def get_summary_from_sparknotes(book_title):
    sparknotes_url = get_sparknotes_url(book_title)
    print(sparknotes_url)
    if sparknotes_url:
        response = requests.get(sparknotes_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        summary_div = soup.find('div', class_='mainTextContent main-container')
        if summary_div:
            summary = summary_div.text.strip()
            return summary
        else:
            print(f"Error: Summary not found for {book_title}")
            return None
    else:
        print(f"Error: SparkNotes summary not found for {book_title}")
        return None

book_title = "1984"  # Example book title
summary = get_summary_from_sparknotes(book_title)
if summary:
    print(summary)
# Out:
# https://www.sparknotes.com/lit/1984/summary/
# Winston Smith is a low-ranking member of the ruling Party in London, in the nation of Oceania. Everywhere Winston goes, even his own home, the Party watches him through telescreens; everywhere he looks he sees the face of the Party’s seemingly omniscient leader, a figure known only as Big Brother. The Party controls everything in Oceania, even the people’s history and language. Currently, the Party is forcing the implementation of an invented language called Newspeak, which attempts to prevent political rebellion by eliminating all words related to it. Even thinking rebellious thoughts is illegal. Such thoughtcrime is, in fact, the worst of all crimes.
# As the novel opens, Winston feels frustrated by the oppression and rigid control of the Party, which prohibits free thought, sex, and any expression of individuality. Winston dislikes the party and has illegally purchased a diary in which to write his criminal thoughts. He has also become fixated on a powerful Party member named O’Brien, whom Winston believes is a secret member of the Brotherhood—the mysterious, legendary group that works to overthrow the Party.
# Winston works in the Ministry of Truth, where he alters historical records to fit the needs of the Party. He notices a coworker, a beautiful dark-haired girl, staring at him, and worries that she is an informant who will turn him in for his thoughtcrime. He is troubled by the Party’s control of history: the Party claims that Oceania has always been allied with Eastasia in a war against Eurasia, but Winston seems to recall a time when this was not true. The Party also claims that Emmanuel Goldstein, the alleged leader of the Brotherhood, is the most dangerous man alive, but this does not seem plausible to Winston. Winston spends his evenings wandering through the poorest neighborhoods in London, where the proletarians, or proles, live squalid lives, relatively free of Party monitoring.
# One day, Winston receives a note from the dark-haired girl that reads “I love you.” She tells him her name, Julia, and they begin a covert affair, always on the lookout for signs of Party monitoring. Eventually they rent a room above the secondhand store in the prole district where Winston bought the diary. This relationship lasts for some time. Winston is sure that they will be caught and punished sooner or later (the fatalistic Winston knows that he has been doomed since he wrote his first diary entry), while Julia is more pragmatic and optimistic. As Winston’s affair with Julia progresses, his hatred for the Party grows more and more intense. At last, he receives the message that he has been waiting for: O’Brien wants to see him.
# Winston and Julia travel to O’Brien’s luxurious apartment. As a member of the powerful Inner Party (Winston belongs to the Outer Party), O’Brien leads a life of luxury that Winston can only imagine. O’Brien confirms to Winston and Julia that, like them, he hates the Party, and says that he works against it as a member of the Brotherhood. He indoctrinates Winston and Julia into the Brotherhood, and gives Winston a copy of Emmanuel Goldstein’s book, the manifesto of the Brotherhood. Winston reads the book—an amalgam of several forms of class-based twentieth-century social theory—to Julia in the room above the store. Suddenly, soldiers barge in and seize them. Mr. Charrington, the proprietor of the store, is revealed as having been a member of the Thought Police all along.
# Torn away from Julia and taken to a place called the Ministry of Love, Winston finds that O’Brien, too, is a Party spy who simply pretended to be a member of the Brotherhood in order to trap Winston into committing an open act of rebellion against the Party. O’Brien spends months torturing and brainwashing Winston, who struggles to resist. At last, O’Brien sends him to the dreaded Room 101, the final destination for anyone who opposes the Party. Here, O’Brien tells Winston that he will be forced to confront his worst fear. Throughout the novel, Winston has had recurring nightmares about rats; O’Brien now straps a cage full of rats onto Winston’s head and prepares to allow the rats to eat his face. Winston snaps, pleading with O’Brien to do it to Julia, not to him.
# Giving up Julia is what O’Brien wanted from Winston all along. His spirit broken, Winston is released to the outside world. He meets Julia but no longer feels anything for her. He has accepted the Party entirely and has learned to love Big Brother.
